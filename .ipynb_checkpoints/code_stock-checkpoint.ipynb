# %%
# !pip install pulp
# !pip install yfinance
# Out:
# Requirement already satisfied: pulp in /opt/conda/lib/python3.10/site-packages (2.7.0)
# Requirement already satisfied: yfinance in /opt/conda/lib/python3.10/site-packages (0.2.37)
# Requirement already satisfied: appdirs>=1.4.4 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: lxml>=4.9.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2.4.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/conda/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: html5lib>=1.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: pytz>=2022.5 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: pandas>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: peewee>=3.16.2 in /opt/conda/lib/python3.10/site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.1.1)

# %%
# !pip install cvxpy
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
import cvxpy as cp
import scipy.linalg as la
import pulp
# Out:
# Requirement already satisfied: cvxpy in /opt/conda/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: ecos>=2 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (2.0.13)
# Requirement already satisfied: osqp>=0.6.2 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (0.6.5)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (1.10.0)
# Requirement already satisfied: pybind11 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (2.12.0)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (1.23.5)
# Requirement already satisfied: clarabel>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (0.7.1)
# Requirement already satisfied: scs>=3.0 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (3.2.4.post1)
# Requirement already satisfied: qdldl in /opt/conda/lib/python3.10/site-packages (from osqp>=0.6.2->cvxpy) (0.1.7.post1)

# %% [markdown]
# ## how we load data from yahoo finance

# %% [markdown]
# #### Short-term corporate bond data

# %%
T = 1 # Number of days in time period
R1 = []
cor_bonds = ["SCHJ","IGSB","VCSH","SPSB","SLQD","ICSH"]

for bond in cor_bonds:
    data = yf.Ticker(bond)
    # 我先改成1年， 这个之后可以随时改成想要的时段
    bond = data.history(period="1y")

    # close values on that day
    close = bond['Close'].values

    # convert day to day close values to return
    returns = (close[T:] - close[:-T])/close[:-T]
    R1.append(returns)

R1 = np.array(R1).T
r1 = np.mean(R1,axis=0)
S1 = np.cov(R1.T)
R1
# Out:
# array([[ 0.0012615 ,  0.0009899 ,  0.0011815 ,  0.00135278,  0.        ,
#          0.000199  ],
#        [ 0.00178484,  0.00197799,  0.00196661,  0.00135082,  0.00247684,
#          0.00039873],
#        [-0.00199126, -0.00256621, -0.00222454, -0.00168638, -0.00185282,
#         -0.0001992 ],
#        ...,
#        [-0.00104   , -0.00117619, -0.00116995, -0.00067471, -0.00081635,
#          0.00019846],
#        [ 0.00110351,  0.00117758,  0.00143155,  0.00101279,  0.00122552,
#          0.00019849],
#        [-0.00546972, -0.0056851 , -0.00571793, -0.00404718, -0.00448799,
#         -0.00069444]])

# %% [markdown]
# #### Stock data

# %%
T = 1 # Number of days in time period
R = []
assets = ["AAPL","EA","MSFT","NFLX","GOOGL","TSLA"]

for stock in assets:
    data = yf.Ticker(stock)
    # 我先改成1年， 这个之后可以随时改成想要的时段
    df = data.history(period="1y")

    # close values on that day
    close = df['Close'].values

    # convert day to day close values to return
    returns = (close[T:] - close[:-T])/close[:-T]
    R.append(returns)

R = np.array(R).T
r = np.mean(R,axis=0)
S = np.cov(R.T)

# %%
R
# Out:
# array([[-0.00435317,  0.00358049,  0.00233358, -0.02122939, -0.00673943,
#         -0.03346004],
#        [ 0.03410361,  0.01704604,  0.02239938,  0.04579646,  0.02666285,
#          0.02968872],
#        [-0.00211396, -0.0031962 , -0.0127657 , -0.02183771,  0.0134041 ,
#         -0.00484128],
#        ...,
#        [-0.00666355, -0.00222575, -0.00218554, -0.01221356,  0.01540988,
#          0.04899941],
#        [ 0.00724251,  0.00530771,  0.00398032, -0.01624729,  0.01130126,
#          0.02254601],
#        [-0.01113927, -0.01063585, -0.00708452,  0.0006147 , -0.00293746,
#         -0.02894624]])

# %% [markdown]
# ## tesla in past 1 years

# %%
# last df is Tesla
df['Open'].plot()
plt.show()

# %% [markdown]
# ## histogram of Tesla in past 1 years

# %%
return_TSLA = R[:,-1]
plt.hist(return_TSLA,bins=50)
plt.show()

# %%
r
# Out:
# array([0.00026376, 0.0001986 , 0.00173443, 0.00265228, 0.0017161 ,
#        0.00012128])

# %%
S
# Out:
# array([[1.46794965e-04, 4.51282562e-05, 8.14891922e-05, 9.54639986e-05,
#         9.41011657e-05, 1.32531730e-04],
#        [4.51282562e-05, 1.24669317e-04, 3.91244085e-05, 4.06778992e-05,
#         3.81256549e-05, 9.03957634e-05],
#        [8.14891922e-05, 3.91244085e-05, 1.90445188e-04, 1.22598644e-04,
#         9.90207916e-05, 1.07310872e-04],
#        [9.54639986e-05, 4.06778992e-05, 1.22598644e-04, 5.03095045e-04,
#         1.14351464e-04, 1.24975462e-04],
#        [9.41011657e-05, 3.81256549e-05, 9.90207916e-05, 1.14351464e-04,
#         2.93251399e-04, 1.35635291e-04],
#        [1.32531730e-04, 9.03957634e-05, 1.07310872e-04, 1.24975462e-04,
#         1.35635291e-04, 9.08183849e-04]])

# %% [markdown]
# # We consider risk as MAD first, all these models are model 1x

# %% [markdown]
# # model 1A
# when we minimize MAD under a specified expected return $r_0$
# $$
# \begin{gathered}
# \operatorname{maximize} -\frac{1}{T} \sum_{t=1}^T\left|\sum_j x_j\left(R_j(t)-r_j\right)\right| \\
# \text { subject to } \sum_j x_j=1 \\
#   \sum_j x_j r_j = r_0 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$
#
# The LP version is
# $$
# \begin{gathered}
# & \operatorname{maximize} -\frac{1}{T} \sum_{t=1}^T y_t \\
# & \text { subject to }-y_t \leq \sum_j x_j\left(R_j(t)-r_j\right) \leq y_t \quad t=1,2, \ldots, T \text {, } \\
# & \sum_j x_j=1 \\
# &  \sum_j x_j r_j = r_0 \\
# & x_j \geq 0 \quad j=1,2, \ldots, n, \\
# & r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods
r0 = 0.0008
print(n,T,r0)


# Create a LP problem
prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

# Define decision variables
x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

# Define objective function
prob +=  - (1/T) * lpSum(y[t] for t in range(T)), "Objective"

# Define constraints
for t in range(T):
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

prob += lpSum(r[j] * x[j] for j in range(n)) == r0

prob += lpSum(x) == 1, "Sum_of_weights"

# Solve the problem
prob.solve()

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 0.0008
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/74631eda275f48588e0829bf5b4adbd8-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/74631eda275f48588e0829bf5b4adbd8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570024 (2)
# 45  Obj -0.00090544277 Primal inf 76.035579 (231)
# 92  Obj -0.0022363862 Primal inf 80.276403 (212)
# 139  Obj -0.0034727384 Primal inf 172.0619 (199)
# 188  Obj -0.0052859756 Primal inf 43.899747 (159)
# 239  Obj -0.0064476385 Primal inf 35.104468 (108)
# 292  Obj -0.0069253039
# Optimal - objective value -0.006870765
# After Postsolve, objective -0.006870765, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764965 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.066356673
# x1: 0.56828287
# x2: 0.23261308
# x3: 0.040997357
# x4: 0.091750021
# x5: 0.0
# expected return (MAD): 0.0007999999968453811
# Mean Absolute Deviation (MAD): 0.006870764954653388

# %% [markdown]
# # model 1B
# when we maximize return under a specified MAD constrait $m_0$
# $$
# \begin{gathered}
# \operatorname{maximize} \sum_j x_j r_j  \\
# \text { subject to } \sum_j x_j=1 \\
#   \frac{1}{T} \sum_{t=1}^T\left|\sum_j x_j\left(R_j(t)-r_j\right)\right| \leq m_0 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$
#
# The LP version is
# $$
# \begin{gathered}
# & \operatorname{maximize}  \sum_j x_j r_j   \\
# & \text { subject to }-y_t \leq \sum_j x_j\left(R_j(t)-r_j\right) \leq y_t \quad t=1,2, \ldots, T \text {, } \\
# & \sum_j x_j=1 \\
# & \frac{1}{T} \sum_{t=1}^T y_t \leq m_0  \\
# & x_j \geq 0 \quad j=1,2, \ldots, n, \\
# & r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods
m0 = 0.007
print(n,T,r0)


# Create a LP problem
prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

# Define decision variables
x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

# Define objective function
prob += lpSum(r[j] * x[j] for j in range(n)), "Objective"

# Define constraints
for t in range(T):
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

prob +=  (1/T) * lpSum(y[t] for t in range(T)) <= m0, "Risk"

prob += lpSum(x) == 1, "Sum_of_weights"

# Solve the problem
prob.solve()

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 0.0008
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e7857d16b83a465e8d2273b5fc35d750-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/e7857d16b83a465e8d2273b5fc35d750-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3771 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3358 (-413) elements
# Perturbing problem by 0.001% of 0.0279967 - largest nonzero change 0.00012071589 ( 26.772376%) - largest zero change 9.9738264e-05
# 0  Obj -0 Primal inf 11.586568 (2) Dual inf 0.050520616 (6)
# 59  Obj 0.0046719901 Primal inf 114.03024 (207)
# 94  Obj 0.0028145928 Primal inf 454.48603 (224)
# 134  Obj 0.001904607 Primal inf 137.87635 (195)
# 176  Obj 0.0015037659 Primal inf 22.862711 (134)
# 219  Obj 0.0012395962 Primal inf 69.857513 (168)
# 263  Obj 0.00095550152 Primal inf 12.454471 (84)
# 297  Obj 0.0008106527
# Optimal - objective value 0.00091480771
# After Postsolve, objective 0.00091480771, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.0009148077101 - 297 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.027648439
# x1: 0.54113437
# x2: 0.27074491
# x3: 0.058828681
# x4: 0.10164361
# x5: 0.0
# expected return (MAD): 0.0009148077234800783
# Mean Absolute Deviation (MAD): 0.006999999991334653

# %% [markdown]
# ## model 1C
# when combine return and risk together with $\mu$
#
# $$
# \begin{gathered}
# \operatorname{maximize} \mu \sum_j x_j r_j-\frac{1}{T} \sum_{t=1}^T\left|\sum_j x_j\left(R_j(t)-r_j\right)\right| \\
# \text { subject to } \sum_j x_j=1 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$
#
# The LP version is
# $$
# \begin{aligned}
# & \operatorname{maximize} \mu \sum_j x_j r_j-\frac{1}{T} \sum_{t=1}^T y_t \\
# & \text { subject to }-y_t \leq \sum_j x_j\left(R_j(t)-r_j\right) \leq y_t \quad t=1,2, \ldots, T \text {, } \\
# & \sum_j x_j=1 \\
# & x_j \geq 0 \quad j=1,2, \ldots, n \\
# & y_t \geq 0 \quad t=1,2, \ldots, T . \\
# &
# \end{aligned}
# $$
#
# below is pulp implementation

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods
mu = 1
print(n,T,mu)


# Create a LP problem
prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

# Define decision variables
x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

# Define objective function
prob += lpSum(r[j] * x[j] for j in range(n)) * mu - (1/T) * lpSum(y[t] for t in range(T)), "Objective"

# Define constraints
for t in range(T):
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

prob += lpSum(x) == 1, "Sum_of_weights"

# Solve the problem
prob.solve()

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 1
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/130449a7a64740c3aba1ce4073ea82a5-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/130449a7a64740c3aba1ce4073ea82a5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.0279967 - largest nonzero change 8.1754702e-05 ( 24.953899%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597127 (1) Dual inf 0.050709455 (6)
# 68  Obj -0.0010263294 Primal inf 238.2922 (221)
# 117  Obj -0.0026911108 Primal inf 97.789421 (190)
# 165  Obj -0.0042247458 Primal inf 263.01076 (239)
# 208  Obj -0.0054947187 Primal inf 146.46431 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919258 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655199 Dual inf 0.00036428427 (1)
# 273  Obj -0.0060654997
# Optimal - objective value -0.0060654997
# After Postsolve, objective -0.0060654997, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499701 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.049672702
# x1: 0.56565559
# x2: 0.23711991
# x3: 0.05627606
# x4: 0.091275738
# x5: 0.0
# expected return (MAD): 0.0008426040045172338
# Mean Absolute Deviation (MAD): 0.0069081037080964145

# %% [markdown]
# # Efficient frontier
#
# Let us use model 1B to compute the efficient frontier

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods

m0_array = np.linspace(0.0,0.01,50)
risk_array = 0. * m0_array
i = 0
for i in range(len(m0_array)):

  # Define the data
  n = len(assets)  # Number of assets
  T = len(R[:,0])  # Number of time periods
  r0 = m0_array[i]

  # Create a LP problem
  prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

  # Define decision variables
  x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
  y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

  # Define objective function
  prob +=  - (1/T) * lpSum(y[t] for t in range(T)), "Objective"

  # Define constraints
  for t in range(T):
      prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
      prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

  prob += lpSum(r[j] * x[j] for j in range(n)) == r0

  prob += lpSum(x) == 1, "Sum_of_weights"

  # Solve the problem
  prob.solve()
  risk_array[i] = value( (1/T) * lpSum(y[t] for t in range(T)))

print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6675d3f1030343fdaed1f01ff4c19379-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6675d3f1030343fdaed1f01ff4c19379-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 0.23597217 (1)
# 37  Obj -0.0011484339 Primal inf 121.07596 (233)
# 89  Obj -0.003049293 Primal inf 212.12522 (230)
# 138  Obj -0.0051214179 Primal inf 116.57345 (187)
# 188  Obj -0.0064716322 Primal inf 430.02488 (218)
# 240  Obj -0.0073815711 Primal inf 27.454401 (104)
# 320  Obj -0.032771274 Primal inf 285.90153 (151)
# 376  Obj -0.053072121 Primal inf 21.981084 (39)
# Primal infeasible - objective value -0.053072121
# PrimalInfeasible objective -0.05307212141 - 376 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/884bdbbc85314621b91def670e0c9709-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/884bdbbc85314621b91def670e0c9709-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.34304424 (2)
# 39  Obj -0.0011238092 Primal inf 93.850504 (220)
# 88  Obj -0.0027524757 Primal inf 82.046181 (206)
# 136  Obj -0.004519645 Primal inf 491.17634 (200)
# 185  Obj -0.0059458844 Primal inf 126.93116 (181)
# 232  Obj -0.006752654 Primal inf 103.95748 (179)
# 271  Obj -0.0071244155 Primal inf 0.026237361 (4)
# 305  Obj -0.007425041
# Optimal - objective value -0.0073655994
# After Postsolve, objective -0.0073655994, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.007365599412 - 305 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/fa9849a8d7a643398d91969841ee7305-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/fa9849a8d7a643398d91969841ee7305-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.45011821 (2)
# 31  Obj -0.00086320919 Primal inf 74.855007 (232)
# 82  Obj -0.0022024618 Primal inf 157.62433 (214)
# 134  Obj -0.0036465802 Primal inf 64.127747 (180)
# 185  Obj -0.0053503191 Primal inf 40.373992 (146)
# 232  Obj -0.0064214303 Primal inf 25.244363 (97)
# 279  Obj -0.0068753333
# Optimal - objective value -0.0068197625
# After Postsolve, objective -0.0068197625, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006819762511 - 279 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/451a20eedcf245169e85918be98d4a17-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/451a20eedcf245169e85918be98d4a17-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.55719218 (2)
# 42  Obj -0.0007842586 Primal inf 555.05113 (227)
# 90  Obj -0.0021556595 Primal inf 43.119191 (198)
# 137  Obj -0.0034425888 Primal inf 512.63965 (225)
# 185  Obj -0.0049106846 Primal inf 154.58125 (187)
# 227  Obj -0.0060864201 Primal inf 65.967804 (150)
# 278  Obj -0.0068107923 Primal inf 0.96774112 (22)
# 290  Obj -0.006829519
# Optimal - objective value -0.006774625
# After Postsolve, objective -0.006774625, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006774625037 - 290 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d613f42e4d6b473c92ac359a04c4ff3f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/d613f42e4d6b473c92ac359a04c4ff3f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.66426615 (2)
# 45  Obj -0.00092359115 Primal inf 76.098809 (231)
# 92  Obj -0.0022588938 Primal inf 292.05516 (221)
# 138  Obj -0.0038318564 Primal inf 42.11589 (166)
# 188  Obj -0.005154683 Primal inf 213.25384 (202)
# 237  Obj -0.0064651005 Primal inf 13.317747 (86)
# 285  Obj -0.0069394292
# Optimal - objective value -0.0068848085
# After Postsolve, objective -0.0068848085, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006884808488 - 285 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/93db8324bf4d41d0b3bec4f6b8e2b365-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/93db8324bf4d41d0b3bec4f6b8e2b365-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.77134012 (2)
# 45  Obj -0.0011695473 Primal inf 104.85571 (233)
# 92  Obj -0.0025881633 Primal inf 192.94825 (220)
# 139  Obj -0.0041617587 Primal inf 143.21874 (210)
# 189  Obj -0.0056267685 Primal inf 48.22259 (144)
# 238  Obj -0.0068477863 Primal inf 17.869506 (98)
# 283  Obj -0.00723065
# Optimal - objective value -0.0071742502
# After Postsolve, objective -0.0071742502, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.007174250249 - 283 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c2f7b2304ce34f0ea6d92bc5776c16d4-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c2f7b2304ce34f0ea6d92bc5776c16d4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.87841409 (2)
# 45  Obj -0.0014034568 Primal inf 125.89434 (233)
# 92  Obj -0.0027373277 Primal inf 73.215413 (176)
# 140  Obj -0.0042858248 Primal inf 431.11439 (206)
# 186  Obj -0.0058076311 Primal inf 36.894048 (148)
# 251  Obj -0.0075230036 Primal inf 12.723443 (73)
# 281  Obj -0.0076816412
# 281  Obj -0.0076221876 Dual inf 6.8738053e-08 (1)
# Optimal - objective value -0.0076221876
# After Postsolve, objective -0.0076221876, infeasibilities - dual 2.861871e-05 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.0076221876 Dual inf 9.6873805e-07 (1)
# 1  Obj -0.007622164
# Optimal - objective value -0.007622164
# Optimal objective -0.007622164029 - 282 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0eeea62d62554a80a478df85fa180e3a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/0eeea62d62554a80a478df85fa180e3a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.98548806 (2)
# 45  Obj -0.0016373663 Primal inf 146.93297 (233)
# 92  Obj -0.003193549 Primal inf 85.378682 (176)
# 136  Obj -0.0047233389 Primal inf 48.02367 (165)
# 179  Obj -0.0059182467 Primal inf 35.682833 (139)
# 226  Obj -0.007128058 Primal inf 4.5002482 (48)
# 279  Obj -0.0082664919
# 279  Obj -0.0082023258 Dual inf 2.357048e-06 (1)
# Optimal - objective value -0.0082023258
# After Postsolve, objective -0.0082023258, infeasibilities - dual 0.00018623769 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.0082023258 Dual inf 3.257048e-06 (1)
# 1  Obj -0.0082022123
# Optimal - objective value -0.0082022123
# Optimal objective -0.008202212343 - 280 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/58ee4e77af3c43f99f233cfb8a6128d5-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/58ee4e77af3c43f99f233cfb8a6128d5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.092562 (2)
# 45  Obj -0.0018712757 Primal inf 167.97159 (233)
# 92  Obj -0.0036497703 Primal inf 97.541952 (176)
# 136  Obj -0.0053981016 Primal inf 54.850507 (165)
# 179  Obj -0.0067637105 Primal inf 40.748131 (139)
# 226  Obj -0.008146352 Primal inf 5.1094373 (48)
# 274  Obj -0.0089855028
# Optimal - objective value -0.0089140437
# After Postsolve, objective -0.0089140437, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00891404365 - 274 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5f3f451ed593425aace14996cb21a28f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/5f3f451ed593425aace14996cb21a28f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.199636 (2)
# 45  Obj -0.0021051852 Primal inf 189.01022 (233)
# 92  Obj -0.0041059916 Primal inf 109.70522 (176)
# 136  Obj -0.0060728643 Primal inf 61.677345 (165)
# 179  Obj -0.0076091743 Primal inf 45.813428 (139)
# 226  Obj -0.009164646 Primal inf 5.7186265 (48)
# 271  Obj -0.0097698565
# Optimal - objective value -0.0096907418
# After Postsolve, objective -0.0096907418, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.009690741798 - 271 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/443da79885bb43ce9090774e93299ef0-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/443da79885bb43ce9090774e93299ef0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.30671 (2)
# 45  Obj -0.0022855539 Primal inf 99.637683 (217)
# 93  Obj -0.0045326524 Primal inf 152.0486 (210)
# 139  Obj -0.0066773613 Primal inf 229.12863 (209)
# 181  Obj -0.0085368162 Primal inf 93.19315 (178)
# 227  Obj -0.01023553 Primal inf 15.194563 (82)
# 267  Obj -0.010619605
# 267  Obj -0.010533641 Dual inf 3.8220877e-06 (1)
# Optimal - objective value -0.010533641
# After Postsolve, objective -0.010533641, infeasibilities - dual 4.4504258e-05 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.010533641 Dual inf 4.7220877e-06 (1)
# 1  Obj -0.010533326
# Optimal - objective value -0.010533326
# Optimal objective -0.01053332594 - 268 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d4ce7e5201b04d8c8462abaff7d119b6-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/d4ce7e5201b04d8c8462abaff7d119b6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.4137839 (2)
# 46  Obj -0.0025009273 Primal inf 264.62131 (225)
# 94  Obj -0.0050348556 Primal inf 294.76258 (208)
# 143  Obj -0.0074686206 Primal inf 309.04019 (211)
# 183  Obj -0.0099103266 Primal inf 351.45514 (202)
# 230  Obj -0.011384527 Primal inf 165.61986 (170)
# 265  Obj -0.011729109
# 265  Obj -0.011635794 Dual inf 1.7176905e-06 (1)
# Optimal - objective value -0.011635794
# After Postsolve, objective -0.011635794, infeasibilities - dual 0.00017787644 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.011635794 Dual inf 2.6176905e-06 (1)
# 1  Obj -0.011635767
# Optimal - objective value -0.011635767
# Optimal objective -0.01163576658 - 266 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4a4004045f7d4469880088811c4213d3-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4a4004045f7d4469880088811c4213d3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.5208579 (2)
# 47  Obj -0.0028998053 Primal inf 227.39129 (218)
# 94  Obj -0.0055239703 Primal inf 76.495467 (182)
# 140  Obj -0.0084780425 Primal inf 208.71762 (196)
# 180  Obj -0.01055742 Primal inf 34.674261 (127)
# 224  Obj -0.012367735 Primal inf 67.01702 (127)
# 276  Obj -0.013167824 Primal inf 0.56218441 (18)
# 287  Obj -0.01321589
# Optimal - objective value -0.013112215
# After Postsolve, objective -0.013112215, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.01311221475 - 287 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5196be913b5c4eb99d8244ba3b60eca3-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/5196be913b5c4eb99d8244ba3b60eca3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.6279319 (2)
# 47  Obj -0.0031414557 Primal inf 246.32179 (218)
# 94  Obj -0.0059843011 Primal inf 82.876893 (182)
# 140  Obj -0.0091845461 Primal inf 226.17184 (196)
# 180  Obj -0.011437204 Primal inf 37.595782 (127)
# 224  Obj -0.013398379 Primal inf 72.633771 (127)
# 277  Obj -0.014735471 Primal inf 27.017724 (72)
# 298  Obj -0.015173568 Primal inf 0.00011296042 (1)
# 298  Obj -0 Primal inf 0.00011296042 (1)
# Primal infeasible - objective value -0
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.015053042, infeasibilities - dual 0.9999749 (251), primal 0.00084753275 (1)
# Perturbing problem by 1e-08% of 0.027447072 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.015053042 Primal inf 0.00011386042 (1)
# 0  Obj -0 Primal inf 0.00011386042 (1)
# Primal infeasible - objective value -0
# PrimalInfeasible objective -0 - 298 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c62b43edb3bd4134adee8660409fe4bf-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c62b43edb3bd4134adee8660409fe4bf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.7350059 (2)
# 45  Obj -0.0032450714 Primal inf 766.24138 (237)
# 92  Obj -0.006615048 Primal inf 134.29562 (202)
# 137  Obj -0.009859606 Primal inf 327.81086 (209)
# 181  Obj -0.012576996 Primal inf 204.03673 (178)
# 228  Obj -0.014359356 Primal inf 5.0522642 (39)
# 286  Obj -0.017028204 Primal inf 13.473131 (41)
# 295  Obj -0.01730368 Primal inf 4.4355741 (24)
# Primal infeasible - objective value -0.01730368
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.017163199, infeasibilities - dual 0.0099304024 (192), primal 0.28653239 (25)
# Perturbing problem by 1e-08% of 0.027447072 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.017163199 Primal inf 4.4439222 (25)
# 7  Obj -0.017293449 Primal inf 0.61086017 (15)
# Primal infeasible - objective value -0.017293449
# PrimalInfeasible objective -0.01729344887 - 302 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7ccb0b504f024ba7a4ff266bf339ec4d-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/7ccb0b504f024ba7a4ff266bf339ec4d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.8420798 (2)
# 43  Obj -0.0033705311 Primal inf 338.08564 (233)
# 87  Obj -0.0064393144 Primal inf 853.53595 (216)
# 133  Obj -0.0098537844 Primal inf 328.26266 (209)
# 177  Obj -0.013151747 Primal inf 390.75065 (177)
# 223  Obj -0.015228583 Primal inf 120.16765 (128)
# 274  Obj -0.017964315 Primal inf 28.319349 (77)
# 291  Obj -0.019258197 Primal inf 14.493974 (46)
# Primal infeasible - objective value -0.019258197
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.019099681, infeasibilities - dual 0.0092538062 (183), primal 0.72593936 (51)
# Perturbing problem by 1e-08% of 0.027447072 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.019099681 Primal inf 15.452983 (51)
# 17  Obj -0.019463298 Primal inf 9.4989981 (35)
# Primal infeasible - objective value -0.019463298
# PrimalInfeasible objective -0.01946329766 - 308 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/dff7496881674b6f994db9626758d8d4-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/dff7496881674b6f994db9626758d8d4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.9491538 (2)
# 43  Obj -0.0035952331 Primal inf 360.64718 (233)
# 87  Obj -0.006868602 Primal inf 910.43248 (216)
# 133  Obj -0.010510703 Primal inf 350.17919 (209)
# 177  Obj -0.01402853 Primal inf 416.79236 (177)
# 223  Obj -0.016243821 Primal inf 128.21182 (128)
# 273  Obj -0.019617252 Primal inf 152.61445 (113)
# 286  Obj -0.032174038 Primal inf 2829.3948 (191)
# Primal infeasible - objective value -0.032174038
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.032198115, infeasibilities - dual 0.0060193831 (118), primal 129.5127 (223)
# Perturbing problem by 1e-08% of 0.027447072 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.054863062 Primal inf 10158.394 (235) Dual inf 0.20435566 (1)
# 0  Obj -0.054863062 Primal inf 10158.394 (235) Dual inf 6.1803178e+14 (118)
# 67  Obj -0.022535508 Primal inf 0.089793958 (1)
# Primal infeasible - objective value -0.022535508
# PrimalInfeasible objective -0.02253550831 - 353 iterations time 0.022, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e4adbb5eb3554671bcde0868646a932d-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/e4adbb5eb3554671bcde0868646a932d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 2.0562278 (2)
# 43  Obj -0.0038199352 Primal inf 383.20872 (233)
# 87  Obj -0.0072978896 Primal inf 967.32902 (216)
# 133  Obj -0.011167622 Primal inf 372.09572 (209)
# 177  Obj -0.014905313 Primal inf 442.83408 (177)
# 223  Obj -0.01725906 Primal inf 136.25599 (128)
# 272  Obj -0.021221386 Primal inf 196.18981 (120)
# 283  Obj -0.036988317 Primal inf 4009.223 (193)
# Primal infeasible - objective value -0.036988317
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.037109441, infeasibilities - dual 0.0059741166 (117), primal 182.62875 (225)
# Perturbing problem by 1e-08% of 0.027447072 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.058128458 Primal inf 11582.078 (237) Dual inf 0.1895148 (1)
# 0  Obj -0.058128458 Primal inf 11582.078 (237) Dual inf 6.2132156e+14 (119)
# 76  Obj -0.025361288 Primal inf 0.11968732 (1)
# Primal infeasible - objective value -0.025361288
# PrimalInfeasible objective -0.0253612878 - 359 iterations time 0.022, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/299f7e161d994065b8034a243fe113ba-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/299f7e161d994065b8034a243fe113ba-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 2.1633017 (2)
# 43  Obj -0.0040116622 Primal inf 495.73157 (215)
# 90  Obj -0.0082876003 Primal inf 2016.3357 (199)
# 133  Obj -0.011465848 Primal inf 74.379034 (140)
# 182  Obj -0.015865705 Primal inf 136.41725 (156)
# 227  Obj -0.018405419 Primal inf 45.638511 (108)
# 276  Obj -0.10128048 Primal inf 4958.3064 (182)
# Primal infeasible - objective value -0.10128048
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.10117818, infeasibilities - dual 0.0063480097 (123), primal 213.49865 (215)
# Perturbing problem by 1e-08% of 0.027447072 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.18696959 Primal inf 12499.735 (225) Dual inf 0.77354782 (1)
# 0  Obj -0.18696959 Primal inf 12499.735 (225) Dual inf 5.9971838e+14 (113)
# 88  Obj -0.028264226 Primal inf 0.14958069 (1)
# Primal infeasible - objective value -0.028264226
# PrimalInfeasible objective -0.02826422626 - 364 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/929c3347d686446a8995d3f397c87cb4-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/929c3347d686446a8995d3f397c87cb4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 4.987799e-05 ( 7.1574468%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 2.2703757 (2)
# 43  Obj -0.0040723256 Primal inf 1778.1691 (241)
# 91  Obj -0.0083319719 Primal inf 247.72019 (189)
# 132  Obj -0.012045405 Primal inf 590.18982 (211)
# 180  Obj -0.016696451 Primal inf 93.847276 (114)
# 226  Obj -0.019272141 Primal inf 8.394847 (44)
# 278  Obj -0.10132474 Primal inf 6436.1156 (188)
# 281  Obj -0.12806754 Primal inf 6077.0458 (182)
# Primal infeasible - objective value -0.12806754
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.12800309, infeasibilities - dual 0.0063281073 (123), primal 258.49759 (215)
# Perturbing problem by 1e-08% of 0.027447072 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.22182748 Primal inf 13824.656 (221) Dual inf 0.84597878 (1)
# 0  Obj -0.22182748 Primal inf 13824.656 (221) Dual inf 5.9965524e+14 (111)
# 88  Obj -0.032377082 Primal inf 0.23154493 (1) Dual inf 7.0876435e+08 (1)
# 96  Obj -0.03121888 Primal inf 0.17947406 (1)
# Primal infeasible - objective value -0.03121888
# PrimalInfeasible objective -0.03121888027 - 377 iterations time 0.022, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/35a6aa955bde4bc0957f0be8bdaba91d-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/35a6aa955bde4bc0957f0be8bdaba91d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 8 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 2.3774515 (2)
# 35  Obj -0.0039004459 Primal inf 545.58473 (232)
# 78  Obj -0.0075862309 Primal inf 206.25056 (210)
# 123  Obj -0.01190735 Primal inf 465.20677 (226)
# 172  Obj -0.017236923 Primal inf 1296.3823 (239)
# 221  Obj -0.020130647 Primal inf 74.194077 (120)
# 282  Obj -0.028242372 Primal inf 117.48935 (113)
# 292  Obj -0.029854625 Primal inf 61.679044 (91)
# Primal infeasible - objective value -0.029854625
# PrimalInfeasible objective -0.02985462509 - 292 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5b1eaee1f0334ce5941b7195457d6ec9-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/5b1eaee1f0334ce5941b7195457d6ec9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 2.4845254 (2)
# 35  Obj -0.0040954681 Primal inf 572.87577 (232)
# 78  Obj -0.0079655425 Primal inf 216.55129 (210)
# 123  Obj -0.012502717 Primal inf 488.45531 (226)
# 172  Obj -0.018098769 Primal inf 1361.2132 (239)
# 221  Obj -0.021137179 Primal inf 77.91558 (120)
# 283  Obj -0.03087435 Primal inf 126.80179 (112)
# 290  Obj -0.031953102 Primal inf 72.654077 (100)
# Primal infeasible - objective value -0.031953102
# PrimalInfeasible objective -0.03195310244 - 290 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/05e90687d64e4f409463926a27862ad6-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/05e90687d64e4f409463926a27862ad6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 2.5915994 (2)
# 35  Obj -0.0042904904 Primal inf 600.1668 (232)
# 78  Obj -0.008344854 Primal inf 226.85202 (210)
# 123  Obj -0.013098085 Primal inf 511.70385 (226)
# 172  Obj -0.018960615 Primal inf 1426.0441 (239)
# 221  Obj -0.022143711 Primal inf 81.637083 (120)
# 285  Obj -0.033200282 Primal inf 102.89564 (112)
# 291  Obj -0.034066929 Primal inf 83.851401 (100)
# Primal infeasible - objective value -0.034066929
# PrimalInfeasible objective -0.03406692914 - 291 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/af9934964a3542dd80cf078eb3c5e143-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/af9934964a3542dd80cf078eb3c5e143-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 2.6986734 (2)
# 35  Obj -0.0044855127 Primal inf 627.45784 (232)
# 78  Obj -0.0087241656 Primal inf 237.15275 (210)
# 123  Obj -0.013693452 Primal inf 534.95239 (226)
# 172  Obj -0.019822461 Primal inf 1490.8751 (239)
# 221  Obj -0.023150244 Primal inf 85.358586 (120)
# 286  Obj -0.035284924 Primal inf 114.29302 (110)
# 291  Obj -0.036180756 Primal inf 95.048725 (100)
# Primal infeasible - objective value -0.036180756
# PrimalInfeasible objective -0.03618075585 - 291 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/25a61eab9a444766bb32739e8b4858d8-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/25a61eab9a444766bb32739e8b4858d8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 2.8057474 (2)
# 35  Obj -0.004680535 Primal inf 654.74887 (232)
# 78  Obj -0.0091034771 Primal inf 247.45348 (210)
# 123  Obj -0.01428882 Primal inf 558.20093 (226)
# 172  Obj -0.020684307 Primal inf 1555.706 (239)
# 221  Obj -0.024156776 Primal inf 89.080089 (120)
# 286  Obj -0.037797797 Primal inf 118.30087 (106)
# 288  Obj -0.038261524 Primal inf 106.27432 (102)
# Primal infeasible - objective value -0.038261524
# PrimalInfeasible objective -0.03826152446 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ce5ce54e0b3c42738a13607639991a62-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/ce5ce54e0b3c42738a13607639991a62-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 2.9128213 (2)
# 35  Obj -0.0048755573 Primal inf 682.03991 (232)
# 78  Obj -0.0094827887 Primal inf 257.75421 (210)
# 123  Obj -0.014884187 Primal inf 581.44947 (226)
# 172  Obj -0.021546153 Primal inf 1620.5369 (239)
# 221  Obj -0.025163308 Primal inf 92.801592 (120)
# 286  Obj -0.039872969 Primal inf 130.60522 (106)
# 288  Obj -0.040378349 Primal inf 117.49763 (102)
# Primal infeasible - objective value -0.040378349
# PrimalInfeasible objective -0.04037834878 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3e7109d2527b4d0cba972bb15dab1e24-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/3e7109d2527b4d0cba972bb15dab1e24-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 3.0198953 (2)
# 35  Obj -0.0050705796 Primal inf 709.33095 (232)
# 78  Obj -0.0098621002 Primal inf 268.05494 (210)
# 123  Obj -0.015479555 Primal inf 604.69801 (226)
# 172  Obj -0.022407999 Primal inf 1685.3678 (239)
# 221  Obj -0.026169841 Primal inf 96.523095 (120)
# 286  Obj -0.04194814 Primal inf 142.90958 (106)
# 288  Obj -0.042495173 Primal inf 128.72093 (102)
# Primal infeasible - objective value -0.042495173
# PrimalInfeasible objective -0.0424951731 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c4467e9207e8425999f5259bcb9fdd45-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c4467e9207e8425999f5259bcb9fdd45-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 3.1269693 (2)
# 35  Obj -0.0052656019 Primal inf 736.62198 (232)
# 78  Obj -0.010241412 Primal inf 278.35568 (210)
# 123  Obj -0.016074922 Primal inf 627.94655 (226)
# 172  Obj -0.023269846 Primal inf 1750.1987 (239)
# 221  Obj -0.027176373 Primal inf 100.2446 (120)
# 286  Obj -0.044023311 Primal inf 155.21393 (106)
# 288  Obj -0.044611997 Primal inf 139.94423 (102)
# Primal infeasible - objective value -0.044611997
# PrimalInfeasible objective -0.04461199741 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1152036d77964dc9920c22b262399a12-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1152036d77964dc9920c22b262399a12-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# ...
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 4.5189309 (2)
# 35  Obj -0.0078008917 Primal inf 1091.4055 (232)
# 78  Obj -0.015172462 Primal inf 412.26517 (210)
# 123  Obj -0.023814699 Primal inf 930.17759 (226)
# 172  Obj -0.034473845 Primal inf 2593.0006 (239)
# 221  Obj -0.040261294 Primal inf 148.62414 (120)
# 281  Obj -0.068328401 Primal inf 492.69168 (142)
# 289  Obj -0.073103856 Primal inf 281.92613 (112)
# Primal infeasible - objective value -0.073103856
# PrimalInfeasible objective -0.07310385611 - 289 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/bfe8caf8829d4309802259b2707b5b6b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/bfe8caf8829d4309802259b2707b5b6b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 4.6260048 (2)
# 35  Obj -0.007995914 Primal inf 1118.6965 (232)
# 78  Obj -0.015551773 Primal inf 422.5659 (210)
# 123  Obj -0.024410067 Primal inf 953.42613 (226)
# 172  Obj -0.035335691 Primal inf 2657.8315 (239)
# 221  Obj -0.041267826 Primal inf 152.34564 (120)
# 281  Obj -0.070305406 Primal inf 512.07335 (142)
# 289  Obj -0.075255571 Primal inf 293.21955 (112)
# Primal infeasible - objective value -0.075255571
# PrimalInfeasible objective -0.07525557083 - 289 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/bfda22eb5bc04f87a7808008266454c0-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/bfda22eb5bc04f87a7808008266454c0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 4.7330788 (2)
# 35  Obj -0.0081909363 Primal inf 1145.9875 (232)
# 78  Obj -0.015931085 Primal inf 432.86663 (210)
# 123  Obj -0.025005434 Primal inf 976.67467 (226)
# 172  Obj -0.036197538 Primal inf 2722.6624 (239)
# 221  Obj -0.042274358 Primal inf 156.06714 (120)
# 281  Obj -0.073491278 Primal inf 523.52957 (139)
# 288  Obj -0.077326306 Primal inf 305.0399 (113)
# Primal infeasible - objective value -0.077326306
# PrimalInfeasible objective -0.07732630566 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/cca9e430f49f4ec6a0ea2f170f04c214-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/cca9e430f49f4ec6a0ea2f170f04c214-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 4.8401528 (2)
# 35  Obj -0.0083859586 Primal inf 1173.2786 (232)
# 78  Obj -0.016310397 Primal inf 443.16736 (210)
# 123  Obj -0.025600802 Primal inf 999.92321 (226)
# 172  Obj -0.037059384 Primal inf 2787.4934 (239)
# 221  Obj -0.043280891 Primal inf 159.78865 (120)
# 281  Obj -0.075509358 Primal inf 542.64192 (139)
# 288  Obj -0.079475402 Primal inf 316.36884 (115)
# Primal infeasible - objective value -0.079475402
# PrimalInfeasible objective -0.07947540155 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7526759893a04043953f5f7350a989a2-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/7526759893a04043953f5f7350a989a2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 4.9472268 (2)
# 35  Obj -0.0085809809 Primal inf 1200.5696 (232)
# 78  Obj -0.016689708 Primal inf 453.46809 (210)
# 123  Obj -0.026196169 Primal inf 1023.1718 (226)
# 172  Obj -0.03792123 Primal inf 2852.3243 (239)
# 221  Obj -0.044287423 Primal inf 163.51015 (120)
# 281  Obj -0.077527438 Primal inf 561.75427 (139)
# 288  Obj -0.081624497 Primal inf 327.70136 (115)
# Primal infeasible - objective value -0.081624497
# PrimalInfeasible objective -0.08162449743 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/8e6799d04db34e729df3928278211046-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/8e6799d04db34e729df3928278211046-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 5.0543007 (2)
# 35  Obj -0.0087760032 Primal inf 1227.8606 (232)
# 78  Obj -0.01706902 Primal inf 463.76882 (210)
# 123  Obj -0.026791537 Primal inf 1046.4203 (226)
# 172  Obj -0.038783076 Primal inf 2917.1552 (239)
# 221  Obj -0.045293955 Primal inf 167.23165 (120)
# 281  Obj -0.079545519 Primal inf 580.86794 (141)
# 288  Obj -0.083773593 Primal inf 339.03387 (115)
# Primal infeasible - objective value -0.083773593
# PrimalInfeasible objective -0.08377359332 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/266fe953733942468c5e8f34d9d2b356-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/266fe953733942468c5e8f34d9d2b356-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 5.1613747 (2)
# 35  Obj -0.0089710255 Primal inf 1255.1517 (232)
# 78  Obj -0.017448331 Primal inf 474.06956 (210)
# 123  Obj -0.027386904 Primal inf 1069.6688 (226)
# 172  Obj -0.039644922 Primal inf 2981.9861 (239)
# 221  Obj -0.046300488 Primal inf 170.95316 (120)
# 281  Obj -0.081563599 Primal inf 600.00837 (143)
# 288  Obj -0.085922689 Primal inf 350.36639 (115)
# Primal infeasible - objective value -0.085922689
# PrimalInfeasible objective -0.08592268921 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b266f7f16cde4f4f94728f28a5d0e47f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b266f7f16cde4f4f94728f28a5d0e47f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 5.2684487 (2)
# 35  Obj -0.0091660478 Primal inf 1282.4427 (232)
# 78  Obj -0.017827643 Primal inf 484.37029 (210)
# 123  Obj -0.027982272 Primal inf 1092.9174 (226)
# 172  Obj -0.040506768 Primal inf 3046.817 (239)
# 221  Obj -0.04730702 Primal inf 174.67466 (120)
# 281  Obj -0.083581679 Primal inf 619.15441 (145)
# 288  Obj -0.088071785 Primal inf 361.69891 (115)
# Primal infeasible - objective value -0.088071785
# PrimalInfeasible objective -0.0880717851 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f59a3a133d7f4786a6095a447aaf4d99-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/f59a3a133d7f4786a6095a447aaf4d99-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 5.3755226 (2)
# 35  Obj -0.00936107 Primal inf 1309.7337 (232)
# 78  Obj -0.018206954 Primal inf 494.67102 (210)
# 123  Obj -0.028577639 Primal inf 1116.1659 (226)
# 172  Obj -0.041368614 Primal inf 3111.6479 (239)
# 221  Obj -0.048313552 Primal inf 178.39616 (120)
# 281  Obj -0.08559976 Primal inf 638.30839 (145)
# 288  Obj -0.090220881 Primal inf 373.03142 (115)
# Primal infeasible - objective value -0.090220881
# PrimalInfeasible objective -0.09022088099 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/2bf2a2d309544e2c9c2cf7448a835e3a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/2bf2a2d309544e2c9c2cf7448a835e3a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027447072 - largest nonzero change 5.0242083e-06 ( 0.71795712%) - largest zero change 4.2503974e-06
# 0  Obj -0 Primal inf 5.4825966 (2)
# 35  Obj -0.0095560923 Primal inf 1337.0248 (232)
# 78  Obj -0.018586266 Primal inf 504.97175 (210)
# 123  Obj -0.029173007 Primal inf 1139.4145 (226)
# 172  Obj -0.04223046 Primal inf 3176.4788 (239)
# 221  Obj -0.049320085 Primal inf 182.11766 (120)
# 281  Obj -0.08761784 Primal inf 657.46237 (145)
# 288  Obj -0.092369977 Primal inf 384.36394 (115)
# Primal infeasible - objective value -0.092369977
# PrimalInfeasible objective -0.09236997688 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Status: Infeasible
# Optimal Portfolio Weights:
# x0: 0.0
# x1: 0.0
# x2: -8.0052887
# x3: 9.0052887
# x4: 0.0
# x5: 0.0
# expected return (MAD): 0.010000000032722714
# Mean Absolute Deviation (MAD): 0.09227463688764942

# %%
plt.figure()
plt.plot(m0_array, risk_array)

# %% [markdown]
# # Now we consider risk as total variance of the portfolio, all these models are model 2x

# %% [markdown]
# # model 2A
# when we minimize variance under a specified expected return $r_0$
# $$
# \begin{gathered}
# \operatorname{maximize} -\frac{1}{T} \sum_{t=1}^T\left(\sum_j x_j\left(R_j(t)-r_j\right)\right)^2 \\
# \text { subject to } \sum_j x_j=1 \\
#   \sum_j x_j r_j = r_0 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$

# %%
# centered return
R_c = 0. * R
for j in range(len(R[0,:])):
  R_c[:,j] = R[:,j] - r[j]

#print(np.outer(R_c[0,:],R_c[0,:]))
R_c.T @ R_c

# compute the convariance matrix manually
sig = 0. * S
for i in range(len(R[:,0])):
  sig = sig + np.outer(R_c[i,:],R_c[i,:])
sig = sig / T


r0 = 0.0005
n = len(R[0,:])
e = np.ones((n,1))
rq = r.reshape(n,1)

X = cp.Variable((n,1))
Objective = cp.Minimize(cp.quad_form(X,sig))
constraints = [e.T@X == 1, X >= 0, rq.T@X >= r0]
problem = cp.Problem(Objective,constraints)

result = problem.solve()

print("expected portfolio", X.value.T)
print("expected return :", (rq.T @ X.value)[0] )
print("Mean variance:", (X.value.T @ sig @ X.value)[0] )
X
# Out:
# expected portfolio [[ 2.58228362e-01  4.82485975e-01  1.74083906e-01  1.68322542e-02
#    6.83695031e-02 -2.82602548e-19]]
# expected return : [0.00062784]
# Mean variance: [8.1580533e-05]
# Variable((6, 1), var121)

# %% [markdown]
# ## Optimization Problem
#
# Choose a risk tolerance $q > 0$:
#
# \begin{align*}
# \text{minimize:} \ \ & \mathbf{x}^T \Sigma \mathbf{x} - q \mathbf{r}^T \mathbf{x} \\
# \text{subject to:} \ \ & \mathbf{e}^T \mathbf{x} = 1 \\
# & \mathbf{x} \geq 0 \\
# \end{align*}

# %%
n = len(assets)
q = 0.1
e = np.ones(n)
X = cp.Variable(n)

obj = cp.Minimize(cp.quad_form(X,S) - q*r@X)
constraints = [e@X == 1, X >= 0]
problem = cp.Problem(obj,constraints)

result = problem.solve()
X.value
# Out:
# array([7.67131792e-23, 1.81513043e-01, 4.26124245e-01, 1.87604641e-01,
#        2.04758072e-01, 4.45852952e-24])

# %% [markdown]
# ## Optimization Problem
#
# \begin{align*}
# \text{minimize:} \ \ & \mathbf{x}^T \Sigma \mathbf{x} \\
# \text{subject to:} \ \ & \mathbf{e}^T \mathbf{x} = 1 \\
# & \mathbf{r}^T \mathbf{x} = \mu \\
# & \mathbf{x} \geq 0 \\
# \end{align*}

# %% [markdown]
# case mu = 0.01,   minimize risk sigma = 0.001
#
# case mu = 0.02,  minimize risk sigma = 0.003
#
# case mu = 0.05,  minimize risk  sigma = 0.010

# %%
n = len(assets)
e = np.ones((n,1))
r = r.reshape(n,1)
mu = 0.001

M = np.block([[2*S,-r,-e],[r.T,0,0],[e.T,0,0]])
b = np.block([[np.zeros((n,1))],[mu],[1]])

x = la.solve(M,b)
