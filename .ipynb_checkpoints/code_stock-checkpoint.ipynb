# %%
# !pip install pulp
# !pip install yfinance
# Out:
# Requirement already satisfied: pulp in /opt/conda/lib/python3.10/site-packages (2.7.0)
# Requirement already satisfied: yfinance in /opt/conda/lib/python3.10/site-packages (0.2.37)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: appdirs>=1.4.4 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2.4.1)
# Requirement already satisfied: pandas>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: peewee>=3.16.2 in /opt/conda/lib/python3.10/site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/conda/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: lxml>=4.9.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: html5lib>=1.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: pytz>=2022.5 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.4)

# %%
# !pip install cvxpy
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
import cvxpy as cp
import scipy.linalg as la
import pulp
# Out:
# Requirement already satisfied: cvxpy in /opt/conda/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: osqp>=0.6.2 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (0.6.5)
# Requirement already satisfied: pybind11 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (2.12.0)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (1.23.5)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (1.10.0)
# Requirement already satisfied: scs>=3.0 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (3.2.4.post1)
# Requirement already satisfied: ecos>=2 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (2.0.13)
# Requirement already satisfied: clarabel>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (0.7.1)
# Requirement already satisfied: qdldl in /opt/conda/lib/python3.10/site-packages (from osqp>=0.6.2->cvxpy) (0.1.7.post1)

# %% [markdown]
# ## how we load data from yahoo finance

# %% [markdown]
# #### Short-term corporate bond data

# %%
T = 1 # Number of days in time period
R1 = []
cor_bonds = ["SCHJ","IGSB","VCSH","SPSB","SLQD","ICSH"]

for bond in cor_bonds:
    data = yf.Ticker(bond)
    # 我先改成1年， 这个之后可以随时改成想要的时段
    bond = data.history(period="1y")

    # close values on that day
    close = bond['Close'].values

    # convert day to day close values to return
    returns = (close[T:] - close[:-T])/close[:-T]
    R1.append(returns)

R1 = np.array(R1).T
r1 = np.mean(R1,axis=0)
S1 = np.cov(R1.T)
R1
# Out:
# array([[ 0.00126159,  0.00099005,  0.00118109,  0.00135285,  0.        ,
#          0.0001994 ],
#        [ 0.00178509,  0.00197776,  0.00196702,  0.00135082,  0.00247676,
#          0.00039833],
#        [-0.00199167, -0.00256613, -0.00222433, -0.00168618, -0.00185298,
#         -0.00019904],
#        ...,
#        [-0.00104   , -0.00117619, -0.00116995, -0.00067471, -0.00081635,
#          0.00019846],
#        [ 0.00110351,  0.00117758,  0.00143155,  0.00101279,  0.00122552,
#          0.00019849],
#        [-0.00546972, -0.0056851 , -0.00571793, -0.00404718, -0.00448799,
#         -0.00059529]])

# %% [markdown]
# #### Stock data

# %%
T = 1 # Number of days in time period
R = []
assets = ["AAPL","EA","MSFT","NFLX","GOOGL","TSLA"]

for stock in assets:
    data = yf.Ticker(stock)
    # 我先改成1年， 这个之后可以随时改成想要的时段
    df = data.history(period="1y")

    # close values on that day
    close = df['Close'].values

    # convert day to day close values to return
    returns = (close[T:] - close[:-T])/close[:-T]
    R.append(returns)

R = np.array(R).T
r = np.mean(R,axis=0)
S = np.cov(R.T)

# %%
R
# Out:
# array([[-0.00435317,  0.00358043,  0.00233358, -0.02122939, -0.00673943,
#         -0.03346004],
#        [ 0.03410361,  0.01704598,  0.02239928,  0.04579646,  0.02666285,
#          0.02968872],
#        [-0.00211396, -0.00319608, -0.01276549, -0.02183771,  0.0134041 ,
#         -0.00484128],
#        ...,
#        [-0.00666355, -0.00222575, -0.00218554, -0.01221356,  0.01540988,
#          0.04899941],
#        [ 0.00724251,  0.00530771,  0.00398032, -0.01624729,  0.01130126,
#          0.02254601],
#        [-0.01113927, -0.01063585, -0.00708452,  0.0006147 , -0.00293746,
#         -0.02894624]])

# %% [markdown]
# ## tesla in past 1 years

# %%
# last df is Tesla
df['Open'].plot()
plt.show()

# %% [markdown]
# ## histogram of Tesla in past 1 years

# %%
return_TSLA = R[:,-1]
plt.hist(return_TSLA,bins=50)
plt.show()

# %%
r
# Out:
# array([0.00026376, 0.0001986 , 0.00173443, 0.00265228, 0.0017161 ,
#        0.00012128])

# %%
S
# Out:
# array([[1.46795002e-04, 4.51282073e-05, 8.14891646e-05, 9.54639620e-05,
#         9.41011540e-05, 1.32531729e-04],
#        [4.51282073e-05, 1.24669261e-04, 3.91243661e-05, 4.06778444e-05,
#         3.81256863e-05, 9.03958042e-05],
#        [8.14891646e-05, 3.91243661e-05, 1.90445007e-04, 1.22598561e-04,
#         9.90207738e-05, 1.07310774e-04],
#        [9.54639620e-05, 4.06778444e-05, 1.22598561e-04, 5.03095045e-04,
#         1.14351464e-04, 1.24975462e-04],
#        [9.41011540e-05, 3.81256863e-05, 9.90207738e-05, 1.14351464e-04,
#         2.93251399e-04, 1.35635291e-04],
#        [1.32531729e-04, 9.03958042e-05, 1.07310774e-04, 1.24975462e-04,
#         1.35635291e-04, 9.08183849e-04]])

# %% [markdown]
# # We consider risk as MAD first, all these models are model 1x

# %% [markdown]
# # model 1A
# when we minimize MAD under a specified expected return $r_0$
# $$
# \begin{gathered}
# \operatorname{maximize} -\frac{1}{T} \sum_{t=1}^T\left|\sum_j x_j\left(R_j(t)-r_j\right)\right| \\
# \text { subject to } \sum_j x_j=1 \\
#   \sum_j x_j r_j = r_0 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$
#
# The LP version is
# $$
# \begin{gathered}
# & \operatorname{maximize} -\frac{1}{T} \sum_{t=1}^T y_t \\
# & \text { subject to }-y_t \leq \sum_j x_j\left(R_j(t)-r_j\right) \leq y_t \quad t=1,2, \ldots, T \text {, } \\
# & \sum_j x_j=1 \\
# &  \sum_j x_j r_j = r_0 \\
# & x_j \geq 0 \quad j=1,2, \ldots, n, \\
# & r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods
r0 = 0.0008
print(n,T,r0)


# Create a LP problem
prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

# Define decision variables
x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

# Define objective function
prob +=  - (1/T) * lpSum(y[t] for t in range(T)), "Objective"

# Define constraints
for t in range(T):
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

prob += lpSum(r[j] * x[j] for j in range(n)) == r0

prob += lpSum(x) == 1, "Sum_of_weights"

# Solve the problem
prob.solve()

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 0.0008
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4a58cc194bb14254a3d3419b2ed2f49c-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4a58cc194bb14254a3d3419b2ed2f49c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.0009054446 Primal inf 76.036306 (231)
# 92  Obj -0.0022363865 Primal inf 80.276853 (212)
# 139  Obj -0.0034727464 Primal inf 172.06444 (199)
# 188  Obj -0.0052859714 Primal inf 43.900277 (159)
# 239  Obj -0.0064476405 Primal inf 35.104354 (108)
# 292  Obj -0.0069253041
# Optimal - objective value -0.0068707645
# After Postsolve, objective -0.0068707645, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764456 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.066354522
# x1: 0.56828414
# x2: 0.23261427
# x3: 0.040996247
# x4: 0.091750826
# x5: 0.0
# expected return (MAD): 0.0008000000060043914
# Mean Absolute Deviation (MAD): 0.006870764454087647

# %% [markdown]
# # model 1B
# when we maximize return under a specified MAD constrait $m_0$
# $$
# \begin{gathered}
# \operatorname{maximize} \sum_j x_j r_j  \\
# \text { subject to } \sum_j x_j=1 \\
#   \frac{1}{T} \sum_{t=1}^T\left|\sum_j x_j\left(R_j(t)-r_j\right)\right| \leq m_0 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$
#
# The LP version is
# $$
# \begin{gathered}
# & \operatorname{maximize}  \sum_j x_j r_j   \\
# & \text { subject to }-y_t \leq \sum_j x_j\left(R_j(t)-r_j\right) \leq y_t \quad t=1,2, \ldots, T \text {, } \\
# & \sum_j x_j=1 \\
# & \frac{1}{T} \sum_{t=1}^T y_t \leq m_0  \\
# & x_j \geq 0 \quad j=1,2, \ldots, n, \\
# & r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods
m0 = 0.007
print(n,T,r0)


# Create a LP problem
prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

# Define decision variables
x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

# Define objective function
prob += lpSum(r[j] * x[j] for j in range(n)), "Objective"

# Define constraints
for t in range(T):
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

prob +=  (1/T) * lpSum(y[t] for t in range(T)) <= m0, "Risk"

prob += lpSum(x) == 1, "Sum_of_weights"

# Solve the problem
prob.solve()

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 0.0008
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1a0645e317a04bd0a558262a644b6645-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1a0645e317a04bd0a558262a644b6645-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3771 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3358 (-413) elements
# Perturbing problem by 0.001% of 0.027958869 - largest nonzero change 0.00012071587 ( 26.772389%) - largest zero change 9.9738226e-05
# 0  Obj -0 Primal inf 11.586553 (2) Dual inf 0.050482856 (6)
# 59  Obj 0.0046719824 Primal inf 114.03069 (207)
# 94  Obj 0.0028145331 Primal inf 454.487 (224)
# 134  Obj 0.0019046061 Primal inf 137.87679 (195)
# 176  Obj 0.0015037611 Primal inf 22.862906 (134)
# 219  Obj 0.0012395913 Primal inf 69.859341 (168)
# 263  Obj 0.0009554946 Primal inf 12.454388 (84)
# 297  Obj 0.00081064965
# Optimal - objective value 0.00091480803
# After Postsolve, objective 0.00091480803, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.0009148080343 - 297 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.027648367
# x1: 0.5411342
# x2: 0.27074487
# x3: 0.058828832
# x4: 0.10164373
# x5: 0.0
# expected return (MAD): 0.0009148080340668202
# Mean Absolute Deviation (MAD): 0.006999999989701195

# %% [markdown]
# ## model 1C
# when combine return and risk together with $\mu$
#
# $$
# \begin{gathered}
# \operatorname{maximize} \mu \sum_j x_j r_j-\frac{1}{T} \sum_{t=1}^T\left|\sum_j x_j\left(R_j(t)-r_j\right)\right| \\
# \text { subject to } \sum_j x_j=1 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$
#
# The LP version is
# $$
# \begin{aligned}
# & \operatorname{maximize} \mu \sum_j x_j r_j-\frac{1}{T} \sum_{t=1}^T y_t \\
# & \text { subject to }-y_t \leq \sum_j x_j\left(R_j(t)-r_j\right) \leq y_t \quad t=1,2, \ldots, T \text {, } \\
# & \sum_j x_j=1 \\
# & x_j \geq 0 \quad j=1,2, \ldots, n \\
# & y_t \geq 0 \quad t=1,2, \ldots, T . \\
# &
# \end{aligned}
# $$
#
# below is pulp implementation

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods
mu = 1
print(n,T,mu)


# Create a LP problem
prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

# Define decision variables
x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

# Define objective function
prob += lpSum(r[j] * x[j] for j in range(n)) * mu - (1/T) * lpSum(y[t] for t in range(T)), "Objective"

# Define constraints
for t in range(T):
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

prob += lpSum(x) == 1, "Sum_of_weights"

# Solve the problem
prob.solve()

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 1
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6e27c2c8cc874182adb2da9ea47d9279-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6e27c2c8cc874182adb2da9ea47d9279-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027958869 - largest nonzero change 8.1754672e-05 ( 24.953907%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050671695 (6)
# 68  Obj -0.0010263212 Primal inf 238.29414 (221)
# 117  Obj -0.0026911223 Primal inf 97.789206 (190)
# 165  Obj -0.0042247256 Primal inf 263.01479 (239)
# 208  Obj -0.0054947305 Primal inf 146.46942 (167)
# 258  Obj -0.0060990492 Primal inf 1.7917948 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655196 Dual inf 0.000364356 (1)
# 273  Obj -0.0060654994
# Optimal - objective value -0.0060654994
# After Postsolve, objective -0.0060654994, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499385 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.049674913
# x1: 0.5656547
# x2: 0.23711884
# x3: 0.056276425
# x4: 0.091275125
# x5: 0.0
# expected return (MAD): 0.000842602294131232
# Mean Absolute Deviation (MAD): 0.006908101662658962

# %% [markdown]
# # Efficient frontier
#
# Let us use model 1B to compute the efficient frontier

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods

m0_array = np.linspace(0.0,0.01,50)
risk_array = 0. * m0_array
i = 0
for i in range(len(m0_array)):

  # Define the data
  n = len(assets)  # Number of assets
  T = len(R[:,0])  # Number of time periods
  r0 = m0_array[i]

  # Create a LP problem
  prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

  # Define decision variables
  x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
  y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

  # Define objective function
  prob +=  - (1/T) * lpSum(y[t] for t in range(T)), "Objective"

  # Define constraints
  for t in range(T):
      prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
      prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

  prob += lpSum(r[j] * x[j] for j in range(n)) == r0

  prob += lpSum(x) == 1, "Sum_of_weights"

  # Solve the problem
  prob.solve()
  risk_array[i] = value( (1/T) * lpSum(y[t] for t in range(T)))

print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/66bd182a95e14ae2b75773e1b3bf05d0-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/66bd182a95e14ae2b75773e1b3bf05d0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 0.23597269 (1)
# 37  Obj -0.0011484348 Primal inf 121.07719 (233)
# 89  Obj -0.0030492872 Primal inf 212.12604 (230)
# 138  Obj -0.0051214186 Primal inf 116.57545 (187)
# 188  Obj -0.0064716061 Primal inf 430.03873 (218)
# 240  Obj -0.007381571 Primal inf 27.454386 (104)
# 320  Obj -0.032771325 Primal inf 285.90637 (151)
# 376  Obj -0.053072233 Primal inf 21.985373 (39)
# Primal infeasible - objective value -0.053072233
# PrimalInfeasible objective -0.05307223274 - 376 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3a47d4fa0ad14bbaa8d9d58377b86e55-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/3a47d4fa0ad14bbaa8d9d58377b86e55-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.34304476 (2)
# 39  Obj -0.0011238081 Primal inf 93.849008 (220)
# 88  Obj -0.0027524798 Primal inf 82.046836 (206)
# 136  Obj -0.0045196714 Primal inf 491.19749 (200)
# 185  Obj -0.005945889 Primal inf 126.93319 (181)
# 232  Obj -0.0067526454 Primal inf 103.9595 (179)
# 271  Obj -0.0071244165 Primal inf 0.026237565 (4)
# 305  Obj -0.007425036
# Optimal - objective value -0.007365593
# After Postsolve, objective -0.007365593, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.007365593047 - 305 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/25490c711ad448c5b6567f29849af389-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/25490c711ad448c5b6567f29849af389-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.45011873 (2)
# 31  Obj -0.0008632093 Primal inf 74.855484 (232)
# 82  Obj -0.0022024623 Primal inf 157.62689 (214)
# 134  Obj -0.0036465835 Primal inf 64.12749 (180)
# 185  Obj -0.0053503179 Primal inf 40.373893 (146)
# 232  Obj -0.0064214299 Primal inf 25.244378 (97)
# 279  Obj -0.0068753335
# Optimal - objective value -0.0068197615
# After Postsolve, objective -0.0068197615, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006819761493 - 279 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f0e71ff4eb1b4d25903017a07fb5b62c-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/f0e71ff4eb1b4d25903017a07fb5b62c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.5571927 (2)
# 42  Obj -0.00078428136 Primal inf 555.05548 (227)
# 90  Obj -0.0021556593 Primal inf 43.120112 (198)
# 138  Obj -0.0035708012 Primal inf 96.970317 (199)
# 189  Obj -0.0053061313 Primal inf 83.283733 (172)
# 238  Obj -0.0062367807 Primal inf 27.105784 (113)
# 286  Obj -0.0068287691
# Optimal - objective value -0.0067746252
# After Postsolve, objective -0.0067746252, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006774625216 - 286 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/2261b05a27d4479e82befd1c567e8d61-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/2261b05a27d4479e82befd1c567e8d61-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.66426667 (2)
# 45  Obj -0.00092359302 Primal inf 76.099525 (231)
# 92  Obj -0.0022588857 Primal inf 292.05262 (221)
# 138  Obj -0.0038318588 Primal inf 42.115686 (166)
# 188  Obj -0.0051546774 Primal inf 213.25664 (202)
# 237  Obj -0.0064651029 Primal inf 13.317718 (86)
# 285  Obj -0.0069394303
# Optimal - objective value -0.0068848081
# After Postsolve, objective -0.0068848081, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006884808104 - 285 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/11cfaec1072e411894ba35f76431fe16-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/11cfaec1072e411894ba35f76431fe16-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.77134064 (2)
# 45  Obj -0.0011695473 Primal inf 104.85777 (233)
# 92  Obj -0.0025881706 Primal inf 192.95014 (220)
# 139  Obj -0.0041617537 Primal inf 143.22075 (210)
# 189  Obj -0.0056267674 Primal inf 48.223339 (144)
# 238  Obj -0.006847789 Primal inf 17.869402 (98)
# 283  Obj -0.0072306508
# Optimal - objective value -0.0071742497
# After Postsolve, objective -0.0071742497, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.007174249727 - 283 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/a4e75e816c754deaa0fd2c159e8d4da9-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/a4e75e816c754deaa0fd2c159e8d4da9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.87841461 (2)
# 45  Obj -0.0014034568 Primal inf 125.89681 (233)
# 92  Obj -0.0027373276 Primal inf 73.217285 (176)
# 140  Obj -0.0042858008 Primal inf 431.11013 (206)
# 186  Obj -0.005807635 Primal inf 36.894563 (148)
# 251  Obj -0.0075230015 Primal inf 12.723375 (73)
# 281  Obj -0.0076816412
# 281  Obj -0.0076221861 Dual inf 7.2197973e-08 (1)
# Optimal - objective value -0.0076221861
# After Postsolve, objective -0.0076221861, infeasibilities - dual 2.8711631e-05 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.0076221861 Dual inf 9.7219797e-07 (1)
# 1  Obj -0.0076221625
# Optimal - objective value -0.0076221625
# Optimal objective -0.007622162487 - 282 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/a9b7477a71274f769a6834510c2def1b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/a9b7477a71274f769a6834510c2def1b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.98548858 (2)
# 45  Obj -0.0016373662 Primal inf 146.93585 (233)
# 92  Obj -0.0031935489 Primal inf 85.380866 (176)
# 136  Obj -0.0047233398 Primal inf 48.02449 (165)
# 179  Obj -0.0059182503 Primal inf 35.682854 (139)
# 226  Obj -0.0071280601 Primal inf 4.5003067 (48)
# 279  Obj -0.0082664924
# 279  Obj -0.0082023247 Dual inf 2.3537461e-06 (1)
# Optimal - objective value -0.0082023247
# After Postsolve, objective -0.0082023247, infeasibilities - dual 0.00018605587 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.0082023247 Dual inf 3.2537461e-06 (1)
# 1  Obj -0.0082022113
# Optimal - objective value -0.0082022113
# Optimal objective -0.008202211329 - 280 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b8e8f064ffef44bcb10dda2c940a0566-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b8e8f064ffef44bcb10dda2c940a0566-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.0925626 (2)
# 45  Obj -0.0018712757 Primal inf 167.97489 (233)
# 92  Obj -0.0036497702 Primal inf 97.544447 (176)
# 136  Obj -0.0053981027 Primal inf 54.851444 (165)
# 179  Obj -0.0067637147 Primal inf 40.748156 (139)
# 226  Obj -0.0081463544 Primal inf 5.1095042 (48)
# 274  Obj -0.0089855025
# Optimal - objective value -0.0089140418
# After Postsolve, objective -0.0089140418, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.008914041817 - 274 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/13fd72686f2b48ffa9351e74d23f511b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/13fd72686f2b48ffa9351e74d23f511b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.1996365 (2)
# 45  Obj -0.0021051852 Primal inf 189.01393 (233)
# 92  Obj -0.0041059914 Primal inf 109.70803 (176)
# 136  Obj -0.0060728655 Primal inf 61.678399 (165)
# 179  Obj -0.007609179 Primal inf 45.813458 (139)
# 226  Obj -0.0091646487 Primal inf 5.7187016 (48)
# 271  Obj -0.0097698565
# Optimal - objective value -0.0096907402
# After Postsolve, objective -0.0096907402, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.009690740191 - 271 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/84d1bf0cb187482e870f29ad077e8e55-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/84d1bf0cb187482e870f29ad077e8e55-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.3067105 (2)
# 45  Obj -0.0022855549 Primal inf 99.638876 (217)
# 93  Obj -0.004532658 Primal inf 152.04866 (210)
# 139  Obj -0.0066773534 Primal inf 229.13326 (209)
# 181  Obj -0.0085368134 Primal inf 93.194903 (178)
# 227  Obj -0.010235528 Primal inf 15.194182 (82)
# 267  Obj -0.010619604
# 267  Obj -0.010533639 Dual inf 3.8200914e-06 (1)
# Optimal - objective value -0.010533639
# After Postsolve, objective -0.010533639, infeasibilities - dual 4.4485713e-05 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.010533639 Dual inf 4.7200914e-06 (1)
# 1  Obj -0.010533324
# Optimal - objective value -0.010533324
# Optimal objective -0.01053332361 - 268 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5367169fe68a4a19b8a827dd69f608b6-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/5367169fe68a4a19b8a827dd69f608b6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.4137845 (2)
# 46  Obj -0.0025009274 Primal inf 264.6248 (225)
# 94  Obj -0.0050348599 Primal inf 294.76807 (208)
# 143  Obj -0.0074686259 Primal inf 309.05108 (211)
# 183  Obj -0.0099103268 Primal inf 351.45954 (202)
# 230  Obj -0.011384541 Primal inf 165.61998 (170)
# 265  Obj -0.011729111
# 265  Obj -0.011635793 Dual inf 1.716047e-06 (1)
# Optimal - objective value -0.011635793
# After Postsolve, objective -0.011635793, infeasibilities - dual 0.00017777034 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.011635793 Dual inf 2.616047e-06 (1)
# 1  Obj -0.011635766
# Optimal - objective value -0.011635766
# Optimal objective -0.01163576558 - 266 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/443b7a477ca247e5a1e91bdbd4e4132d-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/443b7a477ca247e5a1e91bdbd4e4132d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.5208584 (2)
# 47  Obj -0.0028998109 Primal inf 227.39252 (218)
# 94  Obj -0.0055239728 Primal inf 76.495694 (182)
# 140  Obj -0.008478044 Primal inf 208.72206 (196)
# 180  Obj -0.010557424 Primal inf 34.674241 (127)
# 224  Obj -0.012367739 Primal inf 67.017119 (127)
# 276  Obj -0.01316783 Primal inf 0.56218159 (18)
# 287  Obj -0.013215896
# Optimal - objective value -0.013112215
# After Postsolve, objective -0.013112215, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.01311221453 - 287 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/389d753042654cafa1782bc953575563-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/389d753042654cafa1782bc953575563-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.6279324 (2)
# 47  Obj -0.0031414618 Primal inf 246.32312 (218)
# 94  Obj -0.0059843039 Primal inf 82.877141 (182)
# 140  Obj -0.0091845477 Primal inf 226.17665 (196)
# 180  Obj -0.01143721 Primal inf 37.59576 (127)
# 224  Obj -0.013398384 Primal inf 72.633878 (127)
# 277  Obj -0.014735478 Primal inf 27.017682 (72)
# 298  Obj -0.015173575 Primal inf 0.00011295993 (1)
# 298  Obj -0 Primal inf 0.00011295993 (1)
# Primal infeasible - objective value -0
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.015053042, infeasibilities - dual 0.9999749 (251), primal 0.00084753267 (1)
# Perturbing problem by 1e-08% of 0.027446895 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.015053042 Primal inf 0.00011385993 (1)
# 0  Obj -0 Primal inf 0.00011385993 (1)
# Primal infeasible - objective value -0
# PrimalInfeasible objective -0 - 298 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0f12a459be8b4617bf7d0192ebe06e1a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/0f12a459be8b4617bf7d0192ebe06e1a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.7350064 (2)
# 45  Obj -0.0032450825 Primal inf 766.28071 (237)
# 92  Obj -0.006615051 Primal inf 134.29747 (202)
# 137  Obj -0.009859611 Primal inf 327.80973 (209)
# 181  Obj -0.012577009 Primal inf 204.03682 (178)
# 228  Obj -0.014359356 Primal inf 5.0521462 (39)
# 286  Obj -0.017028211 Primal inf 13.473085 (41)
# 295  Obj -0.017303687 Primal inf 4.4355723 (24)
# Primal infeasible - objective value -0.017303687
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.017163199, infeasibilities - dual 0.009930482 (192), primal 0.28653229 (25)
# Perturbing problem by 1e-08% of 0.027446895 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.017163199 Primal inf 4.4439035 (25)
# 7  Obj -0.017293449 Primal inf 0.6108593 (15)
# Primal infeasible - objective value -0.017293449
# PrimalInfeasible objective -0.01729344888 - 302 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/eb7d9136b32349f78efc7a2f01b40ec6-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/eb7d9136b32349f78efc7a2f01b40ec6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.8420803 (2)
# 43  Obj -0.0033705423 Primal inf 338.09738 (233)
# 87  Obj -0.0064392602 Primal inf 853.55702 (216)
# 133  Obj -0.0098537874 Primal inf 328.25142 (209)
# 177  Obj -0.013151762 Primal inf 390.75025 (177)
# 223  Obj -0.015228587 Primal inf 120.16787 (128)
# 274  Obj -0.017964329 Primal inf 28.319328 (77)
# 291  Obj -0.01925821 Primal inf 14.493984 (46)
# Primal infeasible - objective value -0.01925821
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.019099681, infeasibilities - dual 0.0092538862 (183), primal 0.72593967 (51)
# Perturbing problem by 1e-08% of 0.027446895 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.019099681 Primal inf 15.452943 (51)
# 17  Obj -0.019463298 Primal inf 9.4989663 (35)
# Primal infeasible - objective value -0.019463298
# PrimalInfeasible objective -0.01946329849 - 308 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b9ab7bfb6e39445fbe26e8c56f714b2f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b9ab7bfb6e39445fbe26e8c56f714b2f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.9491543 (2)
# 43  Obj -0.0035952451 Primal inf 360.65971 (233)
# 87  Obj -0.0068685443 Primal inf 910.45496 (216)
# 133  Obj -0.010510707 Primal inf 350.1672 (209)
# 177  Obj -0.014028546 Primal inf 416.79195 (177)
# 223  Obj -0.016243826 Primal inf 128.21207 (128)
# 273  Obj -0.019617258 Primal inf 152.61429 (113)
# 286  Obj -0.032174106 Primal inf 2829.405 (191)
# Primal infeasible - objective value -0.032174106
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.032198138, infeasibilities - dual 0.0060194598 (118), primal 129.51329 (223)
# Perturbing problem by 1e-08% of 0.027446895 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.054863131 Primal inf 10158.319 (235) Dual inf 0.20407942 (1)
# 0  Obj -0.054863131 Primal inf 10158.319 (235) Dual inf 6.1719199e+14 (118)
# 67  Obj -0.022535511 Primal inf 0.089793571 (1)
# Primal infeasible - objective value -0.022535511
# PrimalInfeasible objective -0.02253551083 - 353 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e942f32a57eb4a29a9d1bc4b372f51f6-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/e942f32a57eb4a29a9d1bc4b372f51f6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 2.0562283 (2)
# 43  Obj -0.003819948 Primal inf 383.22203 (233)
# 87  Obj -0.0072978283 Primal inf 967.3529 (216)
# 133  Obj -0.011167626 Primal inf 372.08298 (209)
# 177  Obj -0.01490533 Primal inf 442.83365 (177)
# 223  Obj -0.017259065 Primal inf 136.25626 (128)
# 272  Obj -0.02122139 Primal inf 196.18961 (120)
# 283  Obj -0.036988401 Primal inf 4009.2374 (193)
# Primal infeasible - objective value -0.036988401
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.037109467, infeasibilities - dual 0.0059741932 (117), primal 182.62958 (225)
# Perturbing problem by 1e-08% of 0.027446895 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.05812852 Primal inf 11581.993 (237) Dual inf 0.18925857 (1)
# 0  Obj -0.05812852 Primal inf 11581.993 (237) Dual inf 6.2047736e+14 (119)
# 76  Obj -0.025361289 Primal inf 0.11968681 (1)
# Primal infeasible - objective value -0.025361289
# PrimalInfeasible objective -0.02536128903 - 359 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1abc118f093c4fdb8eccedfee1a93695-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1abc118f093c4fdb8eccedfee1a93695-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 2.1633023 (2)
# 43  Obj -0.0040116726 Primal inf 495.73709 (215)
# 90  Obj -0.0082875676 Primal inf 2016.3929 (199)
# 133  Obj -0.011465847 Primal inf 74.37894 (140)
# 182  Obj -0.015865712 Primal inf 136.41382 (156)
# 227  Obj -0.018405414 Primal inf 45.638929 (108)
# 276  Obj -0.10128093 Primal inf 4958.3223 (182)
# Primal infeasible - objective value -0.10128093
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.10117847, infeasibilities - dual 0.0063480871 (123), primal 213.49963 (215)
# Perturbing problem by 1e-08% of 0.027446895 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.1869702 Primal inf 12499.635 (225) Dual inf 0.7725035 (1)
# 0  Obj -0.1869702 Primal inf 12499.635 (225) Dual inf 5.9890309e+14 (113)
# 88  Obj -0.028264229 Primal inf 0.14958005 (1)
# Primal infeasible - objective value -0.028264229
# PrimalInfeasible objective -0.02826422942 - 364 iterations time 0.022, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/fb5632bdbc5741f1b73f43c1fd20fcdb-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/fb5632bdbc5741f1b73f43c1fd20fcdb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 4.987799e-05 ( 7.15744%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 2.2703762 (2)
# 43  Obj -0.0040723409 Primal inf 1778.1976 (241)
# 91  Obj -0.0083319721 Primal inf 247.72567 (189)
# 132  Obj -0.01204543 Primal inf 590.18812 (211)
# 180  Obj -0.016696451 Primal inf 93.851 (114)
# 226  Obj -0.019272141 Primal inf 8.3947784 (44)
# 278  Obj -0.1013252 Primal inf 6436.1363 (188)
# 281  Obj -0.12806813 Primal inf 6077.0645 (182)
# Primal infeasible - objective value -0.12806813
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.12800348, infeasibilities - dual 0.0063281848 (123), primal 258.49876 (215)
# Perturbing problem by 1e-08% of 0.027446895 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.22182823 Primal inf 13824.545 (221) Dual inf 0.84483673 (1)
# 0  Obj -0.22182823 Primal inf 13824.545 (221) Dual inf 5.9884e+14 (111)
# 88  Obj -0.032377084 Primal inf 0.23154392 (1) Dual inf 7.0876253e+08 (1)
# 96  Obj -0.031218883 Primal inf 0.17947328 (1)
# Primal infeasible - objective value -0.031218883
# PrimalInfeasible objective -0.03121888311 - 377 iterations time 0.022, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0af4bbf2eae148bc8330ad1fb98554a0-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/0af4bbf2eae148bc8330ad1fb98554a0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 8 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.377452 (2)
# 35  Obj -0.0039004482 Primal inf 545.59203 (232)
# 78  Obj -0.0075862272 Primal inf 206.25069 (210)
# 123  Obj -0.011907353 Primal inf 465.20455 (226)
# 172  Obj -0.01723695 Primal inf 1296.397 (239)
# 221  Obj -0.02013065 Primal inf 74.194818 (120)
# 282  Obj -0.028242373 Primal inf 117.48896 (113)
# 292  Obj -0.029854629 Primal inf 61.678888 (91)
# Primal infeasible - objective value -0.029854629
# PrimalInfeasible objective -0.02985462943 - 292 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/011a775f69504976a06759946cf139eb-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/011a775f69504976a06759946cf139eb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.484526 (2)
# 35  Obj -0.0040954706 Primal inf 572.88343 (232)
# 78  Obj -0.0079655386 Primal inf 216.55142 (210)
# 123  Obj -0.01250272 Primal inf 488.45298 (226)
# 172  Obj -0.018098798 Primal inf 1361.2287 (239)
# 221  Obj -0.021137182 Primal inf 77.916358 (120)
# 283  Obj -0.030874352 Primal inf 126.80136 (112)
# 290  Obj -0.031953107 Primal inf 72.653897 (100)
# Primal infeasible - objective value -0.031953107
# PrimalInfeasible objective -0.0319531067 - 290 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.05
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.05
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1dfcb43e03b14d9c9976e42ff660a531-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1dfcb43e03b14d9c9976e42ff660a531-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.5915999 (2)
# 35  Obj -0.004290493 Primal inf 600.17483 (232)
# 78  Obj -0.00834485 Primal inf 226.85216 (210)
# 123  Obj -0.013098088 Primal inf 511.70141 (226)
# 172  Obj -0.018960645 Primal inf 1426.0603 (239)
# 221  Obj -0.022143715 Primal inf 81.637898 (120)
# 285  Obj -0.033200284 Primal inf 102.89544 (112)
# 291  Obj -0.034066934 Primal inf 83.851195 (100)
# Primal infeasible - objective value -0.034066934
# PrimalInfeasible objective -0.03406693385 - 291 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/179db75458e543cabf52efbea68a0b8a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/179db75458e543cabf52efbea68a0b8a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.6986739 (2)
# 35  Obj -0.0044855154 Primal inf 627.46623 (232)
# 78  Obj -0.0087241613 Primal inf 237.1529 (210)
# 123  Obj -0.013693456 Primal inf 534.94984 (226)
# 172  Obj -0.019822493 Primal inf 1490.892 (239)
# 221  Obj -0.023150247 Primal inf 85.359438 (120)
# 286  Obj -0.035284927 Primal inf 114.29276 (110)
# 291  Obj -0.036180761 Primal inf 95.048492 (100)
# Primal infeasible - objective value -0.036180761
# PrimalInfeasible objective -0.03618076099 - 291 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/33d34883cd1f451bb6b0212fb86c8301-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/33d34883cd1f451bb6b0212fb86c8301-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.8057479 (2)
# 35  Obj -0.0046805378 Primal inf 654.75763 (232)
# 78  Obj -0.0091034727 Primal inf 247.45363 (210)
# 123  Obj -0.014288823 Primal inf 558.19827 (226)
# 172  Obj -0.02068434 Primal inf 1555.7236 (239)
# 221  Obj -0.024156779 Primal inf 89.080979 (120)
# 286  Obj -0.037797802 Primal inf 118.30058 (106)
# 288  Obj -0.038261531 Primal inf 106.27406 (102)
# Primal infeasible - objective value -0.038261531
# PrimalInfeasible objective -0.03826153085 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/53cc621ab9be43c4b8133f97aabaf4a8-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/53cc621ab9be43c4b8133f97aabaf4a8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.9128218 (2)
# 35  Obj -0.0048755602 Primal inf 682.04904 (232)
# 78  Obj -0.009482784 Primal inf 257.75437 (210)
# 123  Obj -0.014884191 Primal inf 581.4467 (226)
# 172  Obj -0.021546188 Primal inf 1620.5553 (239)
# 221  Obj -0.025163312 Primal inf 92.802519 (120)
# 286  Obj -0.039872973 Primal inf 130.6049 (106)
# 288  Obj -0.040378356 Primal inf 117.49734 (102)
# Primal infeasible - objective value -0.040378356
# PrimalInfeasible objective -0.04037835567 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/20805a01e2214cbcaed930a9b74c0a08-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/20805a01e2214cbcaed930a9b74c0a08-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 3.0198958 (2)
# 35  Obj -0.0050705826 Primal inf 709.34044 (232)
# 78  Obj -0.0098620954 Primal inf 268.05511 (210)
# 123  Obj -0.015479559 Primal inf 604.69513 (226)
# 172  Obj -0.022408035 Primal inf 1685.3869 (239)
# 221  Obj -0.026169844 Primal inf 96.524059 (120)
# 286  Obj -0.041948145 Primal inf 142.90923 (106)
# 288  Obj -0.042495181 Primal inf 128.72061 (102)
# Primal infeasible - objective value -0.042495181
# PrimalInfeasible objective -0.0424951805 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0c422b96a6c44ce788a7f9f58afcba68-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/0c422b96a6c44ce788a7f9f58afcba68-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 3.1269698 (2)
# 35  Obj -0.005265605 Primal inf 736.63184 (232)
# 78  Obj -0.010241407 Primal inf 278.35584 (210)
# 123  Obj -0.016074926 Primal inf 627.94356 (226)
# 172  Obj -0.023269883 Primal inf 1750.2186 (239)
# 221  Obj -0.027176377 Primal inf 100.2456 (120)
# 286  Obj -0.044023316 Primal inf 155.21355 (106)
# 288  Obj -0.044612005 Primal inf 139.94389 (102)
# Primal infeasible - objective value -0.044612005
# PrimalInfeasible objective -0.04461200533 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/730c27daf57a4d2cb59701d2deed5a80-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/730c27daf57a4d2cb59701d2deed5a80-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# ...
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 4.5189314 (2)
# 35  Obj -0.0078008964 Primal inf 1091.4201 (232)
# 78  Obj -0.015172454 Primal inf 412.26542 (210)
# 123  Obj -0.023814706 Primal inf 930.17316 (226)
# 172  Obj -0.0344739 Primal inf 2593.03 (239)
# 221  Obj -0.040261299 Primal inf 148.62562 (120)
# 281  Obj -0.068328405 Primal inf 492.69034 (142)
# 289  Obj -0.073103871 Primal inf 281.92555 (112)
# Primal infeasible - objective value -0.073103871
# PrimalInfeasible objective -0.07310387058 - 289 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c141de99890b47d89de85e0a6456c153-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c141de99890b47d89de85e0a6456c153-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 4.6260054 (2)
# 35  Obj -0.0079959188 Primal inf 1118.7115 (232)
# 78  Obj -0.015551766 Primal inf 422.56616 (210)
# 123  Obj -0.024410073 Primal inf 953.42159 (226)
# 172  Obj -0.035335748 Primal inf 2657.8617 (239)
# 221  Obj -0.041267832 Primal inf 152.34716 (120)
# 281  Obj -0.070305409 Primal inf 512.07196 (142)
# 289  Obj -0.075255586 Primal inf 293.21896 (112)
# Primal infeasible - objective value -0.075255586
# PrimalInfeasible objective -0.0752555858 - 289 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ff9c93d61c37407f8e98fe29e546f7fd-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/ff9c93d61c37407f8e98fe29e546f7fd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 4.7330793 (2)
# 35  Obj -0.0081909412 Primal inf 1146.0029 (232)
# 78  Obj -0.015931077 Primal inf 432.86689 (210)
# 123  Obj -0.025005441 Primal inf 976.67002 (226)
# 172  Obj -0.036197595 Primal inf 2722.6933 (239)
# 221  Obj -0.042274364 Primal inf 156.0687 (120)
# 281  Obj -0.073491282 Primal inf 523.52814 (139)
# 288  Obj -0.077326321 Primal inf 305.0393 (113)
# Primal infeasible - objective value -0.077326321
# PrimalInfeasible objective -0.07732632114 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0d844f7ce7b44f10a6dd002f49701a0b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/0d844f7ce7b44f10a6dd002f49701a0b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 4.8401533 (2)
# 35  Obj -0.0083859636 Primal inf 1173.2943 (232)
# 78  Obj -0.016310389 Primal inf 443.16763 (210)
# 123  Obj -0.025600809 Primal inf 999.91845 (226)
# 172  Obj -0.037059443 Primal inf 2787.525 (239)
# 221  Obj -0.043280897 Primal inf 159.79024 (120)
# 281  Obj -0.075509362 Primal inf 542.64044 (139)
# 288  Obj -0.079475418 Primal inf 316.36823 (115)
# Primal infeasible - objective value -0.079475418
# PrimalInfeasible objective -0.07947541754 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b1d549900ba94140ab747ba02817da56-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b1d549900ba94140ab747ba02817da56-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 4.9472273 (2)
# 35  Obj -0.008580986 Primal inf 1200.5857 (232)
# 78  Obj -0.0166897 Primal inf 453.46837 (210)
# 123  Obj -0.026196176 Primal inf 1023.1669 (226)
# 172  Obj -0.03792129 Primal inf 2852.3566 (239)
# 221  Obj -0.044287429 Primal inf 163.51178 (120)
# 281  Obj -0.077527443 Primal inf 561.75274 (139)
# 288  Obj -0.081624514 Primal inf 327.70074 (115)
# Primal infeasible - objective value -0.081624514
# PrimalInfeasible objective -0.08162451393 - 288 iterations time 0.022
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/190fe9702255436084f76c1683c093e5-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/190fe9702255436084f76c1683c093e5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 5.0543012 (2)
# 35  Obj -0.0087760084 Primal inf 1227.8771 (232)
# 78  Obj -0.017069011 Primal inf 463.76911 (210)
# 123  Obj -0.026791544 Primal inf 1046.4153 (226)
# 172  Obj -0.038783138 Primal inf 2917.1883 (239)
# 221  Obj -0.045293962 Primal inf 167.23332 (120)
# 281  Obj -0.079545523 Primal inf 580.86636 (141)
# 288  Obj -0.08377361 Primal inf 339.03324 (115)
# Primal infeasible - objective value -0.08377361
# PrimalInfeasible objective -0.08377361033 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/cefc8bf13a784d63a27893bb75206465-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/cefc8bf13a784d63a27893bb75206465-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 5.1613752 (2)
# 35  Obj -0.0089710308 Primal inf 1255.1685 (232)
# 78  Obj -0.017448323 Primal inf 474.06984 (210)
# 123  Obj -0.027386911 Primal inf 1069.6637 (226)
# 172  Obj -0.039644985 Primal inf 2982.0199 (239)
# 221  Obj -0.046300494 Primal inf 170.95486 (120)
# 281  Obj -0.081563604 Primal inf 600.00674 (143)
# 288  Obj -0.085922707 Primal inf 350.36575 (115)
# Primal infeasible - objective value -0.085922707
# PrimalInfeasible objective -0.08592270673 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/413273b736f14db5986e58326476fed0-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/413273b736f14db5986e58326476fed0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 5.2684492 (2)
# 35  Obj -0.0091660532 Primal inf 1282.4599 (232)
# 78  Obj -0.017827634 Primal inf 484.37058 (210)
# 123  Obj -0.027982279 Primal inf 1092.9122 (226)
# 172  Obj -0.040506833 Primal inf 3046.8516 (239)
# 221  Obj -0.047307026 Primal inf 174.6764 (120)
# 281  Obj -0.083581684 Primal inf 619.15274 (145)
# 288  Obj -0.088071803 Primal inf 361.69825 (115)
# Primal infeasible - objective value -0.088071803
# PrimalInfeasible objective -0.08807180312 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6c1881c4eaa54890bb30d594c02fe852-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6c1881c4eaa54890bb30d594c02fe852-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 5.3755232 (2)
# 35  Obj -0.0093610756 Primal inf 1309.7513 (232)
# 78  Obj -0.018206945 Primal inf 494.67132 (210)
# 123  Obj -0.028577647 Primal inf 1116.1606 (226)
# 172  Obj -0.04136868 Primal inf 3111.6832 (239)
# 221  Obj -0.048313559 Primal inf 178.39794 (120)
# 281  Obj -0.085599764 Primal inf 638.30667 (145)
# 288  Obj -0.0902209 Primal inf 373.03076 (115)
# Primal infeasible - objective value -0.0902209
# PrimalInfeasible objective -0.09022089952 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/fa35be082fc948a7a37a82931803da32-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/fa35be082fc948a7a37a82931803da32-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446895 - largest nonzero change 5.0242082e-06 ( 0.71795643%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 5.4825971 (2)
# 35  Obj -0.009556098 Primal inf 1337.0427 (232)
# 78  Obj -0.018586257 Primal inf 504.97205 (210)
# 123  Obj -0.029173014 Primal inf 1139.409 (226)
# 172  Obj -0.042230528 Primal inf 3176.5149 (239)
# 221  Obj -0.049320091 Primal inf 182.11948 (120)
# 281  Obj -0.087617845 Primal inf 657.4606 (145)
# 288  Obj -0.092369996 Primal inf 384.36326 (115)
# Primal infeasible - objective value -0.092369996
# PrimalInfeasible objective -0.09236999591 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Infeasible
# Optimal Portfolio Weights:
# x0: 0.0
# x1: 0.0
# x2: -8.0052879
# x3: 9.0052879
# x4: 0.0
# x5: 0.0
# expected return (MAD): 0.010000000019416746
# Mean Absolute Deviation (MAD): 0.09227465233828686

# %%
risk_array
# Out:
# array([0.05301182, 0.00736559, 0.00681976, 0.00677463, 0.00688481,
#        0.00717425, 0.00762216, 0.00820221, 0.00891404, 0.00969074,
#        0.01053332, 0.01163577, 0.01311221, 0.01505304, 0.01729401,
#        0.0194633 , 0.02253551, 0.02536129, 0.02826423, 0.03121888,
#        0.02982414, 0.03192042, 0.03403203, 0.03614364, 0.0382222 ,
#        0.04033681, 0.04245142, 0.04456604, 0.04668065, 0.04879526,
#        0.05090987, 0.05302448, 0.05519613, 0.0573156 , 0.05943506,
#        0.06155453, 0.063674  , 0.06579346, 0.06872961, 0.07087909,
#        0.07302857, 0.07517805, 0.07724661, 0.07939347, 0.08154033,
#        0.0836872 , 0.08583406, 0.08798092, 0.09012779, 0.09227465])

# %%
plt.figure()
plt.plot(risk_array, m0_array)

for i, stock in enumerate(assets):
    plt.annotate(stock, (risk_array[i], m0_array[i]), textcoords="offset points", xytext=(10,0), ha='center')
    
for i, stock in enumerate(assets):
    plt.scatter(risk_array[i], m0_array[i], label=stock)
plt.xlabel('Risk (Mean Absolute Deviation)')
plt.ylabel('Expected Return')
plt.title('Efficient Frontier')
# Out:
# Text(0.5, 1.0, 'Efficient Frontier')

# %% [markdown]
# # Now we consider risk as total variance of the portfolio, all these models are model 2x

# %% [markdown]
# # model 2A
# when we minimize variance under a specified expected return $r_0$
# $$
# \begin{gathered}
# \operatorname{maximize} -\frac{1}{T} \sum_{t=1}^T\left(\sum_j x_j\left(R_j(t)-r_j\right)\right)^2 \\
# \text { subject to } \sum_j x_j=1 \\
#   \sum_j x_j r_j = r_0 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$

# %%
# centered return
R_c = 0. * R
for j in range(len(R[0,:])):
  R_c[:,j] = R[:,j] - r[j]

#print(np.outer(R_c[0,:],R_c[0,:]))
R_c.T @ R_c

# compute the convariance matrix manually
sig = 0. * S
for i in range(len(R[:,0])):
  sig = sig + np.outer(R_c[i,:],R_c[i,:])
sig = sig / T


r0 = 0.0005
n = len(R[0,:])
e = np.ones((n,1))
rq = r.reshape(n,1)

X = cp.Variable((n,1))
Objective = cp.Minimize(cp.quad_form(X,sig))
constraints = [e.T@X == 1, X >= 0, rq.T@X >= r0]
problem = cp.Problem(Objective,constraints)

result = problem.solve()

print("expected portfolio", X.value.T)
print("expected return :", (rq.T @ X.value)[0] )
print("Mean variance:", (X.value.T @ sig @ X.value)[0] )
X
# Out:
# expected portfolio [[ 2.58228176e-01  4.82486070e-01  1.74084183e-01  1.68322886e-02
#    6.83692827e-02 -2.82603289e-19]]
# expected return : [0.00062784]
# Mean variance: [8.1580495e-05]
# Variable((6, 1), var1)

# %% [markdown]
# ## Optimization Problem
#
# Choose a risk tolerance $q > 0$:
#
# \begin{align*}
# \text{minimize:} \ \ & \mathbf{x}^T \Sigma \mathbf{x} - q \mathbf{r}^T \mathbf{x} \\
# \text{subject to:} \ \ & \mathbf{e}^T \mathbf{x} = 1 \\
# & \mathbf{x} \geq 0 \\
# \end{align*}

# %%
n = len(assets)
q = 0.1
e = np.ones(n)
X = cp.Variable(n)

obj = cp.Minimize(cp.quad_form(X,S) - q*r@X)
constraints = [e@X == 1, X >= 0]
problem = cp.Problem(obj,constraints)

result = problem.solve()
X.value
# Out:
# array([1.08826665e-22, 1.81512808e-01, 4.26124774e-01, 1.87604603e-01,
#        2.04757815e-01, 2.68440037e-23])

# %% [markdown]
# ## Optimization Problem
#
# \begin{align*}
# \text{minimize:} \ \ & \mathbf{x}^T \Sigma \mathbf{x} \\
# \text{subject to:} \ \ & \mathbf{e}^T \mathbf{x} = 1 \\
# & \mathbf{r}^T \mathbf{x} = \mu \\
# & \mathbf{x} \geq 0 \\
# \end{align*}

# %% [markdown]
# case mu = 0.01,   minimize risk sigma = 0.001
#
# case mu = 0.02,  minimize risk sigma = 0.003
#
# case mu = 0.05,  minimize risk  sigma = 0.010

# %%
n = len(assets)
e = np.ones((n,1))
r = r.reshape(n,1)
mu = 0.001

M = np.block([[2*S,-r,-e],[r.T,0,0],[e.T,0,0]])
b = np.block([[np.zeros((n,1))],[mu],[1]])

x = la.solve(M,b)
