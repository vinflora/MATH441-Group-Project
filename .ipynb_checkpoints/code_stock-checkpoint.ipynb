# %%
# !pip install pulp
# !pip install yfinance
# Out:
# Requirement already satisfied: pulp in /opt/conda/lib/python3.10/site-packages (2.7.0)
# Requirement already satisfied: yfinance in /opt/conda/lib/python3.10/site-packages (0.2.37)
# Requirement already satisfied: peewee>=3.16.2 in /opt/conda/lib/python3.10/site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: pytz>=2022.5 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: html5lib>=1.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: appdirs>=1.4.4 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2.4.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: pandas>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/conda/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2022.12.7)

# %%
# !pip install cvxpy
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
import cvxpy as cp
import scipy.linalg as la
import pulp
# Out:
# Requirement already satisfied: cvxpy in /opt/conda/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: scs>=3.0 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (3.2.4.post1)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (1.10.0)
# Requirement already satisfied: ecos>=2 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (2.0.13)
# Requirement already satisfied: clarabel>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (0.7.1)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (1.23.5)
# Requirement already satisfied: pybind11 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (2.12.0)
# Requirement already satisfied: osqp>=0.6.2 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (0.6.5)
# Requirement already satisfied: qdldl in /opt/conda/lib/python3.10/site-packages (from osqp>=0.6.2->cvxpy) (0.1.7.post1)

# %% [markdown]
# ## how we load data from yahoo finance

# %% [markdown]
# #### Stock data

# %%
T = 1 # Number of days in time period
R = []
assets = ["AAPL","EA","MSFT","NFLX","GOOGL","TSLA"]

for stock in assets:
    data = yf.Ticker(stock)
    # 我先改成1年， 这个之后可以随时改成想要的时段
    df = data.history(period="1y")

    # close values on that day
    close = df['Close'].values

    # convert day to day close values to return
    returns = (close[T:] - close[:-T])/close[:-T]
    R.append(returns)

R = np.array(R).T
r = np.mean(R,axis=0)
S = np.cov(R.T)

# %%
R
# Out:
# array([[-0.00435327,  0.00358043,  0.00233347, -0.02122939, -0.00673943,
#         -0.03346004],
#        [ 0.03410371,  0.01704598,  0.02239939,  0.04579646,  0.02666285,
#          0.02968872],
#        [-0.00211396, -0.00319614, -0.01276549, -0.02183771,  0.0134041 ,
#         -0.00484128],
#        ...,
#        [-0.00666355, -0.00222575, -0.00218554, -0.01221356,  0.01540988,
#          0.04899941],
#        [ 0.00724251,  0.00530771,  0.00398032, -0.01624729,  0.01130126,
#          0.02254601],
#        [-0.01113927, -0.01063585, -0.00708452,  0.0006147 , -0.00293746,
#         -0.02894624]])

# %%
# Create a single plot for all stocks
plt.figure(figsize=(10, 6))

# Plot price evolution of each stock
for stock in assets:
    data = yf.Ticker(stock)
    df = data.history(period="1y")
    plt.plot(df.index, df['Open'], label=stock)

plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Price Evolution of Stocks')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## tesla in past 1 years

# %%
# last df is Tesla
df['Open'].plot()
plt.show()

# %% [markdown]
# ## histogram of Tesla in past 1 years

# %%
return_TSLA = R[:,-1]
plt.hist(return_TSLA,bins=50)
plt.show()

# %%
r
# Out:
# array([0.00026376, 0.0001986 , 0.00173443, 0.00265228, 0.0017161 ,
#        0.00012128])

# %%
S
# Out:
# array([[1.46795035e-04, 4.51281865e-05, 8.14891640e-05, 9.54640138e-05,
#         9.41011910e-05, 1.32531661e-04],
#        [4.51281865e-05, 1.24669255e-04, 3.91243138e-05, 4.06778010e-05,
#         3.81256575e-05, 9.03957903e-05],
#        [8.14891640e-05, 3.91243138e-05, 1.90445019e-04, 1.22598618e-04,
#         9.90207935e-05, 1.07310785e-04],
#        [9.54640138e-05, 4.06778010e-05, 1.22598618e-04, 5.03095045e-04,
#         1.14351464e-04, 1.24975462e-04],
#        [9.41011910e-05, 3.81256575e-05, 9.90207935e-05, 1.14351464e-04,
#         2.93251399e-04, 1.35635291e-04],
#        [1.32531661e-04, 9.03957903e-05, 1.07310785e-04, 1.24975462e-04,
#         1.35635291e-04, 9.08183849e-04]])

# %% [markdown]
# # We consider risk as MAD first, all these models are model 1x

# %% [markdown]
# # model 1A
# when we minimize MAD under a specified expected return $r_0$
# $$
# \begin{gathered}
# \operatorname{maximize} -\frac{1}{T} \sum_{t=1}^T\left|\sum_j x_j\left(R_j(t)-r_j\right)\right| \\
# \text { subject to } \sum_j x_j=1 \\
#   \sum_j x_j r_j = r_0 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$
#
# The LP version is
# $$
# \begin{gathered}
# & \operatorname{maximize} -\frac{1}{T} \sum_{t=1}^T y_t \\
# & \text { subject to }-y_t \leq \sum_j x_j\left(R_j(t)-r_j\right) \leq y_t \quad t=1,2, \ldots, T \text {, } \\
# & \sum_j x_j=1 \\
# &  \sum_j x_j r_j = r_0 \\
# & x_j \geq 0 \quad j=1,2, \ldots, n, \\
# & r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods
r0 = 0.0008
print(n,T,r0)


# Create a LP problem
prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

# Define decision variables
x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

# Define objective function
prob +=  - (1/T) * lpSum(y[t] for t in range(T)), "Objective"

# Define constraints
for t in range(T):
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

prob += lpSum(r[j] * x[j] for j in range(n)) == r0

prob += lpSum(x) == 1, "Sum_of_weights"

# Solve the problem
prob.solve()

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 0.0008
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/dd0561de26254845a726af77812c9726-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/dd0561de26254845a726af77812c9726-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.06
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.066352689
# x1: 0.56828527
# x2: 0.2326153
# x3: 0.04099521
# x4: 0.091751539
# x5: 0.0
# expected return (MAD): 0.0008000000093771509
# Mean Absolute Deviation (MAD): 0.006870762693000001

# %% [markdown]
# # model 1B
# when we maximize return under a specified MAD constrait $m_0$
# $$
# \begin{gathered}
# \operatorname{maximize} \sum_j x_j r_j  \\
# \text { subject to } \sum_j x_j=1 \\
#   \frac{1}{T} \sum_{t=1}^T\left|\sum_j x_j\left(R_j(t)-r_j\right)\right| \leq m_0 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$
#
# The LP version is
# $$
# \begin{gathered}
# & \operatorname{maximize}  \sum_j x_j r_j   \\
# & \text { subject to }-y_t \leq \sum_j x_j\left(R_j(t)-r_j\right) \leq y_t \quad t=1,2, \ldots, T \text {, } \\
# & \sum_j x_j=1 \\
# & \frac{1}{T} \sum_{t=1}^T y_t \leq m_0  \\
# & x_j \geq 0 \quad j=1,2, \ldots, n, \\
# & r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods
m0 = 0.007
print(n,T,r0)


# Create a LP problem
prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

# Define decision variables
x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

# Define objective function
prob += lpSum(r[j] * x[j] for j in range(n)), "Objective"

# Define constraints
for t in range(T):
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

prob +=  (1/T) * lpSum(y[t] for t in range(T)) <= m0, "Risk"

prob += lpSum(x) == 1, "Sum_of_weights"

# Solve the problem
prob.solve()

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 0.0008
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/125d0beb6bbf44b4ba633fd1f94f4468-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/125d0beb6bbf44b4ba633fd1f94f4468-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3771 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3358 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 0.00012071587 ( 26.772389%) - largest zero change 9.9738188e-05
# 0  Obj -0 Primal inf 11.586553 (2) Dual inf 0.050445198 (6)
# 59  Obj 0.0046719664 Primal inf 114.03098 (207)
# 94  Obj 0.0028144644 Primal inf 454.49221 (224)
# 134  Obj 0.0019046081 Primal inf 137.88237 (195)
# 176  Obj 0.0015037553 Primal inf 22.864292 (134)
# 219  Obj 0.0012395844 Primal inf 69.859559 (168)
# 263  Obj 0.00095548906 Primal inf 12.454784 (84)
# 297  Obj 0.00081064884
# Optimal - objective value 0.00091480957
# After Postsolve, objective 0.00091480957, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.0009148095685 - 297 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.027648368
# x1: 0.54113342
# x2: 0.27074537
# x3: 0.058829192
# x4: 0.10164365
# x5: 0.0
# expected return (MAD): 0.0009148095665351683
# Mean Absolute Deviation (MAD): 0.00699999999901195

# %% [markdown]
# ## model 1C
# when combine return and risk together with $\mu$
#
# $$
# \begin{gathered}
# \operatorname{maximize} \mu \sum_j x_j r_j-\frac{1}{T} \sum_{t=1}^T\left|\sum_j x_j\left(R_j(t)-r_j\right)\right| \\
# \text { subject to } \sum_j x_j=1 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$
#
# The LP version is
# $$
# \begin{aligned}
# & \operatorname{maximize} \mu \sum_j x_j r_j-\frac{1}{T} \sum_{t=1}^T y_t \\
# & \text { subject to }-y_t \leq \sum_j x_j\left(R_j(t)-r_j\right) \leq y_t \quad t=1,2, \ldots, T \text {, } \\
# & \sum_j x_j=1 \\
# & x_j \geq 0 \quad j=1,2, \ldots, n \\
# & y_t \geq 0 \quad t=1,2, \ldots, T . \\
# &
# \end{aligned}
# $$
#
# below is pulp implementation

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods
mu = 1
print(n,T,mu)


# Create a LP problem
prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

# Define decision variables
x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

# Define objective function
prob += lpSum(r[j] * x[j] for j in range(n)) * mu - (1/T) * lpSum(y[t] for t in range(T)), "Objective"

# Define constraints
for t in range(T):
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

prob += lpSum(x) == 1, "Sum_of_weights"

# Solve the problem
prob.solve()

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 1
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d48655a715bd493d805abb8a6a22381b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/d48655a715bd493d805abb8a6a22381b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.049674917
# x1: 0.5656547
# x2: 0.23711883
# x3: 0.056276425
# x4: 0.091275124
# x5: 0.0
# expected return (MAD): 0.0008426022786864088
# Mean Absolute Deviation (MAD): 0.00690809982589004

# %% [markdown]
# # Efficient frontier
#
# Let us use model 1B to compute the efficient frontier

# %% [markdown]
# ### 1A Model efficient frontier

# %%
# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods
r0 = 0.0008
print(n,T,r0)

m0_array = np.linspace(0.0,0.01,50)
risk_array = 0. * m0_array
i = 0
for i in range(len(m0_array)):

    # Create a LP problem
    prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

    # Define decision variables
    x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
    y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

    # Define objective function
    prob +=  - (1/T) * lpSum(y[t] for t in range(T)), "Objective"

    # Define constraints
    for t in range(T):
        prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
        prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

    prob += lpSum(r[j] * x[j] for j in range(n)) == r0

    prob += lpSum(x) == 1, "Sum_of_weights"

    # Solve the problem
    prob.solve()
    risk_array[i] = value( (1/T) * lpSum(y[t] for t in range(T)))

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 0.0008
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/08b832a613f043be8ae5a6b91f919ad1-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/08b832a613f043be8ae5a6b91f919ad1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/85f20fea7355441aae4266e6f7971aef-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/85f20fea7355441aae4266e6f7971aef-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3b52a4ad4ce549749195d04ad2b0c22b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/3b52a4ad4ce549749195d04ad2b0c22b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4980af8cf5fe41c7b046e180f28fbc30-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4980af8cf5fe41c7b046e180f28fbc30-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/405f81b313f74c68af177c703593108a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/405f81b313f74c68af177c703593108a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/232549b566184dd488a1520f38ed0340-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/232549b566184dd488a1520f38ed0340-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9fabed3d72c740b7ae024f1156d5d4aa-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/9fabed3d72c740b7ae024f1156d5d4aa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/01e6265f80ef4928873b6155ccbacf2a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/01e6265f80ef4928873b6155ccbacf2a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6532f8d5bfe34cfaa71df5a5a1554a26-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6532f8d5bfe34cfaa71df5a5a1554a26-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b8e59b49075544ff99ea19eb2955ad58-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b8e59b49075544ff99ea19eb2955ad58-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/eac82136af82452b9be631e359294d81-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/eac82136af82452b9be631e359294d81-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0479ace6837c4519a0cc58bfbebc83bc-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/0479ace6837c4519a0cc58bfbebc83bc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/909e60d185b14ad8910eaab10fe9a8fa-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/909e60d185b14ad8910eaab10fe9a8fa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/994d97784a854425a1993b2cb7e07a73-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/994d97784a854425a1993b2cb7e07a73-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c7ad16e4953e4f72b4ee3087dc3ca9f7-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c7ad16e4953e4f72b4ee3087dc3ca9f7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/8f47b2869cde455c81a2b6fe8d09f3dd-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/8f47b2869cde455c81a2b6fe8d09f3dd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/03bfd86a8f404bdeb2ef9a753df36953-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/03bfd86a8f404bdeb2ef9a753df36953-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/176c854d138141daa62bf68b19d42d80-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/176c854d138141daa62bf68b19d42d80-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1f320ae4b5be481b9bdcddaf23caf8ae-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1f320ae4b5be481b9bdcddaf23caf8ae-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d998bf65730c458e9277519a1a161864-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/d998bf65730c458e9277519a1a161864-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7ce5c15cbc6f4725a10635fe2dc3d4af-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/7ce5c15cbc6f4725a10635fe2dc3d4af-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0348da36d57741768ee31b221de81ddf-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/0348da36d57741768ee31b221de81ddf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/704e53a2517944989c3134c0073520e3-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/704e53a2517944989c3134c0073520e3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/707c86e05aef4c3d866d9803d05d5155-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/707c86e05aef4c3d866d9803d05d5155-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/da15d07b487740caaebae85763fdfe67-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/da15d07b487740caaebae85763fdfe67-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4201237bac3a47bdb8de63153c941794-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4201237bac3a47bdb8de63153c941794-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/644907f42ebb4538b93b9b611d328c0d-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/644907f42ebb4538b93b9b611d328c0d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/cefb4106ad68439788cb4ac554346514-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/cefb4106ad68439788cb4ac554346514-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/2e528239dc164f3d9497975dc910057e-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/2e528239dc164f3d9497975dc910057e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/236318d41ba94dc6bc45d54d20eb6416-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/236318d41ba94dc6bc45d54d20eb6416-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4d56593fe36d4c0bb0e5dcadbc2dce6e-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4d56593fe36d4c0bb0e5dcadbc2dce6e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4bda21acd63a446ca49d407f2ed8ce2f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4bda21acd63a446ca49d407f2ed8ce2f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f2058d403f8c474b8c82f55c82f3b5b5-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/f2058d403f8c474b8c82f55c82f3b5b5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1c920641ca8b4475b0e73cb9cc18ddd7-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1c920641ca8b4475b0e73cb9cc18ddd7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# ...
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b974faf2c11d4d1e81b265e0660397cd-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b974faf2c11d4d1e81b265e0660397cd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/85acae185b4b4db686033e8ff3b71de4-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/85acae185b4b4db686033e8ff3b71de4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/06c4f0269de949e78f21e6b3c2843765-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/06c4f0269de949e78f21e6b3c2843765-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/2da16a576efe46c88256a32270768509-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/2da16a576efe46c88256a32270768509-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7012ca21cc214241b916026528af03d6-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/7012ca21cc214241b916026528af03d6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/db8eb224a91b4ce2897141e4ee479bda-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/db8eb224a91b4ce2897141e4ee479bda-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1cf6906550d04e2e81b7c74b5663e3cd-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1cf6906550d04e2e81b7c74b5663e3cd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/fff77845e43a41bcafadc4d7c71b53a6-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/fff77845e43a41bcafadc4d7c71b53a6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/71ca113c1a1d4714858446155e42099f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/71ca113c1a1d4714858446155e42099f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/40b275058582459f8e1fa1fc34a25421-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/40b275058582459f8e1fa1fc34a25421-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4b6c58e627a34236968c1f28a894ef47-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4b6c58e627a34236968c1f28a894ef47-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.65570075 (2)
# 45  Obj -0.00090544404 Primal inf 76.036584 (231)
# 92  Obj -0.0022363851 Primal inf 80.278195 (212)
# 139  Obj -0.0034727441 Primal inf 172.06546 (199)
# 188  Obj -0.0052859679 Primal inf 43.901188 (159)
# 239  Obj -0.0064476379 Primal inf 35.105089 (108)
# 292  Obj -0.0069253026
# Optimal - objective value -0.0068707627
# After Postsolve, objective -0.0068707627, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00687076269 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.066352689
# x1: 0.56828527
# x2: 0.2326153
# x3: 0.04099521
# x4: 0.091751539
# x5: 0.0
# expected return (MAD): 0.0008000000093771509
# Mean Absolute Deviation (MAD): 0.006870762693000001

# %%
plt.figure()
plt.plot(risk_array, m0_array)

for i, stock in enumerate(assets):
    plt.annotate(stock, (risk_array[i], m0_array[i]), textcoords="offset points", xytext=(10,0), ha='center')
    
for i, stock in enumerate(assets):
    plt.scatter(risk_array[i], m0_array[i], label=stock)
plt.xlabel('Risk (Mean Absolute Deviation)')
plt.ylabel('Expected Return')
plt.title('Efficient Frontier')
# Out:
# Text(0.5, 1.0, 'Efficient Frontier')

# %% [markdown]
# ### 1B Model efficient frontier

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods

m0_array = np.linspace(0.0,0.01,50)
risk_array = 0. * m0_array
i = 0
for i in range(len(m0_array)):

  # Define the data
  n = len(assets)  # Number of assets
  T = len(R[:,0])  # Number of time periods
  r0 = m0_array[i]

  # Create a LP problem
  prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

  # Define decision variables
  x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
  y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

  # Define objective function
  prob +=  - (1/T) * lpSum(y[t] for t in range(T)), "Objective"

  # Define constraints
  for t in range(T):
      prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
      prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

  prob += lpSum(r[j] * x[j] for j in range(n)) == r0

  prob += lpSum(x) == 1, "Sum_of_weights"

  # Solve the problem
  prob.solve()
  risk_array[i] = value( (1/T) * lpSum(y[t] for t in range(T)))

print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/dfe45ec24f564c16a968a46092cc0ca2-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/dfe45ec24f564c16a968a46092cc0ca2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 0.23597269 (1)
# 37  Obj -0.0011484332 Primal inf 121.07912 (233)
# 89  Obj -0.0030492949 Primal inf 212.12638 (230)
# 138  Obj -0.0051214202 Primal inf 116.57626 (187)
# 188  Obj -0.0064716029 Primal inf 430.03866 (218)
# 240  Obj -0.0073815705 Primal inf 27.45451 (104)
# 320  Obj -0.032771331 Primal inf 285.90435 (151)
# 376  Obj -0.053072235 Primal inf 21.983278 (39)
# Primal infeasible - objective value -0.053072235
# PrimalInfeasible objective -0.05307223453 - 376 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b9f1fe66d6d042daacd7564589056e77-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b9f1fe66d6d042daacd7564589056e77-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.34304476 (2)
# 39  Obj -0.001123807 Primal inf 93.850973 (220)
# 88  Obj -0.0027524755 Primal inf 82.048034 (206)
# 136  Obj -0.0045196588 Primal inf 491.18295 (200)
# 185  Obj -0.0059458829 Primal inf 126.93488 (181)
# 232  Obj -0.0067526365 Primal inf 103.9592 (179)
# 271  Obj -0.0071244153 Primal inf 0.026246519 (4)
# 305  Obj -0.0074250328
# Optimal - objective value -0.0073655901
# After Postsolve, objective -0.0073655901, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.007365590076 - 305 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/442a79409ab348359baeff175f970548-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/442a79409ab348359baeff175f970548-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.45011873 (2)
# 31  Obj -0.00086320953 Primal inf 74.855717 (232)
# 82  Obj -0.0022024669 Primal inf 157.6269 (214)
# 134  Obj -0.0036465832 Primal inf 64.127505 (180)
# 185  Obj -0.005350313 Primal inf 40.374559 (146)
# 232  Obj -0.0064214273 Primal inf 25.245523 (97)
# 279  Obj -0.0068753321
# Optimal - objective value -0.0068197603
# After Postsolve, objective -0.0068197603, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006819760266 - 279 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b8d54f7ad5304f5a86f644a492e959cc-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b8d54f7ad5304f5a86f644a492e959cc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.5571927 (2)
# 42  Obj -0.00078428446 Primal inf 555.06082 (227)
# 90  Obj -0.0021556575 Primal inf 43.119746 (198)
# 138  Obj -0.0035708028 Primal inf 96.971462 (199)
# 189  Obj -0.0053061241 Primal inf 83.285617 (172)
# 238  Obj -0.0062367783 Primal inf 27.106712 (113)
# 286  Obj -0.0068287687
# Optimal - objective value -0.0067746243
# After Postsolve, objective -0.0067746243, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00677462433 - 286 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/bce9ff02bfd14a4abeee238698ed8fbc-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/bce9ff02bfd14a4abeee238698ed8fbc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.66426667 (2)
# 45  Obj -0.00092359252 Primal inf 76.099812 (231)
# 92  Obj -0.0022588826 Primal inf 292.06192 (221)
# 138  Obj -0.003831857 Primal inf 42.117177 (166)
# 188  Obj -0.0051546743 Primal inf 213.25787 (202)
# 237  Obj -0.0064651012 Primal inf 13.318085 (86)
# 285  Obj -0.0069394286
# Optimal - objective value -0.0068848064
# After Postsolve, objective -0.0068848064, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006884806377 - 285 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/8f6aa9fc808e464e9250a3a6c6492231-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/8f6aa9fc808e464e9250a3a6c6492231-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.77134064 (2)
# 45  Obj -0.0011695435 Primal inf 104.85732 (233)
# 92  Obj -0.0025881693 Primal inf 192.95252 (220)
# 139  Obj -0.004161751 Primal inf 143.22112 (210)
# 189  Obj -0.005626767 Primal inf 48.224664 (144)
# 238  Obj -0.0068477879 Primal inf 17.869904 (98)
# 283  Obj -0.0072306486
# Optimal - objective value -0.0071742472
# After Postsolve, objective -0.0071742472, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.007174247238 - 283 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/dc54845264024ebba83458a3f3b48071-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/dc54845264024ebba83458a3f3b48071-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.87841461 (2)
# 45  Obj -0.0014034522 Primal inf 125.89628 (233)
# 92  Obj -0.0027373321 Primal inf 73.21723 (176)
# 140  Obj -0.0042858064 Primal inf 431.11989 (206)
# 186  Obj -0.0058076355 Primal inf 36.894366 (148)
# 251  Obj -0.0075230013 Primal inf 12.723964 (73)
# 281  Obj -0.0076816412
# 281  Obj -0.0076221853 Dual inf 7.0537299e-08 (1)
# Optimal - objective value -0.0076221853
# After Postsolve, objective -0.0076221853, infeasibilities - dual 2.8667006e-05 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.0076221853 Dual inf 9.705373e-07 (1)
# 1  Obj -0.0076221617
# Optimal - objective value -0.0076221617
# Optimal objective -0.007622161705 - 282 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9b1633f441694b41a1b8a424d1bc3973-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/9b1633f441694b41a1b8a424d1bc3973-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.98548858 (2)
# 45  Obj -0.0016373609 Primal inf 146.93523 (233)
# 92  Obj -0.0031935542 Primal inf 85.380803 (176)
# 136  Obj -0.004723346 Primal inf 48.024265 (165)
# 179  Obj -0.0059182541 Primal inf 35.682878 (139)
# 226  Obj -0.0071280631 Primal inf 4.5002287 (48)
# 279  Obj -0.0082664926
# 279  Obj -0.0082023237 Dual inf 2.3545722e-06 (1)
# Optimal - objective value -0.0082023237
# After Postsolve, objective -0.0082023237, infeasibilities - dual 0.00018610174 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.0082023237 Dual inf 3.2545722e-06 (1)
# 1  Obj -0.0082022104
# Optimal - objective value -0.0082022104
# Optimal objective -0.008202210366 - 280 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4f00ee7c734045aea1fb6488a9b06ea9-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4f00ee7c734045aea1fb6488a9b06ea9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.0925626 (2)
# 45  Obj -0.0018712696 Primal inf 167.97418 (233)
# 92  Obj -0.0036497762 Primal inf 97.544375 (176)
# 136  Obj -0.0053981097 Primal inf 54.851187 (165)
# 179  Obj -0.006763719 Primal inf 40.748186 (139)
# 226  Obj -0.0081463578 Primal inf 5.109415 (48)
# 274  Obj -0.0089855041
# Optimal - objective value -0.0089140419
# After Postsolve, objective -0.0089140419, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.008914041881 - 274 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ff1142182de64ab6a2840c188809bf7b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/ff1142182de64ab6a2840c188809bf7b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.1996365 (2)
# 45  Obj -0.0021051783 Primal inf 189.01313 (233)
# 92  Obj -0.0041059982 Primal inf 109.70795 (176)
# 136  Obj -0.0060728734 Primal inf 61.67811 (165)
# 179  Obj -0.0076091839 Primal inf 45.813494 (139)
# 226  Obj -0.0091646526 Primal inf 5.7186013 (48)
# 271  Obj -0.0097698589
# Optimal - objective value -0.0096907408
# After Postsolve, objective -0.0096907408, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.009690740809 - 271 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5ed64246597f4f729afb7796fdde7b4c-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/5ed64246597f4f729afb7796fdde7b4c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.3067105 (2)
# 45  Obj -0.0022855606 Primal inf 99.640558 (217)
# 93  Obj -0.00453265 Primal inf 152.04566 (210)
# 139  Obj -0.006677355 Primal inf 229.13353 (209)
# 181  Obj -0.0085368171 Primal inf 93.196051 (178)
# 227  Obj -0.01023553 Primal inf 15.194708 (82)
# 267  Obj -0.010619608
# 267  Obj -0.01053364 Dual inf 3.8211604e-06 (1)
# Optimal - objective value -0.01053364
# After Postsolve, objective -0.01053364, infeasibilities - dual 4.4495602e-05 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.01053364 Dual inf 4.7211604e-06 (1)
# 1  Obj -0.010533325
# Optimal - objective value -0.010533325
# Optimal objective -0.01053332485 - 268 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d260fed95f2a4c5c8472ae1da0722f3a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/d260fed95f2a4c5c8472ae1da0722f3a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.4137845 (2)
# 46  Obj -0.0025009381 Primal inf 264.63231 (225)
# 94  Obj -0.0050348673 Primal inf 294.77556 (208)
# 143  Obj -0.0074685998 Primal inf 309.05391 (211)
# 183  Obj -0.0099103242 Primal inf 351.46312 (202)
# 230  Obj -0.01138455 Primal inf 165.62138 (170)
# 265  Obj -0.011729116
# 265  Obj -0.011635794 Dual inf 1.7171003e-06 (1)
# Optimal - objective value -0.011635794
# After Postsolve, objective -0.011635794, infeasibilities - dual 0.00017783932 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.011635794 Dual inf 2.6171003e-06 (1)
# 1  Obj -0.011635766
# Optimal - objective value -0.011635766
# Optimal objective -0.01163576625 - 266 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/df6cf4db20f9468d8e60931da81a335a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/df6cf4db20f9468d8e60931da81a335a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.5208584 (2)
# 47  Obj -0.0028998163 Primal inf 227.39291 (218)
# 94  Obj -0.0055239775 Primal inf 76.496183 (182)
# 140  Obj -0.0084780423 Primal inf 208.72281 (196)
# 180  Obj -0.010557432 Primal inf 34.675318 (127)
# 224  Obj -0.012367745 Primal inf 67.019741 (127)
# 276  Obj -0.013167835 Primal inf 0.56218453 (18)
# 287  Obj -0.013215901
# Optimal - objective value -0.013112215
# After Postsolve, objective -0.013112215, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.01311221482 - 287 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ac19f9d96f2c4c739afa04c34de401ad-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/ac19f9d96f2c4c739afa04c34de401ad-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.6279324 (2)
# 47  Obj -0.0031414676 Primal inf 246.32354 (218)
# 94  Obj -0.005984309 Primal inf 82.877671 (182)
# 140  Obj -0.0091845458 Primal inf 226.17746 (196)
# 180  Obj -0.011437218 Primal inf 37.596927 (127)
# 224  Obj -0.013398391 Primal inf 72.636718 (127)
# 277  Obj -0.014735484 Primal inf 27.017738 (72)
# 298  Obj -0.015173581 Primal inf 0.00011295993 (1)
# 298  Obj -0 Primal inf 0.00011295993 (1)
# Primal infeasible - objective value -0
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.015053042, infeasibilities - dual 0.9999749 (251), primal 0.00084753267 (1)
# Perturbing problem by 1e-08% of 0.027446915 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.015053042 Primal inf 0.00011385993 (1)
# 0  Obj -0 Primal inf 0.00011385993 (1)
# Primal infeasible - objective value -0
# PrimalInfeasible objective -0 - 298 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6cb28c1d00f545299ddffec8764f441d-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6cb28c1d00f545299ddffec8764f441d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.7350064 (2)
# 45  Obj -0.003245048 Primal inf 766.27325 (237)
# 92  Obj -0.006615046 Primal inf 134.29632 (202)
# 137  Obj -0.0098596032 Primal inf 327.81444 (209)
# 181  Obj -0.012577019 Primal inf 204.03763 (178)
# 228  Obj -0.014359359 Primal inf 5.0522457 (39)
# 286  Obj -0.017028218 Primal inf 13.473109 (41)
# 295  Obj -0.017303694 Primal inf 4.435588 (24)
# Primal infeasible - objective value -0.017303694
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.017163198, infeasibilities - dual 0.0099305593 (192), primal 0.28653242 (25)
# Perturbing problem by 1e-08% of 0.027446915 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.017163198 Primal inf 4.4439024 (25)
# 7  Obj -0.017293449 Primal inf 0.61085938 (15)
# Primal infeasible - objective value -0.017293449
# PrimalInfeasible objective -0.01729344888 - 302 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/fcbc5c27ae5d4b1b84b6d95c29c7b00a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/fcbc5c27ae5d4b1b84b6d95c29c7b00a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.8420803 (2)
# 43  Obj -0.0033705285 Primal inf 338.09478 (233)
# 87  Obj -0.0064392719 Primal inf 853.56977 (216)
# 133  Obj -0.0098537764 Primal inf 328.25233 (209)
# 177  Obj -0.013151776 Primal inf 390.75394 (177)
# 223  Obj -0.015228594 Primal inf 120.16994 (128)
# 274  Obj -0.017964337 Primal inf 28.319828 (77)
# 291  Obj -0.01925822 Primal inf 14.494011 (46)
# Primal infeasible - objective value -0.01925822
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.019099681, infeasibilities - dual 0.0092539631 (183), primal 0.72593901 (51)
# Perturbing problem by 1e-08% of 0.027446915 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.019099681 Primal inf 15.452921 (51)
# 17  Obj -0.019463297 Primal inf 9.4989548 (35)
# Primal infeasible - objective value -0.019463297
# PrimalInfeasible objective -0.01946329732 - 308 iterations time 0.022, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/acc5d997da36444eaa33a04e6217f845-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/acc5d997da36444eaa33a04e6217f845-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.9491543 (2)
# 43  Obj -0.0035952304 Primal inf 360.65692 (233)
# 87  Obj -0.0068685567 Primal inf 910.46856 (216)
# 133  Obj -0.010510695 Primal inf 350.16817 (209)
# 177  Obj -0.014028561 Primal inf 416.79589 (177)
# 223  Obj -0.016243834 Primal inf 128.21429 (128)
# 273  Obj -0.019617269 Primal inf 152.61765 (113)
# 286  Obj -0.032174095 Primal inf 2829.4946 (191)
# Primal infeasible - objective value -0.032174095
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.032198142, infeasibilities - dual 0.0060194661 (118), primal 129.5133 (223)
# Perturbing problem by 1e-08% of 0.027446915 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.054863144 Primal inf 10158.531 (235) Dual inf 0.20380506 (1)
# 0  Obj -0.054863144 Primal inf 10158.531 (235) Dual inf 6.1637651e+14 (118)
# 67  Obj -0.022535507 Primal inf 0.089793573 (1)
# Primal infeasible - objective value -0.022535507
# PrimalInfeasible objective -0.0225355066 - 353 iterations time 0.022, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7a46aa9d1db7476e823ca2dbaac21a7f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/7a46aa9d1db7476e823ca2dbaac21a7f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 2.0562283 (2)
# 43  Obj -0.0038199323 Primal inf 383.21907 (233)
# 87  Obj -0.0072978414 Primal inf 967.36735 (216)
# 133  Obj -0.011167613 Primal inf 372.08401 (209)
# 177  Obj -0.014905346 Primal inf 442.83785 (177)
# 223  Obj -0.017259074 Primal inf 136.25863 (128)
# 272  Obj -0.021221409 Primal inf 196.19409 (120)
# 283  Obj -0.036988442 Primal inf 4009.3626 (193)
# Primal infeasible - objective value -0.036988442
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.037109526, infeasibilities - dual 0.0059741995 (117), primal 182.62957 (225)
# Perturbing problem by 1e-08% of 0.027446915 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.058128663 Primal inf 11582.232 (237) Dual inf 0.18900482 (1)
# 0  Obj -0.058128663 Primal inf 11582.232 (237) Dual inf 6.1965742e+14 (119)
# 76  Obj -0.025361285 Primal inf 0.11968681 (1)
# Primal infeasible - objective value -0.025361285
# PrimalInfeasible objective -0.0253612855 - 359 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/afe8410e7a0a458b845d59d5dcf0d362-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/afe8410e7a0a458b845d59d5dcf0d362-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 2.1633023 (2)
# 43  Obj -0.0040116755 Primal inf 495.73664 (215)
# 90  Obj -0.0082875518 Primal inf 2016.3876 (199)
# 133  Obj -0.011465861 Primal inf 74.379084 (140)
# 182  Obj -0.01586572 Primal inf 136.4157 (156)
# 227  Obj -0.018405416 Primal inf 45.639264 (108)
# 276  Obj -0.10128095 Primal inf 4958.485 (182)
# Primal infeasible - objective value -0.10128095
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.10117856, infeasibilities - dual 0.0063480934 (123), primal 213.4996 (215)
# Perturbing problem by 1e-08% of 0.027446915 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.18697039 Primal inf 12499.906 (225) Dual inf 0.77146562 (1)
# 0  Obj -0.18697039 Primal inf 12499.906 (225) Dual inf 5.9811222e+14 (113)
# 88  Obj -0.028264225 Primal inf 0.14958005 (1)
# Primal infeasible - objective value -0.028264225
# PrimalInfeasible objective -0.02826422501 - 364 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/57830d7530eb47c48fe5b8909f2ec165-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/57830d7530eb47c48fe5b8909f2ec165-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 4.987799e-05 ( 7.1574397%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 2.2703762 (2)
# 43  Obj -0.0040463823 Primal inf 3111.016 (240)
# 87  Obj -0.007778183 Primal inf 195.24667 (208)
# 129  Obj -0.011584509 Primal inf 1224.1026 (203)
# 175  Obj -0.016124719 Primal inf 430.34543 (184)
# 221  Obj -0.019147981 Primal inf 307.09592 (174)
# 272  Obj -0.092028604 Primal inf 6470.5838 (190)
# 276  Obj -0.1280164 Primal inf 6077.2641 (182)
# Primal infeasible - objective value -0.1280164
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.12800345, infeasibilities - dual 0.0063282122 (123), primal 258.49877 (215)
# Perturbing problem by 1e-08% of 0.027446915 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.22182817 Primal inf 13824.845 (221) Dual inf 0.84370044 (1)
# 0  Obj -0.22182817 Primal inf 13824.845 (221) Dual inf 5.9804925e+14 (111)
# 88  Obj -0.03237708 Primal inf 0.23154393 (1) Dual inf 7.0876254e+08 (1)
# 96  Obj -0.031218879 Primal inf 0.17947329 (1)
# Primal infeasible - objective value -0.031218879
# PrimalInfeasible objective -0.03121887874 - 372 iterations time 0.022, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b0bc49f89f3c457482429baaddc17d6a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b0bc49f89f3c457482429baaddc17d6a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 8 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.377452 (2)
# 35  Obj -0.0039004406 Primal inf 545.59114 (232)
# 78  Obj -0.0075862387 Primal inf 206.25379 (210)
# 123  Obj -0.011907354 Primal inf 465.20772 (226)
# 172  Obj -0.017236927 Primal inf 1296.4085 (239)
# 221  Obj -0.02013065 Primal inf 74.195844 (120)
# 282  Obj -0.028242375 Primal inf 117.48905 (113)
# 292  Obj -0.029854626 Primal inf 61.678871 (91)
# Primal infeasible - objective value -0.029854626
# PrimalInfeasible objective -0.02985462633 - 292 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/82b23abab259488cb3032fed223b10ef-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/82b23abab259488cb3032fed223b10ef-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.484526 (2)
# 35  Obj -0.0040954627 Primal inf 572.8825 (232)
# 78  Obj -0.0079655506 Primal inf 216.55468 (210)
# 123  Obj -0.012502722 Primal inf 488.45631 (226)
# 172  Obj -0.018098773 Primal inf 1361.2407 (239)
# 221  Obj -0.021137182 Primal inf 77.917435 (120)
# 283  Obj -0.030874354 Primal inf 126.80155 (112)
# 290  Obj -0.031953104 Primal inf 72.653875 (100)
# Primal infeasible - objective value -0.031953104
# PrimalInfeasible objective -0.0319531036 - 290 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0e32c0d1b79c48f2871bc0a2af6edc83-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/0e32c0d1b79c48f2871bc0a2af6edc83-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.5915999 (2)
# 35  Obj -0.0042904847 Primal inf 600.17386 (232)
# 78  Obj -0.0083448626 Primal inf 226.85557 (210)
# 123  Obj -0.01309809 Primal inf 511.7049 (226)
# 172  Obj -0.018960619 Primal inf 1426.073 (239)
# 221  Obj -0.022143715 Primal inf 81.639027 (120)
# 285  Obj -0.033200288 Primal inf 102.8953 (112)
# 291  Obj -0.03406693 Primal inf 83.85117 (100)
# Primal infeasible - objective value -0.03406693
# PrimalInfeasible objective -0.03406693023 - 291 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f12248ff8aaa4e53be056dde19d2f060-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/f12248ff8aaa4e53be056dde19d2f060-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.6986739 (2)
# 35  Obj -0.0044855067 Primal inf 627.46521 (232)
# 78  Obj -0.0087241745 Primal inf 237.15646 (210)
# 123  Obj -0.013693457 Primal inf 534.95349 (226)
# 172  Obj -0.019822466 Primal inf 1490.9052 (239)
# 221  Obj -0.023150247 Primal inf 85.360618 (120)
# 286  Obj -0.03528493 Primal inf 114.29264 (110)
# 291  Obj -0.036180757 Primal inf 95.048465 (100)
# Primal infeasible - objective value -0.036180757
# PrimalInfeasible objective -0.03618075686 - 291 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/635de512b9ff4d91bed994ae3ad40d3a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/635de512b9ff4d91bed994ae3ad40d3a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.8057479 (2)
# 35  Obj -0.0046805288 Primal inf 654.75657 (232)
# 78  Obj -0.0091034864 Primal inf 247.45736 (210)
# 123  Obj -0.014288825 Primal inf 558.20208 (226)
# 172  Obj -0.020684312 Primal inf 1555.7374 (239)
# 221  Obj -0.02415678 Primal inf 89.08221 (120)
# 286  Obj -0.037797798 Primal inf 118.30053 (106)
# 288  Obj -0.038261525 Primal inf 106.27403 (102)
# Primal infeasible - objective value -0.038261525
# PrimalInfeasible objective -0.03826152539 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/eebfce03d3f1449b8389d858bc0ca649-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/eebfce03d3f1449b8389d858bc0ca649-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.9128218 (2)
# 35  Obj -0.0048755508 Primal inf 682.04793 (232)
# 78  Obj -0.0094827984 Primal inf 257.75825 (210)
# 123  Obj -0.014884193 Primal inf 581.45066 (226)
# 172  Obj -0.021546158 Primal inf 1620.5696 (239)
# 221  Obj -0.025163312 Primal inf 92.803801 (120)
# 286  Obj -0.039872969 Primal inf 130.60485 (106)
# 288  Obj -0.04037835 Primal inf 117.49731 (102)
# Primal infeasible - objective value -0.04037835
# PrimalInfeasible objective -0.04037834963 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5910c496b23547299079eafa51899acc-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/5910c496b23547299079eafa51899acc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 3.0198958 (2)
# 35  Obj -0.0050705728 Primal inf 709.33928 (232)
# 78  Obj -0.0098621103 Primal inf 268.05914 (210)
# 123  Obj -0.01547956 Primal inf 604.69925 (226)
# 172  Obj -0.022408005 Primal inf 1685.4019 (239)
# 221  Obj -0.026169845 Primal inf 96.525393 (120)
# 286  Obj -0.041948141 Primal inf 142.90917 (106)
# 288  Obj -0.042495174 Primal inf 128.72058 (102)
# Primal infeasible - objective value -0.042495174
# PrimalInfeasible objective -0.04249517387 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d878933e90664781b6949c2b1ae0f1fa-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/d878933e90664781b6949c2b1ae0f1fa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 3.1269698 (2)
# 35  Obj -0.0052655949 Primal inf 736.63064 (232)
# 78  Obj -0.010241422 Primal inf 278.36003 (210)
# 123  Obj -0.016074928 Primal inf 627.94784 (226)
# 172  Obj -0.023269851 Primal inf 1750.2341 (239)
# 221  Obj -0.027176377 Primal inf 100.24698 (120)
# 286  Obj -0.044023312 Primal inf 155.21349 (106)
# 288  Obj -0.044611998 Primal inf 139.94386 (102)
# Primal infeasible - objective value -0.044611998
# PrimalInfeasible objective -0.04461199811 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/17cc830b05b3467d87cf16f6811fba37-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/17cc830b05b3467d87cf16f6811fba37-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# ...
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 4.5189314 (2)
# 35  Obj -0.0078008813 Primal inf 1091.4183 (232)
# 78  Obj -0.015172477 Primal inf 412.27163 (210)
# 123  Obj -0.023814708 Primal inf 930.17949 (226)
# 172  Obj -0.034473854 Primal inf 2593.053 (239)
# 221  Obj -0.040261299 Primal inf 148.62767 (120)
# 281  Obj -0.068328409 Primal inf 492.69435 (142)
# 289  Obj -0.073103856 Primal inf 281.9255 (112)
# Primal infeasible - objective value -0.073103856
# PrimalInfeasible objective -0.07310385574 - 289 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6428c9730e8242a1a3c05bc18c179746-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6428c9730e8242a1a3c05bc18c179746-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 4.6260054 (2)
# 35  Obj -0.0079959033 Primal inf 1118.7096 (232)
# 78  Obj -0.015551789 Primal inf 422.57252 (210)
# 123  Obj -0.024410076 Primal inf 953.42808 (226)
# 172  Obj -0.0353357 Primal inf 2657.8852 (239)
# 221  Obj -0.041267832 Primal inf 152.34926 (120)
# 281  Obj -0.070305414 Primal inf 512.07617 (142)
# 289  Obj -0.07525557 Primal inf 293.21891 (112)
# Primal infeasible - objective value -0.07525557
# PrimalInfeasible objective -0.07525557038 - 289 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/77019bf0be684beb8778aa360aeab3af-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/77019bf0be684beb8778aa360aeab3af-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 4.7330793 (2)
# 35  Obj -0.0081909254 Primal inf 1146.001 (232)
# 78  Obj -0.015931101 Primal inf 432.87341 (210)
# 123  Obj -0.025005444 Primal inf 976.67667 (226)
# 172  Obj -0.036197546 Primal inf 2722.7175 (239)
# 221  Obj -0.042274364 Primal inf 156.07086 (120)
# 281  Obj -0.073491286 Primal inf 523.53255 (139)
# 288  Obj -0.077326308 Primal inf 305.03923 (113)
# Primal infeasible - objective value -0.077326308
# PrimalInfeasible objective -0.07732630756 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/bcfdaeb78d8f4619ad974304525cc5cb-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/bcfdaeb78d8f4619ad974304525cc5cb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 4.8401533 (2)
# 35  Obj -0.0083859474 Primal inf 1173.2924 (232)
# 78  Obj -0.016310413 Primal inf 443.1743 (210)
# 123  Obj -0.025600811 Primal inf 999.92526 (226)
# 172  Obj -0.037059393 Primal inf 2787.5497 (239)
# 221  Obj -0.043280897 Primal inf 159.79245 (120)
# 281  Obj -0.075509366 Primal inf 542.64505 (139)
# 288  Obj -0.079475403 Primal inf 316.36816 (115)
# Primal infeasible - objective value -0.079475403
# PrimalInfeasible objective -0.07947540345 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6479f745193641698c141f55918b8913-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6479f745193641698c141f55918b8913-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 4.9472273 (2)
# 35  Obj -0.0085809694 Primal inf 1200.5837 (232)
# 78  Obj -0.016689725 Primal inf 453.47519 (210)
# 123  Obj -0.026196179 Primal inf 1023.1738 (226)
# 172  Obj -0.037921239 Primal inf 2852.3819 (239)
# 221  Obj -0.044287429 Primal inf 163.51404 (120)
# 281  Obj -0.077527447 Primal inf 561.75755 (139)
# 288  Obj -0.081624499 Primal inf 327.70066 (115)
# Primal infeasible - objective value -0.081624499
# PrimalInfeasible objective -0.08162449935 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/16fdf5303d8a429eba7d131de46e7601-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/16fdf5303d8a429eba7d131de46e7601-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 5.0543012 (2)
# 35  Obj -0.0087759914 Primal inf 1227.8751 (232)
# 78  Obj -0.017069037 Primal inf 463.77609 (210)
# 123  Obj -0.026791547 Primal inf 1046.4224 (226)
# 172  Obj -0.038783085 Primal inf 2917.2141 (239)
# 221  Obj -0.045293962 Primal inf 167.23563 (120)
# 281  Obj -0.079545527 Primal inf 580.87137 (141)
# 288  Obj -0.083773595 Primal inf 339.03316 (115)
# Primal infeasible - objective value -0.083773595
# PrimalInfeasible objective -0.08377359524 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c54ef4ab1b914e42bbceb1f593d7808b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c54ef4ab1b914e42bbceb1f593d7808b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 5.1613752 (2)
# 35  Obj -0.0089710135 Primal inf 1255.1664 (232)
# 78  Obj -0.017448349 Primal inf 474.07698 (210)
# 123  Obj -0.027386915 Primal inf 1069.671 (226)
# 172  Obj -0.039644932 Primal inf 2982.0464 (239)
# 221  Obj -0.046300494 Primal inf 170.95722 (120)
# 281  Obj -0.081563608 Primal inf 600.01195 (143)
# 288  Obj -0.085922691 Primal inf 350.36566 (115)
# Primal infeasible - objective value -0.085922691
# PrimalInfeasible objective -0.08592269113 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c5812d13142c44ac8ca27f761e25394b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c5812d13142c44ac8ca27f761e25394b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 5.2684492 (2)
# 35  Obj -0.0091660355 Primal inf 1282.4578 (232)
# 78  Obj -0.017827661 Primal inf 484.37787 (210)
# 123  Obj -0.027982282 Primal inf 1092.9196 (226)
# 172  Obj -0.040506778 Primal inf 3046.8786 (239)
# 221  Obj -0.047307027 Primal inf 174.67881 (120)
# 281  Obj -0.083581689 Primal inf 619.15816 (145)
# 288  Obj -0.088071787 Primal inf 361.69817 (115)
# Primal infeasible - objective value -0.088071787
# PrimalInfeasible objective -0.08807178703 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9170d900c71341c082c21b10109284ed-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/9170d900c71341c082c21b10109284ed-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 5.3755232 (2)
# 35  Obj -0.0093610575 Primal inf 1309.7491 (232)
# 78  Obj -0.018206973 Primal inf 494.67876 (210)
# 123  Obj -0.02857765 Primal inf 1116.1682 (226)
# 172  Obj -0.041368624 Primal inf 3111.7108 (239)
# 221  Obj -0.048313559 Primal inf 178.4004 (120)
# 281  Obj -0.085599769 Primal inf 638.31229 (145)
# 288  Obj -0.090220883 Primal inf 373.03067 (115)
# Primal infeasible - objective value -0.090220883
# PrimalInfeasible objective -0.09022088292 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/15fa094b9a7f4062969438662ec05b21-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/15fa094b9a7f4062969438662ec05b21-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446915 - largest nonzero change 5.0242082e-06 ( 0.71795641%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 5.4825971 (2)
# 35  Obj -0.0095560796 Primal inf 1337.0405 (232)
# 78  Obj -0.018586285 Primal inf 504.97965 (210)
# 123  Obj -0.029173018 Primal inf 1139.4168 (226)
# 172  Obj -0.042230471 Primal inf 3176.543 (239)
# 221  Obj -0.049320092 Primal inf 182.122 (120)
# 281  Obj -0.08761785 Primal inf 657.46642 (145)
# 288  Obj -0.092369979 Primal inf 384.36317 (115)
# Primal infeasible - objective value -0.092369979
# PrimalInfeasible objective -0.09236997881 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Infeasible
# Optimal Portfolio Weights:
# x0: 0.0
# x1: 0.0
# x2: -8.0052879
# x3: 9.0052879
# x4: 0.0
# x5: 0.0
# expected return (MAD): 0.009999999976964755
# Mean Absolute Deviation (MAD): 0.09227462855059765

# %%
risk_array
# Out:
# array([0.05301182, 0.00736559, 0.00681976, 0.00677462, 0.00688481,
#        0.00717425, 0.00762216, 0.00820221, 0.00891404, 0.00969074,
#        0.01053332, 0.01163577, 0.01311221, 0.01505304, 0.01729401,
#        0.0194633 , 0.02253551, 0.02536129, 0.02826422, 0.03121888,
#        0.02982414, 0.03192041, 0.03403202, 0.03614364, 0.03822219,
#        0.0403368 , 0.04245141, 0.04456603, 0.04668064, 0.04879525,
#        0.05090986, 0.05302447, 0.05519612, 0.05731558, 0.05943505,
#        0.06155451, 0.06367398, 0.06579344, 0.06872959, 0.07087907,
#        0.07302855, 0.07517803, 0.07724659, 0.07939345, 0.08154031,
#        0.08368718, 0.08583404, 0.0879809 , 0.09012777, 0.09227463])

# %%
plt.figure()
plt.plot(risk_array, m0_array)

for i, stock in enumerate(assets):
    plt.annotate(stock, (risk_array[i], m0_array[i]), textcoords="offset points", xytext=(10,0), ha='center')
    
for i, stock in enumerate(assets):
    plt.scatter(risk_array[i], m0_array[i], label=stock)
plt.xlabel('Risk (Mean Absolute Deviation)')
plt.ylabel('Expected Return')
plt.title('Efficient Frontier')
# Out:
# Text(0.5, 1.0, 'Efficient Frontier')

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods
mu = 1
print(n,T,mu)

m0_array = np.linspace(0.0,0.01,50)
risk_array = 0. * m0_array
i = 0
for i in range(len(m0_array)):
    n = len(assets)  # Number of assets
    T = len(R[:,0])  # Number of time periods
    mu = 1
    r0 = m0_array[i]
    
    # Create a LP problem
    prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

    # Define decision variables
    x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
    y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

    # Define objective function
    prob += lpSum(r[j] * x[j] for j in range(n)) * mu - (1/T) * lpSum(y[t] for t in range(T)), "Objective"

    # Define constraints
    for t in range(T):
        prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
        prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

    prob += lpSum(x) == 1, "Sum_of_weights"

    # Solve the problem
    prob.solve()
    risk_array[i] = value( (1/T) * lpSum(y[t] for t in range(T)))

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 1
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7d9daf070d004ddb9c7a837988c6edbd-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/7d9daf070d004ddb9c7a837988c6edbd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/25904627278444048b8406887a86bac7-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/25904627278444048b8406887a86bac7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7db043aabd53410d80a03dd7a32d0117-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/7db043aabd53410d80a03dd7a32d0117-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.06
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/774ee8a46a91492182a277719af9764e-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/774ee8a46a91492182a277719af9764e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1d03ab719dba430793fd1729d44326f3-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1d03ab719dba430793fd1729d44326f3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/bdb2ef581fbe44ca958ba0a320d4df40-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/bdb2ef581fbe44ca958ba0a320d4df40-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0545491161f844dfb76c97b677615e7c-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/0545491161f844dfb76c97b677615e7c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3e62057550b54e95852baf3ef3a561f8-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/3e62057550b54e95852baf3ef3a561f8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/53365cdddecb4ac78db6ba9dd2d07311-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/53365cdddecb4ac78db6ba9dd2d07311-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/69cf0ad14d174e7a9f9d618c3c394361-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/69cf0ad14d174e7a9f9d618c3c394361-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/05234b8010a14cf88da7dae7041b8e2f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/05234b8010a14cf88da7dae7041b8e2f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/8801b11552f3415f96c1659284b669aa-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/8801b11552f3415f96c1659284b669aa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e8793613d60d49fa82490465a0e5d32b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/e8793613d60d49fa82490465a0e5d32b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/28a79cc9415849a09d804ca2093a5c8c-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/28a79cc9415849a09d804ca2093a5c8c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/a10c63de89304668b41b40ead951eb6e-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/a10c63de89304668b41b40ead951eb6e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f598dbd436bc478a86e45536ee2cd273-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/f598dbd436bc478a86e45536ee2cd273-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5c4624d673c74ef0a84462ffeb9c62e2-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/5c4624d673c74ef0a84462ffeb9c62e2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e4ec79ac58154db790b1273d84e4219a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/e4ec79ac58154db790b1273d84e4219a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4fd62486e217478bbd7c3bbe771a3ed4-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4fd62486e217478bbd7c3bbe771a3ed4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/aa6a8f1ca89c4e228648d45582705e6a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/aa6a8f1ca89c4e228648d45582705e6a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b9f6b6367adc4c9894e21598abec83a1-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b9f6b6367adc4c9894e21598abec83a1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/196f029eedc3408a991ab1cf7fe50a5c-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/196f029eedc3408a991ab1cf7fe50a5c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0f98a40991b345ea9014eb6c06c4dfd3-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/0f98a40991b345ea9014eb6c06c4dfd3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/66ae9a120b5b438199509501a7c26c35-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/66ae9a120b5b438199509501a7c26c35-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/a158c618685741338c733893cba835bb-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/a158c618685741338c733893cba835bb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/296167eed1234640a48e95425594fc71-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/296167eed1234640a48e95425594fc71-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1a41ac98648e43718a3f48b82bce9497-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1a41ac98648e43718a3f48b82bce9497-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/846f2253d0344b9cab419c1d130ec09d-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/846f2253d0344b9cab419c1d130ec09d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/a22b846cd4c64ce3aa947834641dc3e0-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/a22b846cd4c64ce3aa947834641dc3e0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/fb6a87876c504811875d21622aa9699f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/fb6a87876c504811875d21622aa9699f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/be6644e0c8254e69a09ebdb5f0066b29-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/be6644e0c8254e69a09ebdb5f0066b29-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/54d67d5d041a411ebd5e3c6ac9124169-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/54d67d5d041a411ebd5e3c6ac9124169-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# ...
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b21d1441d4f348358561e33996aa4f78-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b21d1441d4f348358561e33996aa4f78-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d01d37e2fbb1446e84ec9bfd3a2a7870-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/d01d37e2fbb1446e84ec9bfd3a2a7870-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/407c00894b8746ae8ba9d8bd71274abc-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/407c00894b8746ae8ba9d8bd71274abc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/36efe9fcaaf24da29eb87a81d02e821f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/36efe9fcaaf24da29eb87a81d02e821f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/11e1e953476140c6a8cf02af0c0d5efc-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/11e1e953476140c6a8cf02af0c0d5efc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9b55e64f82374085bb57251bcf4fe2ce-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/9b55e64f82374085bb57251bcf4fe2ce-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0e153e857fa34d5cb9ec7ffd5c504a4c-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/0e153e857fa34d5cb9ec7ffd5c504a4c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.05
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/13a819cb74dc4c41b93f408db3acd3c8-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/13a819cb74dc4c41b93f408db3acd3c8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9402d0a1dbeb46d0847157dad7840b42-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/9402d0a1dbeb46d0847157dad7840b42-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/bd228f12edad4cfb8cadcfad6d93426a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/bd228f12edad4cfb8cadcfad6d93426a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027921212 - largest nonzero change 8.1754641e-05 ( 24.953897%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597179 (1) Dual inf 0.050634038 (6)
# 68  Obj -0.0010263053 Primal inf 238.29578 (221)
# 117  Obj -0.0026911093 Primal inf 97.791683 (190)
# 165  Obj -0.0042247087 Primal inf 263.01798 (239)
# 208  Obj -0.0054947366 Primal inf 146.47002 (167)
# 258  Obj -0.0060990438 Primal inf 1.7920571 (34)
# 272  Obj -0.0061227866
# 272  Obj -0.0060655178 Dual inf 0.00036436565 (1)
# 273  Obj -0.0060654975
# Optimal - objective value -0.0060654975
# After Postsolve, objective -0.0060654975, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065497538 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.049674917
# x1: 0.5656547
# x2: 0.23711883
# x3: 0.056276425
# x4: 0.091275124
# x5: 0.0
# expected return (MAD): 0.0008426022786864088
# Mean Absolute Deviation (MAD): 0.00690809982589004

# %%
plt.figure()
plt.plot(risk_array, m0_array)

for i, stock in enumerate(assets):
    plt.annotate(stock, (risk_array[i], m0_array[i]), textcoords="offset points", xytext=(10,0), ha='center')
    
for i, stock in enumerate(assets):
    plt.scatter(risk_array[i], m0_array[i], label=stock)
plt.xlabel('Risk (Mean Absolute Deviation)')
plt.ylabel('Expected Return')
plt.title('Efficient Frontier')
# Out:
# Text(0.5, 1.0, 'Efficient Frontier')

# %% [markdown]
# # Now we consider risk as total variance of the portfolio, all these models are model 2x

# %% [markdown]
# # model 2A
# when we minimize variance under a specified expected return $r_0$
# $$
# \begin{gathered}
# \operatorname{maximize} -\frac{1}{T} \sum_{t=1}^T\left(\sum_j x_j\left(R_j(t)-r_j\right)\right)^2 \\
# \text { subject to } \sum_j x_j=1 \\
#   \sum_j x_j r_j = r_0 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$

# %%
# centered return
R_c = 0. * R
for j in range(len(R[0,:])):
  R_c[:,j] = R[:,j] - r[j]

#print(np.outer(R_c[0,:],R_c[0,:]))
R_c.T @ R_c

# compute the convariance matrix manually
sig = 0. * S
for i in range(len(R[:,0])):
  sig = sig + np.outer(R_c[i,:],R_c[i,:])
sig = sig / T


r0 = 0.0005
n = len(R[0,:])
e = np.ones((n,1))
rq = r.reshape(n,1)

X = cp.Variable((n,1))
Objective = cp.Minimize(cp.quad_form(X,sig))
constraints = [e.T@X == 1, X >= 0, rq.T@X >= r0]
problem = cp.Problem(Objective,constraints)

result = problem.solve()

print("expected portfolio", X.value.T)
print("expected return :", (rq.T @ X.value)[0] )
print("Mean variance:", (X.value.T @ sig @ X.value)[0] )
X
# Out:
# expected portfolio [[ 2.58228017e-01  4.82486166e-01  1.74084311e-01  1.68322573e-02
#    6.83692490e-02 -2.82601648e-19]]
# expected return : [0.00062784]
# Mean variance: [8.15804821e-05]
# Variable((6, 1), var1)

# %% [markdown]
# ## Optimization Problem
#
# Choose a risk tolerance $q > 0$:
#
# \begin{align*}
# \text{minimize:} \ \ & \mathbf{x}^T \Sigma \mathbf{x} - q \mathbf{r}^T \mathbf{x} \\
# \text{subject to:} \ \ & \mathbf{e}^T \mathbf{x} = 1 \\
# & \mathbf{x} \geq 0 \\
# \end{align*}

# %%
n = len(assets)
q = 0.1
e = np.ones(n)
X = cp.Variable(n)

obj = cp.Minimize(cp.quad_form(X,S) - q*r@X)
constraints = [e@X == 1, X >= 0]
problem = cp.Problem(obj,constraints)

result = problem.solve()
X.value
# Out:
# array([1.71503988e-23, 1.81513034e-01, 4.26124625e-01, 1.87604561e-01,
#        2.04757779e-01, 2.94208997e-25])

# %% [markdown]
# ## Optimization Problem
#
# \begin{align*}
# \text{minimize:} \ \ & \mathbf{x}^T \Sigma \mathbf{x} \\
# \text{subject to:} \ \ & \mathbf{e}^T \mathbf{x} = 1 \\
# & \mathbf{r}^T \mathbf{x} = \mu \\
# & \mathbf{x} \geq 0 \\
# \end{align*}

# %% [markdown]
# case mu = 0.01,   minimize risk sigma = 0.001
#
# case mu = 0.02,  minimize risk sigma = 0.003
#
# case mu = 0.05,  minimize risk  sigma = 0.010

# %%
n = len(assets)
e = np.ones((n,1))
r = r.reshape(n,1)
mu = 0.001

M = np.block([[2*S,-r,-e],[r.T,0,0],[e.T,0,0]])
b = np.block([[np.zeros((n,1))],[mu],[1]])

x = la.solve(M,b)
