# %%
# !pip install pulp
# !pip install yfinance
# Out:
# Requirement already satisfied: pulp in /opt/conda/lib/python3.10/site-packages (2.7.0)
# Requirement already satisfied: yfinance in /opt/conda/lib/python3.10/site-packages (0.2.37)
# Requirement already satisfied: appdirs>=1.4.4 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/conda/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: html5lib>=1.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: peewee>=3.16.2 in /opt/conda/lib/python3.10/site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: pandas>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: lxml>=4.9.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: pytz>=2022.5 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2.4.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.1.1)

# %%
# !pip install cvxpy
import cvxpy as cp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pulp
import scipy.linalg as la
import yfinance as yf
# Out:
# Requirement already satisfied: cvxpy in /opt/conda/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: clarabel>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (0.7.1)
# Requirement already satisfied: ecos>=2 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (2.0.13)
# Requirement already satisfied: osqp>=0.6.2 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (0.6.5)
# Requirement already satisfied: pybind11 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (2.12.0)
# Requirement already satisfied: scs>=3.0 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (3.2.4.post1)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (1.10.0)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (1.23.5)
# Requirement already satisfied: qdldl in /opt/conda/lib/python3.10/site-packages (from osqp>=0.6.2->cvxpy) (0.1.7.post1)

# %% [markdown]
# ## how we load data from yahoo finance

# %% [markdown]
# #### Stock data

# %%
T = 1  # Number of days in time period
R = []
assets = ["AAPL", "EA", "MSFT", "NFLX", "GOOGL", "TSLA"]

for stock in assets:
    data = yf.Ticker(stock)
    # 我先改成1年， 这个之后可以随时改成想要的时段
    df = data.history(period="1y")

    # close values on that day
    close = df["Close"].values

    # convert day to day close values to return
    returns = (close[T:] - close[:-T]) / close[:-T]
    R.append(returns)

R = np.array(R).T
r = np.mean(R, axis=0)
S = np.cov(R.T)

# %%
R
# Out:
# array([[-0.00435327,  0.00358043,  0.00233369, -0.02122939, -0.00673943,
#         -0.03346004],
#        [ 0.03410371,  0.01704598,  0.02239938,  0.04579646,  0.02666285,
#          0.02968872],
#        [-0.00211396, -0.00319608, -0.0127656 , -0.02183771,  0.0134041 ,
#         -0.00484128],
#        ...,
#        [-0.00666355, -0.00222575, -0.00218554, -0.01221356,  0.01540988,
#          0.04899941],
#        [ 0.00724251,  0.00530771,  0.00398032, -0.01624729,  0.01130126,
#          0.02254601],
#        [-0.01113927, -0.01063585, -0.00708452,  0.0006147 , -0.00293746,
#         -0.02894624]])

# %%
# Create a single plot for all stocks
plt.figure(figsize=(10, 6))

# Plot price evolution of each stock
for stock in assets:
    data = yf.Ticker(stock)
    df = data.history(period="1y")
    plt.plot(df.index, df["Open"], label=stock)

plt.xlabel("Date")
plt.ylabel("Price")
plt.title("Price Evolution of Stocks")
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## tesla in past 1 years

# %%
# last df is Tesla
df["Open"].plot()
plt.show()

# %% [markdown]
# ## histogram of Tesla in past 1 years

# %%
return_TSLA = R[:, -1]
plt.hist(return_TSLA, bins=50)
plt.show()

# %%
r
# Out:
# array([0.00026376, 0.0001986 , 0.00173443, 0.00265228, 0.0017161 ,
#        0.00012128])

# %%
S
# Out:
# array([[1.46795035e-04, 4.51281958e-05, 8.14892342e-05, 9.54640138e-05,
#         9.41011910e-05, 1.32531661e-04],
#        [4.51281958e-05, 1.24669199e-04, 3.91245121e-05, 4.06778348e-05,
#         3.81256715e-05, 9.03957737e-05],
#        [8.14892342e-05, 3.91245121e-05, 1.90445179e-04, 1.22598620e-04,
#         9.90208073e-05, 1.07310873e-04],
#        [9.54640138e-05, 4.06778348e-05, 1.22598620e-04, 5.03095045e-04,
#         1.14351464e-04, 1.24975462e-04],
#        [9.41011910e-05, 3.81256715e-05, 9.90208073e-05, 1.14351464e-04,
#         2.93251399e-04, 1.35635291e-04],
#        [1.32531661e-04, 9.03957737e-05, 1.07310873e-04, 1.24975462e-04,
#         1.35635291e-04, 9.08183849e-04]])

# %% [markdown]
# # We consider risk as MAD first, all these models are model 1x

# %% [markdown]
# # model 1A
# when we minimize MAD under a specified expected return $r_0$
# $$
# \begin{gathered}
# \operatorname{maximize} -\frac{1}{T} \sum_{t=1}^T\left|\sum_j x_j\left(R_j(t)-r_j\right)\right| \\
# \text { subject to } \sum_j x_j=1 \\
#   \sum_j x_j r_j = r_0 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$
#
# The LP version is
# $$
# \begin{gathered}
# & \operatorname{maximize} -\frac{1}{T} \sum_{t=1}^T y_t \\
# & \text { subject to }-y_t \leq \sum_j x_j\left(R_j(t)-r_j\right) \leq y_t \quad t=1,2, \ldots, T \text {, } \\
# & \sum_j x_j=1 \\
# &  \sum_j x_j r_j = r_0 \\
# & x_j \geq 0 \quad j=1,2, \ldots, n, \\
# & r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:, 0])  # Number of time periods
r0 = 0.0008
print(n, T, r0)


# Create a LP problem
prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

# Define decision variables
x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

# Define objective function
prob += -(1 / T) * lpSum(y[t] for t in range(T)), "Objective"

# Define constraints
for t in range(T):
    prob += (
        lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t],
        f"Upper_constraint_{t}",
    )
    prob += (
        lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t],
        f"Lower_constraint_{t}",
    )

prob += lpSum(r[j] * x[j] for j in range(n)) == r0

prob += lpSum(x) == 1, "Sum_of_weights"

# Solve the problem
prob.solve()

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value((1 / T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 0.0008
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/8417f573b44a466ea83e728133536925-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/8417f573b44a466ea83e728133536925-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.066355703
# x1: 0.56828344
# x2: 0.23261362
# x3: 0.040996853
# x4: 0.091750385
# x5: 0.0
# expected return (MAD): 0.0008000000055305188
# Mean Absolute Deviation (MAD): 0.006870764865438248

# %% [markdown]
# # model 1B
# when we maximize return under a specified MAD constrait $m_0$
# $$
# \begin{gathered}
# \operatorname{maximize} \sum_j x_j r_j  \\
# \text { subject to } \sum_j x_j=1 \\
#   \frac{1}{T} \sum_{t=1}^T\left|\sum_j x_j\left(R_j(t)-r_j\right)\right| \leq m_0 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$
#
# The LP version is
# $$
# \begin{gathered}
# & \operatorname{maximize}  \sum_j x_j r_j   \\
# & \text { subject to }-y_t \leq \sum_j x_j\left(R_j(t)-r_j\right) \leq y_t \quad t=1,2, \ldots, T \text {, } \\
# & \sum_j x_j=1 \\
# & \frac{1}{T} \sum_{t=1}^T y_t \leq m_0  \\
# & x_j \geq 0 \quad j=1,2, \ldots, n, \\
# & r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:, 0])  # Number of time periods
m0 = 0.007
print(n, T, r0)


# Create a LP problem
prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

# Define decision variables
x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

# Define objective function
prob += lpSum(r[j] * x[j] for j in range(n)), "Objective"

# Define constraints
for t in range(T):
    prob += (
        lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t],
        f"Upper_constraint_{t}",
    )
    prob += (
        lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t],
        f"Lower_constraint_{t}",
    )

prob += (1 / T) * lpSum(y[t] for t in range(T)) <= m0, "Risk"

prob += lpSum(x) == 1, "Sum_of_weights"

# Solve the problem
prob.solve()

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value((1 / T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 0.0008
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3e3edac9acfc472381ad3d45e42fb889-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/3e3edac9acfc472381ad3d45e42fb889-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3771 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3358 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 0.00012071587 ( 26.772391%) - largest zero change 9.9738264e-05
# 0  Obj -0 Primal inf 11.586551 (2) Dual inf 0.050520451 (6)
# 59  Obj 0.0046719868 Primal inf 114.03008 (207)
# 94  Obj 0.0028145892 Primal inf 454.49011 (224)
# 134  Obj 0.0019046092 Primal inf 137.88174 (195)
# 176  Obj 0.0015037658 Primal inf 22.863909 (134)
# 219  Obj 0.0012395952 Primal inf 69.858194 (168)
# 263  Obj 0.00095550074 Primal inf 12.454773 (84)
# 297  Obj 0.00081065229
# Optimal - objective value 0.00091480764
# After Postsolve, objective 0.00091480764, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.0009148076398 - 297 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.02764802
# x1: 0.54113489
# x2: 0.27074384
# x3: 0.058828877
# x4: 0.10164437
# x5: 0.0
# expected return (MAD): 0.0009148076347440409
# Mean Absolute Deviation (MAD): 0.007000000005681274

# %% [markdown]
# ## model 1C
# when combine return and risk together with $\mu$
#
# $$
# \begin{gathered}
# \operatorname{maximize} \mu \sum_j x_j r_j-\frac{1}{T} \sum_{t=1}^T\left|\sum_j x_j\left(R_j(t)-r_j\right)\right| \\
# \text { subject to } \sum_j x_j=1 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$
#
# The LP version is
# $$
# \begin{aligned}
# & \operatorname{maximize} \mu \sum_j x_j r_j-\frac{1}{T} \sum_{t=1}^T y_t \\
# & \text { subject to }-y_t \leq \sum_j x_j\left(R_j(t)-r_j\right) \leq y_t \quad t=1,2, \ldots, T \text {, } \\
# & \sum_j x_j=1 \\
# & x_j \geq 0 \quad j=1,2, \ldots, n \\
# & y_t \geq 0 \quad t=1,2, \ldots, T . \\
# &
# \end{aligned}
# $$
#
# below is pulp implementation

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:, 0])  # Number of time periods
mu = 1
print(n, T, mu)


# Create a LP problem
prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

# Define decision variables
x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

# Define objective function
prob += (
    lpSum(r[j] * x[j] for j in range(n)) * mu - (1 / T) * lpSum(y[t] for t in range(T)),
    "Objective",
)

# Define constraints
for t in range(T):
    prob += (
        lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t],
        f"Upper_constraint_{t}",
    )
    prob += (
        lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t],
        f"Lower_constraint_{t}",
    )

prob += lpSum(x) == 1, "Sum_of_weights"

# Solve the problem
prob.solve()

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value((1 / T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 1
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/02acf48c8fd2404f8bfe04ccc21ebbbb-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/02acf48c8fd2404f8bfe04ccc21ebbbb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.049674924
# x1: 0.56565469
# x2: 0.23711883
# x3: 0.056276425
# x4: 0.091275124
# x5: 0.0
# expected return (MAD): 0.0008426023820794647
# Mean Absolute Deviation (MAD): 0.006908101997449403

# %% [markdown]
# # Efficient frontier
#
# Let us use model 1B to compute the efficient frontier

# %% [markdown]
# ### 1A Model efficient frontier

# %%
# Define the data
n = len(assets)  # Number of assets
T = len(R[:, 0])  # Number of time periods
r0 = 0.0008
print(n, T, r0)

m0_array = np.linspace(0.0, 0.01, 50)
risk_array = 0.0 * m0_array
i = 0
for i in range(len(m0_array)):
    # Create a LP problem
    prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

    # Define decision variables
    x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
    y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

    # Define objective function
    prob += -(1 / T) * lpSum(y[t] for t in range(T)), "Objective"

    # Define constraints
    for t in range(T):
        prob += (
            lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t],
            f"Upper_constraint_{t}",
        )
        prob += (
            lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t],
            f"Lower_constraint_{t}",
        )

    prob += lpSum(r[j] * x[j] for j in range(n)) == r0

    prob += lpSum(x) == 1, "Sum_of_weights"

    # Solve the problem
    prob.solve()
    risk_array[i] = value((1 / T) * lpSum(y[t] for t in range(T)))

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value((1 / T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 0.0008
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f2e4f54309ec438e8eaed5caf1a17003-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/f2e4f54309ec438e8eaed5caf1a17003-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f39863c8c07b482bb85b7f89fc4c3cb9-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/f39863c8c07b482bb85b7f89fc4c3cb9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/dd7f073598a440129aed62ad464f7211-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/dd7f073598a440129aed62ad464f7211-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6b724c503f8a4e028e0b23813078c6cb-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6b724c503f8a4e028e0b23813078c6cb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e67854b5eaee4d16b47ea4b77eb56340-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/e67854b5eaee4d16b47ea4b77eb56340-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/346293a996554d7f91a1135bcf2b7f29-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/346293a996554d7f91a1135bcf2b7f29-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ccc86b106d814ed3be38966957f62530-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/ccc86b106d814ed3be38966957f62530-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7e7e41aabb3d4eef89932652e45d6626-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/7e7e41aabb3d4eef89932652e45d6626-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c88c2e88948c4c35bc2fc10b03a02c62-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c88c2e88948c4c35bc2fc10b03a02c62-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d7dd32914ed64473b4c66e53bbf5401f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/d7dd32914ed64473b4c66e53bbf5401f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e26be81bb23b444186e8b1a10f8402d4-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/e26be81bb23b444186e8b1a10f8402d4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5d4e24fbd6ab44bfb4883e76e4da4e7b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/5d4e24fbd6ab44bfb4883e76e4da4e7b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6ac3943ec4034ce2b8943174141cdd22-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6ac3943ec4034ce2b8943174141cdd22-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.05
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4de94d7dd9804437a86e7a985711c761-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4de94d7dd9804437a86e7a985711c761-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.06
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/36f5114165ae4270a226d0f5fab6a7b5-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/36f5114165ae4270a226d0f5fab6a7b5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7e01822da68b4c19bc07fcd12f786614-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/7e01822da68b4c19bc07fcd12f786614-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/a36fa139eacf421c9ac9858d0ab1ba94-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/a36fa139eacf421c9ac9858d0ab1ba94-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1ca981f991b5479892eb0fe880d42786-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1ca981f991b5479892eb0fe880d42786-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1f3335745c604c9d89304551e0edbd5a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1f3335745c604c9d89304551e0edbd5a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/62d066a0e9b048d596dfbbe2b2f6e426-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/62d066a0e9b048d596dfbbe2b2f6e426-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1eb2b0ba472b4ffebd88f22d8ed13b8d-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1eb2b0ba472b4ffebd88f22d8ed13b8d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ce050c88e9d34b75b0738d65e0b6ea5e-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/ce050c88e9d34b75b0738d65e0b6ea5e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e202508b271e431992e5110d22185211-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/e202508b271e431992e5110d22185211-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/bce56f1e43634015b8392c31288c4971-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/bce56f1e43634015b8392c31288c4971-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6613b988c1914e178226d2cd5eb6b085-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6613b988c1914e178226d2cd5eb6b085-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c52b3d354bbb4b47838006bebd83a5e3-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c52b3d354bbb4b47838006bebd83a5e3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/08df6edc953945baa044be0dc64f3fdd-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/08df6edc953945baa044be0dc64f3fdd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/65b49517054c4699a045b5d22685d060-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/65b49517054c4699a045b5d22685d060-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/163970554b4b42889813d2f79dec4144-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/163970554b4b42889813d2f79dec4144-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ccaa24430759474f9c2f4856fd4017bb-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/ccaa24430759474f9c2f4856fd4017bb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/fe0b28b6e5e1490fa1e04b27a7756665-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/fe0b28b6e5e1490fa1e04b27a7756665-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5a028f3216864a11a9f086ad7ee7e334-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/5a028f3216864a11a9f086ad7ee7e334-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4136b83e35dd457ba6760666066f4391-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4136b83e35dd457ba6760666066f4391-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/cb2988c1ea9641b6b63a13af0fb00a8e-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/cb2988c1ea9641b6b63a13af0fb00a8e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# ...
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/92ddd69c58af46db81d18fd5a51b3bfd-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/92ddd69c58af46db81d18fd5a51b3bfd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9f77e48b893444b58f20157dd79883e5-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/9f77e48b893444b58f20157dd79883e5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/41d2877d0a8d4c7ca8707e5a0761bfd6-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/41d2877d0a8d4c7ca8707e5a0761bfd6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f611c75a7e5e441aabc12cfe23a8f22b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/f611c75a7e5e441aabc12cfe23a8f22b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/69a34ae90822453785cb1dd18a3aec86-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/69a34ae90822453785cb1dd18a3aec86-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/a9817a07c6b04a3c951e0d316f63a34e-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/a9817a07c6b04a3c951e0d316f63a34e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/cd83faac6f544d91b5af5d703a4e5597-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/cd83faac6f544d91b5af5d703a4e5597-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ecf9d1417e0145f0ad42d1119c3cd36d-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/ecf9d1417e0145f0ad42d1119c3cd36d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e10484b53f2d4979a8d238eb9d7e8c69-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/e10484b53f2d4979a8d238eb9d7e8c69-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9a11e405183b445fbf9c3e919024ede2-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/9a11e405183b445fbf9c3e919024ede2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7590f89e2f464f81b64af085cf230614-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/7590f89e2f464f81b64af085cf230614-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.6557008 (2)
# 45  Obj -0.00090544354 Primal inf 76.036032 (231)
# 92  Obj -0.0022363878 Primal inf 80.278418 (212)
# 139  Obj -0.0034727421 Primal inf 172.06399 (199)
# 188  Obj -0.0052859762 Primal inf 43.900081 (159)
# 239  Obj -0.0064476395 Primal inf 35.105019 (108)
# 292  Obj -0.0069253038
# Optimal - objective value -0.0068707649
# After Postsolve, objective -0.0068707649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006870764878 - 292 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.03
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.066355703
# x1: 0.56828344
# x2: 0.23261362
# x3: 0.040996853
# x4: 0.091750385
# x5: 0.0
# expected return (MAD): 0.0008000000055305188
# Mean Absolute Deviation (MAD): 0.006870764865438248

# %%
plt.figure()
plt.plot(risk_array, m0_array)

for i, stock in enumerate(assets):
    plt.annotate(
        stock,
        (risk_array[i], m0_array[i]),
        textcoords="offset points",
        xytext=(10, 0),
        ha="center",
    )

for i, stock in enumerate(assets):
    plt.scatter(risk_array[i], m0_array[i], label=stock)
plt.xlabel("Risk (Mean Absolute Deviation)")
plt.ylabel("Expected Return")
plt.title("Efficient Frontier")
# Out:
# Text(0.5, 1.0, 'Efficient Frontier')

# %% [markdown]
# ### 1B Model efficient frontier

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:, 0])  # Number of time periods

m0_array = np.linspace(0.0, 0.01, 50)
risk_array = 0.0 * m0_array
i = 0
for i in range(len(m0_array)):
    # Define the data
    n = len(assets)  # Number of assets
    T = len(R[:, 0])  # Number of time periods
    r0 = m0_array[i]

    # Create a LP problem
    prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

    # Define decision variables
    x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
    y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

    # Define objective function
    prob += -(1 / T) * lpSum(y[t] for t in range(T)), "Objective"

    # Define constraints
    for t in range(T):
        prob += (
            lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t],
            f"Upper_constraint_{t}",
        )
        prob += (
            lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t],
            f"Lower_constraint_{t}",
        )

    prob += lpSum(r[j] * x[j] for j in range(n)) == r0

    prob += lpSum(x) == 1, "Sum_of_weights"

    # Solve the problem
    prob.solve()
    risk_array[i] = value((1 / T) * lpSum(y[t] for t in range(T)))

print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value((1 / T) * lpSum(y[t] for t in range(T))))
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ee5c861fc6c14247b3e0e6feb637ae58-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/ee5c861fc6c14247b3e0e6feb637ae58-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 0.23597274 (1)
# 37  Obj -0.0011484339 Primal inf 121.07863 (233)
# 89  Obj -0.0030492967 Primal inf 212.12591 (230)
# 138  Obj -0.0051214196 Primal inf 116.57574 (187)
# 188  Obj -0.0064716249 Primal inf 430.02561 (218)
# 240  Obj -0.007381572 Primal inf 27.454432 (104)
# 320  Obj -0.032771333 Primal inf 285.90231 (151)
# 376  Obj -0.053072247 Primal inf 21.981232 (39)
# Primal infeasible - objective value -0.053072247
# PrimalInfeasible objective -0.0530722465 - 376 iterations time 0.022
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6801c8b9259849c3b0bb7a9ae6743d9f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6801c8b9259849c3b0bb7a9ae6743d9f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.34304481 (2)
# 39  Obj -0.0011238093 Primal inf 93.850721 (220)
# 88  Obj -0.0027524769 Primal inf 82.047859 (206)
# 136  Obj -0.0045196439 Primal inf 491.19275 (200)
# 185  Obj -0.0059458852 Primal inf 126.93353 (181)
# 232  Obj -0.0067526518 Primal inf 103.95703 (179)
# 271  Obj -0.0071244163 Primal inf 0.026243602 (4)
# 305  Obj -0.0074250341
# Optimal - objective value -0.0073655921
# After Postsolve, objective -0.0073655921, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.007365592092 - 305 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.06
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/10e6c5ec18b34c1cb3b967dabdae2b46-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/10e6c5ec18b34c1cb3b967dabdae2b46-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.45011878 (2)
# 31  Obj -0.00086320936 Primal inf 74.855834 (232)
# 82  Obj -0.0022024615 Primal inf 157.62544 (214)
# 134  Obj -0.0036465831 Primal inf 64.12701 (180)
# 185  Obj -0.0053503199 Primal inf 40.374115 (146)
# 232  Obj -0.0064214292 Primal inf 25.245274 (97)
# 279  Obj -0.0068753325
# Optimal - objective value -0.0068197612
# After Postsolve, objective -0.0068197612, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00681976117 - 279 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b07503e53bfc4dbb8bf49cf66e886b86-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b07503e53bfc4dbb8bf49cf66e886b86-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.55719275 (2)
# 42  Obj -0.00078426421 Primal inf 555.05468 (227)
# 90  Obj -0.0021556611 Primal inf 43.119145 (198)
# 138  Obj -0.0035707981 Primal inf 96.970124 (199)
# 189  Obj -0.0053061369 Primal inf 83.284069 (172)
# 238  Obj -0.0062367777 Primal inf 27.106624 (113)
# 286  Obj -0.0068287688
# Optimal - objective value -0.0067746251
# After Postsolve, objective -0.0067746251, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006774625093 - 286 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ae6bfccc772945248d51b57038991cee-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/ae6bfccc772945248d51b57038991cee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.66426672 (2)
# 45  Obj -0.00092359193 Primal inf 76.09926 (231)
# 92  Obj -0.0022588914 Primal inf 292.05846 (221)
# 138  Obj -0.0038318591 Primal inf 42.116888 (166)
# 188  Obj -0.0051546845 Primal inf 213.25471 (202)
# 237  Obj -0.0064651006 Primal inf 13.318047 (86)
# 285  Obj -0.0069394295
# Optimal - objective value -0.0068848084
# After Postsolve, objective -0.0068848084, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.00688480845 - 285 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9cbb443b1e694a9a94584d292d297122-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/9cbb443b1e694a9a94584d292d297122-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.77134069 (2)
# 45  Obj -0.001169549 Primal inf 104.85621 (233)
# 92  Obj -0.0025881703 Primal inf 192.95015 (220)
# 139  Obj -0.0041617594 Primal inf 143.21905 (210)
# 189  Obj -0.0056267692 Primal inf 48.224274 (144)
# 238  Obj -0.0068477867 Primal inf 17.869612 (98)
# 283  Obj -0.0072306506
# Optimal - objective value -0.0071742505
# After Postsolve, objective -0.0071742505, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.007174250547 - 283 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5eaad9e2a0ed4594a7de88788acb6d45-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/5eaad9e2a0ed4594a7de88788acb6d45-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.87841466 (2)
# 45  Obj -0.0014034588 Primal inf 125.89494 (233)
# 92  Obj -0.0027373267 Primal inf 73.215512 (176)
# 140  Obj -0.0042858071 Primal inf 431.11427 (206)
# 186  Obj -0.005807633 Primal inf 36.894072 (148)
# 251  Obj -0.0075230032 Primal inf 12.723918 (73)
# 281  Obj -0.0076816412
# 281  Obj -0.0076221872 Dual inf 6.8991781e-08 (1)
# Optimal - objective value -0.0076221872
# After Postsolve, objective -0.0076221872, infeasibilities - dual 2.8625469e-05 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.0076221872 Dual inf 9.6899178e-07 (1)
# 1  Obj -0.0076221636
# Optimal - objective value -0.0076221636
# Optimal objective -0.007622163589 - 282 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/110b008bc20140d3a7cac98126e91331-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/110b008bc20140d3a7cac98126e91331-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 0.98548863 (2)
# 45  Obj -0.0016373686 Primal inf 146.93366 (233)
# 92  Obj -0.0031935478 Primal inf 85.378798 (176)
# 136  Obj -0.0047233385 Primal inf 48.023779 (165)
# 179  Obj -0.0059182472 Primal inf 35.682708 (139)
# 226  Obj -0.0071280583 Primal inf 4.5002444 (48)
# 279  Obj -0.0082664926
# 279  Obj -0.008202326 Dual inf 2.356177e-06 (1)
# Optimal - objective value -0.008202326
# After Postsolve, objective -0.008202326, infeasibilities - dual 0.00018619096 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.008202326 Dual inf 3.256177e-06 (1)
# 1  Obj -0.0082022126
# Optimal - objective value -0.0082022126
# Optimal objective -0.008202212609 - 280 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f5089fc56c4d448c8c9eebec9247d015-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/f5089fc56c4d448c8c9eebec9247d015-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.0925626 (2)
# 45  Obj -0.0018712784 Primal inf 167.97239 (233)
# 92  Obj -0.0036497689 Primal inf 97.542084 (176)
# 136  Obj -0.0053981012 Primal inf 54.850632 (165)
# 179  Obj -0.0067637111 Primal inf 40.747988 (139)
# 226  Obj -0.0081463524 Primal inf 5.1094329 (48)
# 274  Obj -0.0089855032
# Optimal - objective value -0.0089140434
# After Postsolve, objective -0.0089140434, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.008914043368 - 274 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7e246acb81af4a16a87340f11875efd1-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/7e246acb81af4a16a87340f11875efd1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.1996366 (2)
# 45  Obj -0.0021051882 Primal inf 189.01112 (233)
# 92  Obj -0.00410599 Primal inf 109.70537 (176)
# 136  Obj -0.0060728638 Primal inf 61.677485 (165)
# 179  Obj -0.007609175 Primal inf 45.813268 (139)
# 226  Obj -0.0091646464 Primal inf 5.7186214 (48)
# 271  Obj -0.0097698565
# Optimal - objective value -0.0096907411
# After Postsolve, objective -0.0096907411, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.009690741055 - 271 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c42725cc6a524001962e7fdeb3ce3dd9-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c42725cc6a524001962e7fdeb3ce3dd9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.3067105 (2)
# 45  Obj -0.0022855531 Primal inf 99.639942 (217)
# 93  Obj -0.0045326565 Primal inf 152.04733 (210)
# 139  Obj -0.0066773624 Primal inf 229.12933 (209)
# 181  Obj -0.0085368135 Primal inf 93.195442 (178)
# 227  Obj -0.010235529 Primal inf 15.194437 (82)
# 267  Obj -0.010619604
# 267  Obj -0.01053364 Dual inf 3.8207025e-06 (1)
# Optimal - objective value -0.01053364
# After Postsolve, objective -0.01053364, infeasibilities - dual 4.4491357e-05 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.01053364 Dual inf 4.7207025e-06 (1)
# 1  Obj -0.010533324
# Optimal - objective value -0.010533324
# Optimal objective -0.01053332432 - 268 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/00f6e21e16664fecb2421491dbf61d24-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/00f6e21e16664fecb2421491dbf61d24-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.4137845 (2)
# 46  Obj -0.0025009226 Primal inf 264.62711 (225)
# 94  Obj -0.0050348584 Primal inf 294.76739 (208)
# 143  Obj -0.0074686274 Primal inf 309.04738 (211)
# 183  Obj -0.0099103361 Primal inf 351.46085 (202)
# 230  Obj -0.011384531 Primal inf 165.62072 (170)
# 265  Obj -0.011729109
# 265  Obj -0.011635793 Dual inf 1.7160307e-06 (1)
# Optimal - objective value -0.011635793
# After Postsolve, objective -0.011635793, infeasibilities - dual 0.00017776931 (1), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj -0.011635793 Dual inf 2.6160307e-06 (1)
# 1  Obj -0.011635766
# Optimal - objective value -0.011635766
# Optimal objective -0.01163576558 - 266 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/119813e56ce1408d8b2492ffc1bb87f0-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/119813e56ce1408d8b2492ffc1bb87f0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.5208585 (2)
# 47  Obj -0.0028998046 Primal inf 227.39139 (218)
# 94  Obj -0.0055239717 Primal inf 76.496017 (182)
# 140  Obj -0.008478048 Primal inf 208.72095 (196)
# 180  Obj -0.01055742 Primal inf 34.675371 (127)
# 224  Obj -0.012367733 Primal inf 67.01967 (127)
# 276  Obj -0.013167825 Primal inf 0.56218305 (18)
# 287  Obj -0.013215891
# Optimal - objective value -0.013112214
# After Postsolve, objective -0.013112214, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.01311221414 - 287 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/050daf9ef40843d49251492ead0b005c-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/050daf9ef40843d49251492ead0b005c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.6279325 (2)
# 47  Obj -0.003141455 Primal inf 246.3219 (218)
# 94  Obj -0.0059843026 Primal inf 82.877491 (182)
# 140  Obj -0.009184552 Primal inf 226.17545 (196)
# 180  Obj -0.011437205 Primal inf 37.596984 (127)
# 224  Obj -0.013398378 Primal inf 72.636642 (127)
# 277  Obj -0.014735471 Primal inf 27.017686 (72)
# 298  Obj -0.015173569 Primal inf 0.00011295994 (1)
# 298  Obj -0 Primal inf 0.00011295994 (1)
# Primal infeasible - objective value -0
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.015053042, infeasibilities - dual 0.9999749 (251), primal 0.00084753315 (1)
# Perturbing problem by 1e-08% of 0.027446881 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.015053042 Primal inf 0.00011385994 (1)
# 0  Obj -0 Primal inf 0.00011385994 (1)
# Primal infeasible - objective value -0
# PrimalInfeasible objective -0 - 298 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3c15d2c99ad346daa0aacf64778c1ab0-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/3c15d2c99ad346daa0aacf64778c1ab0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.7350064 (2)
# 45  Obj -0.0032450905 Primal inf 766.26368 (237)
# 92  Obj -0.0066150537 Primal inf 134.29505 (202)
# 137  Obj -0.0098596171 Primal inf 327.81573 (209)
# 181  Obj -0.012576998 Primal inf 204.03675 (178)
# 228  Obj -0.014359356 Primal inf 5.0522231 (39)
# 286  Obj -0.017028205 Primal inf 13.473055 (41)
# 295  Obj -0.017303683 Primal inf 4.4355602 (24)
# Primal infeasible - objective value -0.017303683
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.0171632, infeasibilities - dual 0.0099304939 (192), primal 0.28653255 (25)
# Perturbing problem by 1e-08% of 0.027446881 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.0171632 Primal inf 4.4439086 (25)
# 7  Obj -0.017293449 Primal inf 0.61085915 (15)
# Primal infeasible - objective value -0.017293449
# PrimalInfeasible objective -0.01729344888 - 302 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/60db43329f114f48a71628bafaaffeb9-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/60db43329f114f48a71628bafaaffeb9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.8420804 (2)
# 43  Obj -0.0033705435 Primal inf 338.09053 (233)
# 87  Obj -0.0064392864 Primal inf 853.55761 (216)
# 133  Obj -0.0098537881 Primal inf 328.26361 (209)
# 177  Obj -0.013151745 Primal inf 390.75309 (177)
# 223  Obj -0.015228581 Primal inf 120.16971 (128)
# 274  Obj -0.017964325 Primal inf 28.319762 (77)
# 291  Obj -0.019258208 Primal inf 14.493947 (46)
# Primal infeasible - objective value -0.019258208
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.019099683, infeasibilities - dual 0.0092538978 (183), primal 0.72594006 (51)
# Perturbing problem by 1e-08% of 0.027446881 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.019099683 Primal inf 15.452955 (51)
# 17  Obj -0.019463301 Primal inf 9.4989702 (35)
# Primal infeasible - objective value -0.019463301
# PrimalInfeasible objective -0.01946330071 - 308 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/898ba22b308b4d71b773506809eceaa1-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/898ba22b308b4d71b773506809eceaa1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 1.9491544 (2)
# 43  Obj -0.0035952464 Primal inf 360.65239 (233)
# 87  Obj -0.0068685722 Primal inf 910.4556 (216)
# 133  Obj -0.010510707 Primal inf 350.1802 (209)
# 177  Obj -0.014028528 Primal inf 416.79497 (177)
# 223  Obj -0.016243819 Primal inf 128.21402 (128)
# 273  Obj -0.019617245 Primal inf 152.61734 (113)
# 286  Obj -0.032173732 Primal inf 2829.4067 (191)
# Primal infeasible - objective value -0.032173732
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.032197743, infeasibilities - dual 0.0060194264 (118), primal 129.50953 (223)
# Perturbing problem by 1e-08% of 0.027446881 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.054861953 Primal inf 10158.306 (235) Dual inf 0.20434699 (1)
# 0  Obj -0.054861953 Primal inf 10158.306 (235) Dual inf 6.1802037e+14 (118)
# 67  Obj -0.022535514 Primal inf 0.089793579 (1)
# Primal infeasible - objective value -0.022535514
# PrimalInfeasible objective -0.0225355142 - 353 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c12afd4297b047c3a343acb2ca1289ed-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c12afd4297b047c3a343acb2ca1289ed-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 2.0562283 (2)
# 43  Obj -0.0038199493 Primal inf 383.21426 (233)
# 87  Obj -0.007297858 Primal inf 967.35358 (216)
# 133  Obj -0.011167627 Primal inf 372.0968 (209)
# 177  Obj -0.014905311 Primal inf 442.83686 (177)
# 223  Obj -0.017259058 Primal inf 136.25833 (128)
# 272  Obj -0.021221388 Primal inf 196.19367 (120)
# 283  Obj -0.036987937 Primal inf 4009.2395 (193)
# Primal infeasible - objective value -0.036987937
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.037108957, infeasibilities - dual 0.0059741598 (117), primal 182.62432 (225)
# Perturbing problem by 1e-08% of 0.027446881 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.058127285 Primal inf 11581.977 (237) Dual inf 0.18950671 (1)
# 0  Obj -0.058127285 Primal inf 11581.977 (237) Dual inf 6.2131004e+14 (119)
# 76  Obj -0.025361295 Primal inf 0.11968682 (1)
# Primal infeasible - objective value -0.025361295
# PrimalInfeasible objective -0.0253612951 - 359 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e24d6fce9fab42f0a7dcbb6ec7ad53d4-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/e24d6fce9fab42f0a7dcbb6ec7ad53d4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 2.1633023 (2)
# 43  Obj -0.0040116647 Primal inf 495.73355 (215)
# 90  Obj -0.0082876138 Primal inf 2016.3304 (199)
# 133  Obj -0.011465842 Primal inf 74.378998 (140)
# 182  Obj -0.015865704 Primal inf 136.41845 (156)
# 227  Obj -0.018405415 Primal inf 45.638575 (108)
# 276  Obj -0.10127869 Primal inf 4958.3333 (182)
# Primal infeasible - objective value -0.10127869
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.10117619, infeasibilities - dual 0.0063480538 (123), primal 213.49349 (215)
# Perturbing problem by 1e-08% of 0.027446881 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.1869654 Primal inf 12499.634 (225) Dual inf 0.77352026 (1)
# 0  Obj -0.1869654 Primal inf 12499.634 (225) Dual inf 5.997076e+14 (113)
# 88  Obj -0.028264236 Primal inf 0.14958006 (1)
# Primal infeasible - objective value -0.028264236
# PrimalInfeasible objective -0.0282642355 - 364 iterations time 0.022, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/235a0768e41943e3aaabf8191fc80690-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/235a0768e41943e3aaabf8191fc80690-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 4.987799e-05 ( 7.1574316%) - largest zero change 4.2399266e-05
# 0  Obj -0 Primal inf 2.2703763 (2)
# 43  Obj -0.004072336 Primal inf 1778.1866 (241)
# 91  Obj -0.0083319776 Primal inf 247.72205 (189)
# 132  Obj -0.01204541 Primal inf 590.19442 (211)
# 180  Obj -0.016696446 Primal inf 93.847568 (114)
# 226  Obj -0.01927214 Primal inf 8.3948143 (44)
# 278  Obj -0.10132294 Primal inf 6436.1401 (188)
# 281  Obj -0.12806511 Primal inf 6077.0785 (182)
# Primal infeasible - objective value -0.12806511
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.12800047, infeasibilities - dual 0.0063281515 (123), primal 258.49135 (215)
# Perturbing problem by 1e-08% of 0.027446881 - largest nonzero change 0 ( 0%) - largest zero change 8.4775266e-06
# 0  Obj -0.22182248 Primal inf 13824.544 (221) Dual inf 0.84594892 (1)
# 0  Obj -0.22182248 Primal inf 13824.544 (221) Dual inf 5.9964443e+14 (111)
# 88  Obj -0.032377096 Primal inf 0.23154398 (1) Dual inf 7.0876285e+08 (1)
# 96  Obj -0.031218892 Primal inf 0.1794733 (1)
# Primal infeasible - objective value -0.031218892
# PrimalInfeasible objective -0.03121889151 - 377 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/a3133dd0644a480ca69ee5240ff84236-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/a3133dd0644a480ca69ee5240ff84236-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 8 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.377452 (2)
# 35  Obj -0.0039004474 Primal inf 545.58805 (232)
# 78  Obj -0.0075862259 Primal inf 206.2501 (210)
# 123  Obj -0.01190735 Primal inf 465.20663 (226)
# 172  Obj -0.017236937 Primal inf 1296.3996 (239)
# 221  Obj -0.020130649 Primal inf 74.195521 (120)
# 282  Obj -0.028242371 Primal inf 117.48896 (113)
# 292  Obj -0.029854636 Primal inf 61.678924 (91)
# Primal infeasible - objective value -0.029854636
# PrimalInfeasible objective -0.02985463569 - 292 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/151af3a8ae1c4bbe96b0a79ad7682fcc-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/151af3a8ae1c4bbe96b0a79ad7682fcc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.484526 (2)
# 35  Obj -0.0040954698 Primal inf 572.87925 (232)
# 78  Obj -0.0079655372 Primal inf 216.55081 (210)
# 123  Obj -0.012502718 Primal inf 488.45517 (226)
# 172  Obj -0.018098784 Primal inf 1361.2314 (239)
# 221  Obj -0.021137181 Primal inf 77.917096 (120)
# 283  Obj -0.03087435 Primal inf 126.80146 (112)
# 290  Obj -0.031953115 Primal inf 72.653938 (100)
# Primal infeasible - objective value -0.031953115
# PrimalInfeasible objective -0.03195311454 - 290 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/075673912bb340218f2028ec794af44d-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/075673912bb340218f2028ec794af44d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.5916 (2)
# 35  Obj -0.0042904922 Primal inf 600.17045 (232)
# 78  Obj -0.0083448485 Primal inf 226.85151 (210)
# 123  Obj -0.013098085 Primal inf 511.7037 (226)
# 172  Obj -0.018960631 Primal inf 1426.0631 (239)
# 221  Obj -0.022143713 Primal inf 81.638672 (120)
# 285  Obj -0.033200291 Primal inf 102.89552 (112)
# 291  Obj -0.034066943 Primal inf 83.851242 (100)
# Primal infeasible - objective value -0.034066943
# PrimalInfeasible objective -0.03406694275 - 291 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b99dacafb94c449aa2f8421a8ecae104-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b99dacafb94c449aa2f8421a8ecae104-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.698674 (2)
# 35  Obj -0.0044855145 Primal inf 627.46166 (232)
# 78  Obj -0.0087241598 Primal inf 237.15222 (210)
# 123  Obj -0.013693453 Primal inf 534.95224 (226)
# 172  Obj -0.019822478 Primal inf 1490.8949 (239)
# 221  Obj -0.023150246 Primal inf 85.360247 (120)
# 286  Obj -0.035284935 Primal inf 114.29284 (110)
# 291  Obj -0.036180771 Primal inf 95.048546 (100)
# Primal infeasible - objective value -0.036180771
# PrimalInfeasible objective -0.03618077096 - 291 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/70825486262f48e8a1166538b976e546-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/70825486262f48e8a1166538b976e546-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.8057479 (2)
# 35  Obj -0.0046805369 Primal inf 654.75286 (232)
# 78  Obj -0.009103471 Primal inf 247.45293 (210)
# 123  Obj -0.01428882 Primal inf 558.20077 (226)
# 172  Obj -0.020684325 Primal inf 1555.7267 (239)
# 221  Obj -0.024156778 Primal inf 89.081822 (120)
# 286  Obj -0.03779781 Primal inf 118.30067 (106)
# 288  Obj -0.038261541 Primal inf 106.27412 (102)
# Primal infeasible - objective value -0.038261541
# PrimalInfeasible objective -0.03826154109 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6606598b5d6b4262b02aae1df656903e-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6606598b5d6b4262b02aae1df656903e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 2.9128219 (2)
# 35  Obj -0.0048755593 Primal inf 682.04406 (232)
# 78  Obj -0.0094827823 Primal inf 257.75364 (210)
# 123  Obj -0.014884188 Primal inf 581.44931 (226)
# 172  Obj -0.021546172 Primal inf 1620.5585 (239)
# 221  Obj -0.025163311 Primal inf 92.803398 (120)
# 286  Obj -0.039872982 Primal inf 130.605 (106)
# 288  Obj -0.040378367 Primal inf 117.49741 (102)
# Primal infeasible - objective value -0.040378367
# PrimalInfeasible objective -0.04037836691 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/dcd4e9089ecf4163962885ce1cc0d085-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/dcd4e9089ecf4163962885ce1cc0d085-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 3.0198959 (2)
# 35  Obj -0.0050705816 Primal inf 709.33526 (232)
# 78  Obj -0.0098620936 Primal inf 268.05434 (210)
# 123  Obj -0.015479555 Primal inf 604.69784 (226)
# 172  Obj -0.022408019 Primal inf 1685.3903 (239)
# 221  Obj -0.026169843 Primal inf 96.524973 (120)
# 286  Obj -0.041948154 Primal inf 142.90934 (106)
# 288  Obj -0.042495193 Primal inf 128.72069 (102)
# Primal infeasible - objective value -0.042495193
# PrimalInfeasible objective -0.04249519273 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3cc937b57c004efe97dbe9dc8e6e670c-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/3cc937b57c004efe97dbe9dc8e6e670c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 3.1269698 (2)
# 35  Obj -0.005265604 Primal inf 736.62647 (232)
# 78  Obj -0.010241405 Primal inf 278.35505 (210)
# 123  Obj -0.016074923 Primal inf 627.94637 (226)
# 172  Obj -0.023269865 Primal inf 1750.222 (239)
# 221  Obj -0.027176376 Primal inf 100.24655 (120)
# 286  Obj -0.044023327 Primal inf 155.21367 (106)
# 288  Obj -0.044612019 Primal inf 139.94397 (102)
# Primal infeasible - objective value -0.044612019
# PrimalInfeasible objective -0.04461201855 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9ab71baf51c54a9cbcdcc9f5aa75dae4-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/9ab71baf51c54a9cbcdcc9f5aa75dae4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# ...
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 4.5189314 (2)
# 35  Obj -0.0078008948 Primal inf 1091.4121 (232)
# 78  Obj -0.015172452 Primal inf 412.26425 (210)
# 123  Obj -0.0238147 Primal inf 930.17732 (226)
# 172  Obj -0.034473875 Primal inf 2593.0352 (239)
# 221  Obj -0.040261297 Primal inf 148.62703 (120)
# 281  Obj -0.0683284 Primal inf 492.69406 (142)
# 289  Obj -0.073103897 Primal inf 281.92576 (112)
# Primal infeasible - objective value -0.073103897
# PrimalInfeasible objective -0.07310389722 - 289 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c7bd8e141bc34b2fa61ed65dfdc591fc-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c7bd8e141bc34b2fa61ed65dfdc591fc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 4.6260054 (2)
# 35  Obj -0.0079959172 Primal inf 1118.7033 (232)
# 78  Obj -0.015551763 Primal inf 422.56495 (210)
# 123  Obj -0.024410068 Primal inf 953.42585 (226)
# 172  Obj -0.035335722 Primal inf 2657.867 (239)
# 221  Obj -0.04126783 Primal inf 152.3486 (120)
# 281  Obj -0.070305404 Primal inf 512.07587 (142)
# 289  Obj -0.075255613 Primal inf 293.21918 (112)
# Primal infeasible - objective value -0.075255613
# PrimalInfeasible objective -0.07525561346 - 289 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/bf63c63f80b54f1da441cd3d4a71b254-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/bf63c63f80b54f1da441cd3d4a71b254-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 4.7330794 (2)
# 35  Obj -0.0081909396 Primal inf 1145.9945 (232)
# 78  Obj -0.015931074 Primal inf 432.86566 (210)
# 123  Obj -0.025005435 Primal inf 976.67439 (226)
# 172  Obj -0.036197568 Primal inf 2722.6987 (239)
# 221  Obj -0.042274362 Primal inf 156.07018 (120)
# 281  Obj -0.073491276 Primal inf 523.53224 (139)
# 288  Obj -0.07732635 Primal inf 305.03952 (113)
# Primal infeasible - objective value -0.07732635
# PrimalInfeasible objective -0.07732634978 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4b6a50ba21ea4a93806069b2377a3fcb-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4b6a50ba21ea4a93806069b2377a3fcb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 4.8401534 (2)
# 35  Obj -0.0083859619 Primal inf 1173.2857 (232)
# 78  Obj -0.016310386 Primal inf 443.16637 (210)
# 123  Obj -0.025600803 Primal inf 999.92292 (226)
# 172  Obj -0.037059415 Primal inf 2787.5305 (239)
# 221  Obj -0.043280894 Primal inf 159.79175 (120)
# 281  Obj -0.075509356 Primal inf 542.64473 (139)
# 288  Obj -0.079475447 Primal inf 316.36846 (115)
# Primal infeasible - objective value -0.079475447
# PrimalInfeasible objective -0.07947544718 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5ff94dbee3f943a0b57edf50caf8472d-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/5ff94dbee3f943a0b57edf50caf8472d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 4.9472273 (2)
# 35  Obj -0.0085809843 Primal inf 1200.5769 (232)
# 78  Obj -0.016689697 Primal inf 453.46708 (210)
# 123  Obj -0.02619617 Primal inf 1023.1715 (226)
# 172  Obj -0.037921262 Primal inf 2852.3623 (239)
# 221  Obj -0.044287427 Primal inf 163.51333 (120)
# 281  Obj -0.077527437 Primal inf 561.75723 (139)
# 288  Obj -0.081624545 Primal inf 327.70098 (115)
# Primal infeasible - objective value -0.081624545
# PrimalInfeasible objective -0.08162454459 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0afd786e1d0042078dbc784ad5c446b1-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/0afd786e1d0042078dbc784ad5c446b1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 5.0543013 (2)
# 35  Obj -0.0087760067 Primal inf 1227.8681 (232)
# 78  Obj -0.017069008 Primal inf 463.76778 (210)
# 123  Obj -0.026791538 Primal inf 1046.42 (226)
# 172  Obj -0.038783109 Primal inf 2917.1941 (239)
# 221  Obj -0.045293959 Primal inf 167.2349 (120)
# 281  Obj -0.079545517 Primal inf 580.87104 (141)
# 288  Obj -0.083773642 Primal inf 339.03349 (115)
# Primal infeasible - objective value -0.083773642
# PrimalInfeasible objective -0.083773642 - 288 iterations time 0.022
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.04
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/62176904264b4066b969728de621a345-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/62176904264b4066b969728de621a345-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 5.1613753 (2)
# 35  Obj -0.0089710291 Primal inf 1255.1593 (232)
# 78  Obj -0.01744832 Primal inf 474.06849 (210)
# 123  Obj -0.027386905 Primal inf 1069.6685 (226)
# 172  Obj -0.039644956 Primal inf 2982.0259 (239)
# 221  Obj -0.046300492 Primal inf 170.95648 (120)
# 281  Obj -0.081563597 Primal inf 600.01161 (143)
# 288  Obj -0.085922739 Primal inf 350.366 (115)
# Primal infeasible - objective value -0.085922739
# PrimalInfeasible objective -0.0859227394 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/de7d9cb0de9c4e909c8c87d1866dead1-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/de7d9cb0de9c4e909c8c87d1866dead1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 5.2684492 (2)
# 35  Obj -0.0091660514 Primal inf 1282.4505 (232)
# 78  Obj -0.017827631 Primal inf 484.3692 (210)
# 123  Obj -0.027982273 Primal inf 1092.9171 (226)
# 172  Obj -0.040506803 Primal inf 3046.8576 (239)
# 221  Obj -0.047307024 Primal inf 174.67805 (120)
# 281  Obj -0.083581678 Primal inf 619.1578 (145)
# 288  Obj -0.088071837 Primal inf 361.69851 (115)
# Primal infeasible - objective value -0.088071837
# PrimalInfeasible objective -0.08807183681 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9d87e4cb9dc441b8b7d0a29c347cdff8-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/9d87e4cb9dc441b8b7d0a29c347cdff8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 5.3755232 (2)
# 35  Obj -0.0093610738 Primal inf 1309.7417 (232)
# 78  Obj -0.018206942 Primal inf 494.66991 (210)
# 123  Obj -0.02857764 Primal inf 1116.1656 (226)
# 172  Obj -0.04136865 Primal inf 3111.6894 (239)
# 221  Obj -0.048313557 Primal inf 178.39963 (120)
# 281  Obj -0.085599758 Primal inf 638.31192 (145)
# 288  Obj -0.090220934 Primal inf 373.03103 (115)
# Primal infeasible - objective value -0.090220934
# PrimalInfeasible objective -0.09022093422 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6a2a45e289b9487aac380c208c28fd28-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6a2a45e289b9487aac380c208c28fd28-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 4287 RHS
# At line 4792 BOUNDS
# At line 4793 ENDATA
# Problem MODEL has 504 rows, 257 columns and 3526 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 445 (-59) rows, 257 (0) columns and 3113 (-413) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.027446881 - largest nonzero change 5.0242082e-06 ( 0.71795559%) - largest zero change 4.2503973e-06
# 0  Obj -0 Primal inf 5.4825972 (2)
# 35  Obj -0.0095560962 Primal inf 1337.0329 (232)
# 78  Obj -0.018586253 Primal inf 504.97061 (210)
# 123  Obj -0.029173008 Primal inf 1139.4141 (226)
# 172  Obj -0.042230497 Primal inf 3176.5212 (239)
# 221  Obj -0.049320089 Primal inf 182.1212 (120)
# 281  Obj -0.087617838 Primal inf 657.46604 (145)
# 288  Obj -0.092370032 Primal inf 384.36354 (115)
# Primal infeasible - objective value -0.092370032
# PrimalInfeasible objective -0.09237003162 - 288 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Infeasible
# Optimal Portfolio Weights:
# x0: 0.0
# x1: 0.0
# x2: -8.0052924
# x3: 9.0052924
# x4: 0.0
# x5: 0.0
# expected return (MAD): 0.009999999993124592
# Mean Absolute Deviation (MAD): 0.09227469047498006

# %%
risk_array
# Out:
# array([0.05301184, 0.00736559, 0.00681976, 0.00677463, 0.00688481,
#        0.00717425, 0.00762216, 0.00820221, 0.00891404, 0.00969074,
#        0.01053332, 0.01163577, 0.01311221, 0.01505304, 0.01729401,
#        0.0194633 , 0.02253551, 0.0253613 , 0.02826424, 0.03121889,
#        0.02982415, 0.03192042, 0.03403204, 0.03614365, 0.03822221,
#        0.04033683, 0.04245144, 0.04456605, 0.04668066, 0.04879528,
#        0.05090989, 0.0530245 , 0.05519615, 0.05731562, 0.05943509,
#        0.06155455, 0.06367402, 0.06579349, 0.06872963, 0.07087912,
#        0.0730286 , 0.07517808, 0.07724664, 0.0793935 , 0.08154037,
#        0.08368723, 0.0858341 , 0.08798096, 0.09012783, 0.09227469])

# %%
plt.figure()
plt.plot(risk_array, m0_array)

for i, stock in enumerate(assets):
    plt.annotate(
        stock,
        (risk_array[i], m0_array[i]),
        textcoords="offset points",
        xytext=(10, 0),
        ha="center",
    )

for i, stock in enumerate(assets):
    plt.scatter(risk_array[i], m0_array[i], label=stock)
plt.xlabel("Risk (Mean Absolute Deviation)")
plt.ylabel("Expected Return")
plt.title("Efficient Frontier")
# Out:
# Text(0.5, 1.0, 'Efficient Frontier')

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:, 0])  # Number of time periods
mu = 1
print(n, T, mu)

m0_array = np.linspace(0.0, 0.01, 50)
risk_array = 0.0 * m0_array
i = 0
for i in range(len(m0_array)):
    n = len(assets)  # Number of assets
    T = len(R[:, 0])  # Number of time periods
    mu = 1
    r0 = m0_array[i]

    # Create a LP problem
    prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

    # Define decision variables
    x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
    y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

    # Define objective function
    prob += (
        lpSum(r[j] * x[j] for j in range(n)) * mu
        - (1 / T) * lpSum(y[t] for t in range(T)),
        "Objective",
    )

    # Define constraints
    for t in range(T):
        prob += (
            lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t],
            f"Upper_constraint_{t}",
        )
        prob += (
            lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t],
            f"Lower_constraint_{t}",
        )

    prob += lpSum(x) == 1, "Sum_of_weights"

    # Solve the problem
    prob.solve()
    risk_array[i] = value((1 / T) * lpSum(y[t] for t in range(T)))

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value((1 / T) * lpSum(y[t] for t in range(T))))
# Out:
# 6 251 1
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/149c13d711234a2fbe35bf7b3e12d6ab-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/149c13d711234a2fbe35bf7b3e12d6ab-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5812d3ae20af4f17a24cb03483a27f59-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/5812d3ae20af4f17a24cb03483a27f59-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/2d8499791bf743d481904faceaf0d2f3-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/2d8499791bf743d481904faceaf0d2f3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d5c56bb635684929aecaa3c491a68618-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/d5c56bb635684929aecaa3c491a68618-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/32544a914b9d40bdbc0746d61d8e033e-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/32544a914b9d40bdbc0746d61d8e033e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/fb73cff9e18a45688d9cd057c8cd4496-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/fb73cff9e18a45688d9cd057c8cd4496-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c9aa961f6c0b4ba4ad0371d3949440f4-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c9aa961f6c0b4ba4ad0371d3949440f4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f930a6b08d96499cba421fd3f6f85eb3-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/f930a6b08d96499cba421fd3f6f85eb3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9d11d09bf3bf4fe88760655d92e37846-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/9d11d09bf3bf4fe88760655d92e37846-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c10cb3e6421442eb8de70bb942ea74c4-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c10cb3e6421442eb8de70bb942ea74c4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/2a463044c23c49248e4e0bafbd6ff36e-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/2a463044c23c49248e4e0bafbd6ff36e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/497e1d50d84344f3b4b3c8c6aa4bf9c8-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/497e1d50d84344f3b4b3c8c6aa4bf9c8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7804660e7b6c4cf5bc4a32f294f8d9ee-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/7804660e7b6c4cf5bc4a32f294f8d9ee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c0983517ba0d4f969ccd235ef493f920-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c0983517ba0d4f969ccd235ef493f920-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/962245dcb88a4892bc4b109de72976eb-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/962245dcb88a4892bc4b109de72976eb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/2e65d3914dc04a9d8f4093ad9873b59a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/2e65d3914dc04a9d8f4093ad9873b59a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1bf77a4cc23e4901aaac553476b1c751-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1bf77a4cc23e4901aaac553476b1c751-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e5493757272c47fe82a5cca3ad05cda0-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/e5493757272c47fe82a5cca3ad05cda0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.06
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/296f9ae04a8e4d2fb69ab1db89bdaed9-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/296f9ae04a8e4d2fb69ab1db89bdaed9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5a49562d757a447c88a6ea8ee7c0383f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/5a49562d757a447c88a6ea8ee7c0383f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f9def1c10ba84be1a89ae6c2593af5b1-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/f9def1c10ba84be1a89ae6c2593af5b1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d568dd660e5f423b9f91260133f9ba74-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/d568dd660e5f423b9f91260133f9ba74-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3549a358bbb54c2ca1d67db35bec6657-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/3549a358bbb54c2ca1d67db35bec6657-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/cfcc061da3e84b3f94ea795f4b8c9b08-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/cfcc061da3e84b3f94ea795f4b8c9b08-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/93c49d7aac8748ffa16496fcd70c4604-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/93c49d7aac8748ffa16496fcd70c4604-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/620f0d8196e042b6b918a29f92f7f738-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/620f0d8196e042b6b918a29f92f7f738-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/412dd8767fca44feb5ef10e51bd210f2-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/412dd8767fca44feb5ef10e51bd210f2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ee9ca14877b3425cb7b057b6ded37cd4-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/ee9ca14877b3425cb7b057b6ded37cd4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/633291baa8014867a6cf891ea34f48ee-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/633291baa8014867a6cf891ea34f48ee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/77c3bf7391c94920bba006a74da97615-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/77c3bf7391c94920bba006a74da97615-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b25bd7defea3405eb5b25d01385bfc84-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b25bd7defea3405eb5b25d01385bfc84-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7408cd11b42644b39c766fc57af84b26-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/7408cd11b42644b39c766fc57af84b26-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# ...
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/003c080cb9a546049829ebdd888403d3-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/003c080cb9a546049829ebdd888403d3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6fd8274ce915416e8db8b93fae4a29a6-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6fd8274ce915416e8db8b93fae4a29a6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1be8c335e3b446c4ae3bfb4265cfa39b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1be8c335e3b446c4ae3bfb4265cfa39b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9797509009f448b0822f93e22e7f8824-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/9797509009f448b0822f93e22e7f8824-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d0c0ad8865134357b32e919cb904d454-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/d0c0ad8865134357b32e919cb904d454-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/14430b8a23be419da3315d4a98d9bd6c-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/14430b8a23be419da3315d4a98d9bd6c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/db07331b86c1403c9f8678764d236ccf-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/db07331b86c1403c9f8678764d236ccf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5246f82f59074065b02569a70a2edeef-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/5246f82f59074065b02569a70a2edeef-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/128b7bd155f847a6883f308ff16d6d9d-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/128b7bd155f847a6883f308ff16d6d9d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ae677719451542f3aaa9bdaab305cf1d-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/ae677719451542f3aaa9bdaab305cf1d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 4286 RHS
# At line 4790 BOUNDS
# At line 4791 ENDATA
# Problem MODEL has 503 rows, 257 columns and 3520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 444 (-59) rows, 257 (0) columns and 3107 (-413) elements
# Perturbing problem by 0.001% of 0.027996451 - largest nonzero change 8.1754703e-05 ( 24.953919%) - largest zero change 0
# 0  Obj -0 Primal inf 0.23597184 (1) Dual inf 0.050709289 (6)
# 68  Obj -0.0010263327 Primal inf 238.29447 (221)
# 117  Obj -0.0026911203 Primal inf 97.791248 (190)
# 165  Obj -0.0042247465 Primal inf 263.01418 (239)
# 208  Obj -0.0054947191 Primal inf 146.46771 (167)
# 258  Obj -0.0060990496 Primal inf 1.7919067 (34)
# 272  Obj -0.0061227906
# 272  Obj -0.0060655198 Dual inf 0.0003642717 (1)
# 273  Obj -0.0060654996
# Optimal - objective value -0.0060654996
# After Postsolve, objective -0.0060654996, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.006065499598 - 273 iterations time 0.022, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.049674924
# x1: 0.56565469
# x2: 0.23711883
# x3: 0.056276425
# x4: 0.091275124
# x5: 0.0
# expected return (MAD): 0.0008426023820794647
# Mean Absolute Deviation (MAD): 0.006908101997449403

# %%
plt.figure()
plt.plot(risk_array, m0_array)

for i, stock in enumerate(assets):
    plt.annotate(
        stock,
        (risk_array[i], m0_array[i]),
        textcoords="offset points",
        xytext=(10, 0),
        ha="center",
    )

for i, stock in enumerate(assets):
    plt.scatter(risk_array[i], m0_array[i], label=stock)
plt.xlabel("Risk (Mean Absolute Deviation)")
plt.ylabel("Expected Return")
plt.title("Efficient Frontier")
# Out:
# Text(0.5, 1.0, 'Efficient Frontier')

# %% [markdown]
# # Now we consider risk as total variance of the portfolio, all these models are model 2x

# %% [markdown]
# # model 2A
# when we minimize variance under a specified expected return $r_0$
# $$
# \begin{gathered}
# \operatorname{maximize} -\frac{1}{T} \sum_{t=1}^T\left(\sum_j x_j\left(R_j(t)-r_j\right)\right)^2 \\
# \text { subject to } \sum_j x_j=1 \\
#   \sum_j x_j r_j = r_0 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$

# %%
# centered return
R_c = 0.0 * R
for j in range(len(R[0, :])):
    R_c[:, j] = R[:, j] - r[j]

# print(np.outer(R_c[0,:],R_c[0,:]))
R_c.T @ R_c

# compute the convariance matrix manually
sig = 0.0 * S
for i in range(len(R[:, 0])):
    sig = sig + np.outer(R_c[i, :], R_c[i, :])
sig = sig / T


r0 = 0.0005
n = len(R[0, :])
e = np.ones((n, 1))
rq = r.reshape(n, 1)

X = cp.Variable((n, 1))
Objective = cp.Minimize(cp.quad_form(X, sig))
constraints = [e.T @ X == 1, X >= 0, rq.T @ X >= r0]
problem = cp.Problem(Objective, constraints)

result = problem.solve()

print("expected portfolio", X.value.T)
print("expected return :", (rq.T @ X.value)[0])
print("Mean variance:", (X.value.T @ sig @ X.value)[0])
X
# Out:
# expected portfolio [[ 2.58228379e-01  4.82486422e-01  1.74083342e-01  1.68323928e-02
#    6.83694643e-02 -2.82610869e-19]]
# expected return : [0.00062784]
# Mean variance: [8.15805176e-05]
# Variable((6, 1), var1)

# %% [markdown]
# ## Optimization Problem
#
# Choose a risk tolerance $q > 0$:
#
# \begin{align*}
# \text{minimize:} \ \ & \mathbf{x}^T \Sigma \mathbf{x} - q \mathbf{r}^T \mathbf{x} \\
# \text{subject to:} \ \ & \mathbf{e}^T \mathbf{x} = 1 \\
# & \mathbf{x} \geq 0 \\
# \end{align*}

# %%
n = len(assets)
q = 0.1
e = np.ones(n)
X = cp.Variable(n)

obj = cp.Minimize(cp.quad_form(X, S) - q * r @ X)
constraints = [e @ X == 1, X >= 0]
problem = cp.Problem(obj, constraints)


result = problem.solve()
X.value
# Out:
# array([-1.32374719e-23,  1.81512877e-01,  4.26124376e-01,  1.87604703e-01,
#         2.04758045e-01,  1.70131817e-23])

# %%
r
# Out:
# array([[0.00026376],
#        [0.0001986 ],
#        [0.00173443],
#        [0.00265228],
#        [0.0017161 ],
#        [0.00012128]])

# %% [markdown]
# ![Screenshot 2024-04-11 at 00.08.06.png](attachment:bf505bc6-3730-41a1-8cdc-d9f0ec809d16.png)## Optimization Problem
#
# \begin{align*}
# \text{minimize:} \ \ & \mathbf{x}^T \Sigma \mathbf{x} \\
# \text{subject to:} \ \ & \mathbf{e}^T \mathbf{x} = 1 \\
# & \mathbf{r}^T \mathbf{x} = \mu \\
# & \mathbf{x} \geq 0 \\
# \end{align*}

# %% [markdown]
# case mu = 0.01,   minimize risk sigma = 0.001
#
# case mu = 0.02,  minimize risk sigma = 0.003
#
# case mu = 0.05,  minimize risk  sigma = 0.010

# %%
n = len(assets)
e = np.ones((n, 1))
r = r.reshape(n, 1)
mu = 0.001

M = np.block([[2 * S, -r, -e], [r.T, 0, 0], [e.T, 0, 0]])
b = np.block([[np.zeros((n, 1))], [mu], [1]])

x = la.solve(M, b)
print(x)
# Out:
# [[ 1.41766429e-01]
#  [ 4.30586160e-01]
#  [ 2.70153332e-01]
#  [ 7.30250252e-02]
#  [ 1.28294702e-01]
#  [-4.38256485e-02]
#  [ 2.89793620e-02]
#  [ 1.43341355e-04]]
