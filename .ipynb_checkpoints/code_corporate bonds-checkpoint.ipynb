# %%
# !pip install pulp
# !pip install yfinance
# Out:
# Requirement already satisfied: pulp in /opt/conda/lib/python3.10/site-packages (2.7.0)
# Requirement already satisfied: yfinance in /opt/conda/lib/python3.10/site-packages (0.2.37)
# Requirement already satisfied: peewee>=3.16.2 in /opt/conda/lib/python3.10/site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/conda/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: html5lib>=1.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: pandas>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2.4.1)
# Requirement already satisfied: appdirs>=1.4.4 in /opt/conda/lib/python3.10/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: lxml>=4.9.1 in /opt/conda/lib/python3.10/site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: pytz>=2022.5 in /opt/conda/lib/python3.10/site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.4)

# %%
# !pip install cvxpy
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
import cvxpy as cp
import scipy.linalg as la
import pulp
# Out:
# Requirement already satisfied: cvxpy in /opt/conda/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (1.23.5)
# Requirement already satisfied: pybind11 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (2.12.0)
# Requirement already satisfied: clarabel>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (0.7.1)
# Requirement already satisfied: osqp>=0.6.2 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (0.6.5)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (1.10.0)
# Requirement already satisfied: scs>=3.0 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (3.2.4.post1)
# Requirement already satisfied: ecos>=2 in /opt/conda/lib/python3.10/site-packages (from cvxpy) (2.0.13)
# Requirement already satisfied: qdldl in /opt/conda/lib/python3.10/site-packages (from osqp>=0.6.2->cvxpy) (0.1.7.post1)

# %% [markdown]
# ## how we load data from yahoo finance

# %% [markdown]
# #### Short-term corporate bond data

# %%
T = 1 # Number of days in time period
R = []
assets = ["SCHJ","IGSB","VCSH","SPSB","GSIG","ICSH","RATE", "RYSE", "XBIL"]

for bond in assets:
    data = yf.Ticker(bond)
    # 我先改成1年， 这个之后可以随时改成想要的时段
    df = data.history(period="1y")

    # close values on that day
    close = df['Close'].values

    # convert day to day close values to return
    returns = (close[T:] - close[:-T])/close[:-T]
    R.append(returns)

# Return
R = np.array(R).T
# Mean return
r = np.mean(R,axis=0)
# Covariance matrix: a measure of strength of correlation between two variable or more set of variables.
S = np.cov(R.T)

# %%
R
# Out:
# array([[ 0.00126159,  0.00098998,  0.0011815 , ..., -0.00517014,
#         -0.00058422,  0.00019952],
#        [ 0.00178501,  0.00197776,  0.00196702, ...,  0.00320492,
#          0.00662511,  0.0003992 ],
#        [-0.00199151, -0.00256613, -0.00222454, ...,  0.00561195,
#          0.00925278, -0.00019948],
#        ...,
#        [-0.00104   , -0.00117619, -0.00116995, ...,  0.01079535,
#          0.0045183 ,  0.        ],
#        [ 0.00110351,  0.00117758,  0.00143155, ..., -0.01991958,
#         -0.01212852,  0.        ],
#        [-0.00546972, -0.0056851 , -0.00571793, ...,  0.05956922,
#          0.03586471,  0.00010012]])

# %% [markdown]
# ## US Treasury Bond in past 1 years

# %%
# last df is US Treasury Bond
df['Open'].plot()
plt.ylabel('Price (USD)')
plt.show()

# %% [markdown]
# ## histogram of US Treasury Bond in past 1 years

# %%
return_XBIL = R[:,-1]
plt.hist(return_XBIL,bins=50)
plt.ylabel('Frequency')
plt.show()

# %%
r
# Out:
# array([0.00015512, 0.00015891, 0.0001538 , 0.00017072, 0.00014795,
#        0.00021568, 0.0009257 , 0.00085391, 0.00019502])

# %%
S
# Out:
# array([[ 3.68715748e-06,  3.58995043e-06,  3.52438115e-06,
#          2.35189064e-06,  3.58496880e-06,  3.87640236e-07,
#         -1.99745789e-05, -1.61437837e-05,  1.44812035e-07],
#        [ 3.58995043e-06,  3.77958563e-06,  3.65819263e-06,
#          2.43972733e-06,  3.71652508e-06,  4.00700785e-07,
#         -1.96503285e-05, -1.68891328e-05,  1.49437451e-07],
#        [ 3.52438115e-06,  3.65819263e-06,  3.61307344e-06,
#          2.38010430e-06,  3.64796475e-06,  3.98404717e-07,
#         -1.97045081e-05, -1.65644517e-05,  1.48268384e-07],
#        [ 2.35189064e-06,  2.43972733e-06,  2.38010430e-06,
#          1.72968585e-06,  2.42479919e-06,  2.73142506e-07,
#         -1.22739172e-05, -1.01979676e-05,  1.04076616e-07],
#        [ 3.58496880e-06,  3.71652508e-06,  3.64796475e-06,
#          2.42479919e-06,  3.78634304e-06,  3.99893145e-07,
#         -2.04505487e-05, -1.69960151e-05,  1.41588266e-07],
#        [ 3.87640236e-07,  4.00700785e-07,  3.98404717e-07,
#          2.73142506e-07,  3.99893145e-07,  1.00879729e-07,
#         -1.72234302e-06, -1.86209796e-06,  2.19455943e-08],
#        [-1.99745789e-05, -1.96503285e-05, -1.97045081e-05,
#         -1.22739172e-05, -2.04505487e-05, -1.72234302e-06,
#          3.17385143e-04,  1.14889818e-04, -4.08429476e-07],
#        [-1.61437837e-05, -1.68891328e-05, -1.65644517e-05,
#         -1.01979676e-05, -1.69960151e-05, -1.86209796e-06,
#          1.14889818e-04,  1.04190298e-04, -4.90015325e-07],
#        [ 1.44812035e-07,  1.49437451e-07,  1.48268384e-07,
#          1.04076616e-07,  1.41588266e-07,  2.19455943e-08,
#         -4.08429476e-07, -4.90015325e-07,  4.98543035e-08]])

# %% [markdown]
# # We consider risk as MAD first, all these models are model 1x

# %% [markdown]
# # model 1A
# when we minimize MAD under a specified expected return $r_0$
# $$
# \begin{gathered}
# \operatorname{maximize} -\frac{1}{T} \sum_{t=1}^T\left|\sum_j x_j\left(R_j(t)-r_j\right)\right| \\
# \text { subject to } \sum_j x_j=1 \\
#   \sum_j x_j r_j = r_0 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$
#
# The LP version is
# $$
# \begin{gathered}
# & \operatorname{maximize} -\frac{1}{T} \sum_{t=1}^T y_t \\
# & \text { subject to }-y_t \leq \sum_j x_j\left(R_j(t)-r_j\right) \leq y_t \quad t=1,2, \ldots, T \text {, } \\
# & \sum_j x_j=1 \\
# &  \sum_j x_j r_j = r_0 \\
# & x_j \geq 0 \quad j=1,2, \ldots, n, \\
# & r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods
r0 = 0.0008
print(n,T,r0)


# Create a LP problem
prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

# Define decision variables
x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

# Define objective function
prob +=  - (1/T) * lpSum(y[t] for t in range(T)), "Objective"

# Define constraints
for t in range(T):
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

prob += lpSum(r[j] * x[j] for j in range(n)) == r0

prob += lpSum(x) == 1, "Sum_of_weights"

# Solve the problem
prob.solve()

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# 9 251 0.0008
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/68c06f3b675049819a20f1c73152f410-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/68c06f3b675049819a20f1c73152f410-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9863111e-05 ( 38.904592%) - largest zero change 4.081594e-05
# 0  Obj -0 Primal inf 0.43205688 (2)
# 45  Obj -0.00027097642 Primal inf 319.55092 (234)
# 94  Obj -0.00096344647 Primal inf 1386.6219 (242)
# 140  Obj -0.0018966094 Primal inf 478.75815 (229)
# 188  Obj -0.0028769826 Primal inf 407.10082 (221)
# 242  Obj -0.0040382739 Primal inf 186.46341 (181)
# 282  Obj -0.0052359353 Primal inf 98.328413 (140)
# 322  Obj -0.0065647324 Primal inf 29.735917 (71)
# 356  Obj -0.0072942666
# Optimal - objective value -0.0070523127
# After Postsolve, objective -0.0070523127, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.007052312693 - 356 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.0
# x1: 0.077562059
# x2: 0.0
# x3: 0.0
# x4: 0.0
# x5: 0.0
# x6: 0.0
# x7: 0.92243794
# x8: 0.0
# expected return (MAD): 0.0007999999988162063
# Mean Absolute Deviation (MAD): 0.007052312684043828

# %% [markdown]
# # model 1B
# when we maximize return under a specified MAD constrait $m_0$
# $$
# \begin{gathered}
# \operatorname{maximize} \sum_j x_j r_j  \\
# \text { subject to } \sum_j x_j=1 \\
#   \frac{1}{T} \sum_{t=1}^T\left|\sum_j x_j\left(R_j(t)-r_j\right)\right| \leq m_0 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$
#
# The LP version is
# $$
# \begin{gathered}
# & \operatorname{maximize}  \sum_j x_j r_j   \\
# & \text { subject to }-y_t \leq \sum_j x_j\left(R_j(t)-r_j\right) \leq y_t \quad t=1,2, \ldots, T \text {, } \\
# & \sum_j x_j=1 \\
# & \frac{1}{T} \sum_{t=1}^T y_t \leq m_0  \\
# & x_j \geq 0 \quad j=1,2, \ldots, n, \\
# & r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods
m0 = 0.007
print(n,T,r0)


# Create a LP problem
prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

# Define decision variables
x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

# Define objective function
prob += lpSum(r[j] * x[j] for j in range(n)), "Objective"

# Define constraints
for t in range(T):
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

prob +=  (1/T) * lpSum(y[t] for t in range(T)) <= m0, "Risk"

prob += lpSum(x) == 1, "Sum_of_weights"

# Solve the problem
prob.solve()

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# 9 251 0.0008
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/97d6118fee73421a985ad40bd55a9194-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/97d6118fee73421a985ad40bd55a9194-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5280 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 5190 (-90) elements
# Perturbing problem by 0.001% of 0.076383402 - largest nonzero change 0.00034218208 ( 10.89029%) - largest zero change 9.978651e-05
# 0  Obj -0 Primal inf 21.44045 (2) Dual inf 0.14632643 (9)
# 84  Obj 0.0023836161 Primal inf 181.27904 (170)
# 123  Obj 0.0021436499 Primal inf 58.673711 (130)
# 161  Obj 0.0005260479 Primal inf 57.102623 (121)
# 203  Obj 0.0004522334 Primal inf 16.504328 (78)
# 246  Obj 0.00041162761 Primal inf 2.6406625 (32)
# 280  Obj 0.0003959867
# Optimal - objective value 0.00079598201
# After Postsolve, objective 0.00079598201, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.0007959820076 - 280 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.0
# x1: 0.083343376
# x2: 0.0
# x3: 0.0
# x4: 0.0
# x5: 0.0
# x6: 0.0
# x7: 0.91665662
# x8: 0.0
# expected return (MAD): 0.0007959820045303267
# Mean Absolute Deviation (MAD): 0.007000000005581676

# %% [markdown]
# ## model 1C
# when combine return and risk together with $\mu$
#
# $$
# \begin{gathered}
# \operatorname{maximize} \mu \sum_j x_j r_j-\frac{1}{T} \sum_{t=1}^T\left|\sum_j x_j\left(R_j(t)-r_j\right)\right| \\
# \text { subject to } \sum_j x_j=1 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$
#
# The LP version is
# $$
# \begin{aligned}
# & \operatorname{maximize} \mu \sum_j x_j r_j-\frac{1}{T} \sum_{t=1}^T y_t \\
# & \text { subject to }-y_t \leq \sum_j x_j\left(R_j(t)-r_j\right) \leq y_t \quad t=1,2, \ldots, T \text {, } \\
# & \sum_j x_j=1 \\
# & x_j \geq 0 \quad j=1,2, \ldots, n \\
# & y_t \geq 0 \quad t=1,2, \ldots, T . \\
# &
# \end{aligned}
# $$
#
# below is pulp implementation

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods
mu = 1
print(n,T,mu)


# Create a LP problem
prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

# Define decision variables
x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

# Define objective function
prob += lpSum(r[j] * x[j] for j in range(n)) * mu - (1/T) * lpSum(y[t] for t in range(T)), "Objective"

# Define constraints
for t in range(T):
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
    prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

prob += lpSum(x) == 1, "Sum_of_weights"

# Solve the problem
prob.solve()

# Print the results
print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# 9 251 1
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b588ae7ca33844939008402d2c70342a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b588ae7ca33844939008402d2c70342a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 508 COLUMNS
# At line 5798 RHS
# At line 6302 BOUNDS
# At line 6303 ENDATA
# Problem MODEL has 503 rows, 260 columns and 5029 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 494 (-9) rows, 260 (0) columns and 4939 (-90) elements
# Perturbing problem by 0.001% of 0.046502418 - largest nonzero change 8.1686767e-05 ( 38.920141%) - largest zero change 0
# 0  Obj -0 Primal inf 0.097171571 (1) Dual inf 0.10006481 (9)
# 50  Obj 0.00071065838 Primal inf 149.69788 (206)
# 81  Obj 0.00039188745 Primal inf 24.24008 (187)
# 133  Obj 0.00017920805 Primal inf 93.872914 (234)
# 182  Obj 0.0001068829 Primal inf 9.9277816 (189)
# 231  Obj 7.252904e-05 Primal inf 1.4931382 (113)
# 283  Obj 5.8021563e-05 Primal inf 0.01133487 (10)
# 293  Obj 5.7935276e-05
# 293  Obj 6.4182745e-05 Dual inf 0.0033417142 (2)
# 295  Obj 6.4186208e-05
# Optimal - objective value 6.4186208e-05
# After Postsolve, objective 6.4186208e-05, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 6.418620828e-05 - 295 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Optimal
# Optimal Portfolio Weights:
# x0: 0.0
# x1: 0.0
# x2: 0.0
# x3: 0.0
# x4: 0.0
# x5: 0.48371344
# x6: 0.0
# x7: 0.013143063
# x8: 0.5031435
# expected return (MAD): 0.0002136727458961694
# Mean Absolute Deviation (MAD): 0.00014948653661239043

# %% [markdown]
# # Efficient frontier
#
# Let us use model 1B to compute the efficient frontier

# %%
from pulp import *

# Define the data
n = len(assets)  # Number of assets
T = len(R[:,0])  # Number of time periods

m0_array = np.linspace(0.0,0.01,50)
risk_array = 0. * m0_array
i = 0
for i in range(len(m0_array)):

  # Define the data
  n = len(assets)  # Number of assets
  T = len(R[:,0])  # Number of time periods
  r0 = m0_array[i]

  # Create a LP problem
  prob = LpProblem("Financial_Portfolio_Optimization", LpMaximize)

  # Define decision variables
  x = [LpVariable(f"x{j}", lowBound=0) for j in range(n)]
  y = [LpVariable(f"y{t}", lowBound=0) for t in range(T)]

  # Define objective function
  prob +=  - (1/T) * lpSum(y[t] for t in range(T)), "Objective"

  # Define constraints
  for t in range(T):
      prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) <= y[t], f"Upper_constraint_{t}"
      prob += lpSum(x[j] * (R[t][j] - r[j]) for j in range(n)) >= -y[t], f"Lower_constraint_{t}"

  prob += lpSum(r[j] * x[j] for j in range(n)) == r0

  prob += lpSum(x) == 1, "Sum_of_weights"

  # Solve the problem
  prob.solve()
  risk_array[i] = value( (1/T) * lpSum(y[t] for t in range(T)))

print("Status:", LpStatus[prob.status])
print("Optimal Portfolio Weights:")
for j in range(n):
    print(f"x{j}: {value(x[j])}")
print("expected return (MAD):", value(lpSum(r[j] * x[j] for j in range(n))))
print("Mean Absolute Deviation (MAD):", value( (1/T) * lpSum(y[t] for t in range(T))))
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/365106c6688443a7896d1d20b6b7a9f0-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/365106c6688443a7896d1d20b6b7a9f0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 0.097172471 (1)
# 37  Obj -7.4392282e-05 Primal inf 183.95054 (245)
# 82  Obj -0.00022431915 Primal inf 108.95691 (236)
# 130  Obj -0.00048414193 Primal inf 127.35341 (210)
# 176  Obj -0.0011100634 Primal inf 213.64362 (208)
# 228  Obj -0.0025339919 Primal inf 362.86763 (207)
# 297  Obj -0.0050489172 Primal inf 43.073544 (96)
# 339  Obj -0.006115256 Primal inf 2.3137149 (17)
# Primal infeasible - objective value -0.006115256
# PrimalInfeasible objective -0.006115256047 - 339 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/229e7d1c1b734fcdb2e71e858daa2513-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/229e7d1c1b734fcdb2e71e858daa2513-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9863111e-05 ( 38.904592%) - largest zero change 4.081594e-05
# 0  Obj -0 Primal inf 0.18260075 (2)
# 37  Obj -2.7891216e-05 Primal inf 12.974627 (246)
# 84  Obj -5.7437877e-05 Primal inf 14.850559 (242)
# 134  Obj -9.2673624e-05 Primal inf 16.088721 (216)
# 174  Obj -0.00012120726 Primal inf 1.8953863 (113)
# 225  Obj -0.0001455775 Primal inf 12.006034 (210)
# 270  Obj -0.00015563745
# Optimal - objective value -0.0001502554
# After Postsolve, objective -0.0001502554, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.000150255402 - 270 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1e9e06c6599a488faae88392362dc2e2-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1e9e06c6599a488faae88392362dc2e2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9863111e-05 ( 38.904592%) - largest zero change 4.081594e-05
# 0  Obj -0 Primal inf 0.26803093 (2)
# 31  Obj -4.2202253e-05 Primal inf 38.702181 (240)
# 81  Obj -0.00010940576 Primal inf 109.13355 (239)
# 129  Obj -0.00023451874 Primal inf 107.09888 (240)
# 179  Obj -0.00048252883 Primal inf 66.83509 (204)
# 233  Obj -0.00092174863 Primal inf 103.40771 (202)
# 289  Obj -0.0016331451 Primal inf 35.251855 (157)
# 347  Obj -0.0019985959 Primal inf 3.3408101 (46)
# 374  Obj -0.0020813504
# Optimal - objective value -0.0020044687
# After Postsolve, objective -0.0020044687, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.002004468652 - 374 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4f1cb4c241e1408da66e0097dfaec322-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4f1cb4c241e1408da66e0097dfaec322-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9863111e-05 ( 38.904592%) - largest zero change 4.081594e-05
# 0  Obj -0 Primal inf 0.35346111 (2)
# 46  Obj -0.00024470447 Primal inf 161.88411 (229)
# 101  Obj -0.00074350306 Primal inf 139.72133 (206)
# 159  Obj -0.0015556734 Primal inf 105.35696 (187)
# 214  Obj -0.0023176671 Primal inf 242.36843 (182)
# 273  Obj -0.0031853687 Primal inf 125.76979 (160)
# 333  Obj -0.0046325243 Primal inf 6.4596642 (40)
# 353  Obj -0.0047717109
# Optimal - objective value -0.0046092333
# After Postsolve, objective -0.0046092333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.004609233329 - 353 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4a3871a6df9b476490a2543182622c0b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4a3871a6df9b476490a2543182622c0b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9863111e-05 ( 38.904592%) - largest zero change 4.081594e-05
# 0  Obj -0 Primal inf 0.43889129 (2)
# 45  Obj -0.00020087124 Primal inf 314.00055 (241)
# 98  Obj -0.00089294196 Primal inf 298.026 (221)
# 144  Obj -0.0015019516 Primal inf 1585.2951 (230)
# 186  Obj -0.0020913261 Primal inf 150.6031 (196)
# 244  Obj -0.0034417466 Primal inf 120.2358 (151)
# 296  Obj -0.0047638045 Primal inf 117.54944 (148)
# 340  Obj -0.0064957009 Primal inf 11.481614 (46)
# 386  Obj -0.0075221242
# Optimal - objective value -0.0072648778
# After Postsolve, objective -0.0072648778, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.007264877754 - 386 iterations time 0.012, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b8d7805940f242589f3462f248785b70-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b8d7805940f242589f3462f248785b70-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9863111e-05 ( 38.904592%) - largest zero change 4.081594e-05
# 0  Obj -0 Primal inf 0.52432147 (2)
# 42  Obj -0.00021674789 Primal inf 120.86177 (230)
# 89  Obj -0.0010538601 Primal inf 314.75512 (232)
# 165  Obj -0.0037174096 Primal inf 221.39494 (178)
# 219  Obj -0.0053423917 Primal inf 611.05673 (232)
# 266  Obj -0.0068544479 Primal inf 358.57364 (167)
# 306  Obj -0.0090904484 Primal inf 52.649178 (80)
# 375  Obj -0.02197655 Primal inf 247.91998 (71)
# 396  Obj -0.026917515 Primal inf 46.741234 (29)
# Primal infeasible - objective value -0.026917515
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.025996586, infeasibilities - dual 0.044733796 (238), primal 1.6163607 (29)
# Perturbing problem by 1e-08% of 0.0065327338 - largest nonzero change 0 ( 0%) - largest zero change 9.2206422e-06
# 0  Obj -0.025996586 Primal inf 46.902702 (29)
# 13  Obj -0.026784088 Primal inf 0.20674348 (3)
# Primal infeasible - objective value -0.026784088
# PrimalInfeasible objective -0.02678408802 - 409 iterations time 0.022, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/80d85f0929e14a50a57564d36d81c77b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/80d85f0929e14a50a57564d36d81c77b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9863111e-05 ( 38.904592%) - largest zero change 4.081594e-05
# 0  Obj -0 Primal inf 0.60975166 (2)
# 46  Obj -0.0003288164 Primal inf 312.53346 (237)
# 95  Obj -0.0013054787 Primal inf 1042.2182 (227)
# 145  Obj -0.002744202 Primal inf 458.18117 (207)
# 197  Obj -0.0045755049 Primal inf 446.60531 (200)
# 254  Obj -0.0074418518 Primal inf 451.20948 (192)
# 291  Obj -0.0092346051 Primal inf 190.19877 (147)
# 326  Obj -0.011474175 Primal inf 71.445145 (83)
# 405  Obj -0.053041517 Primal inf 212.07167 (49)
# Primal infeasible - objective value -0.053041517
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.051157561, infeasibilities - dual 0.043005392 (228), primal 5.6474481 (49)
# Perturbing problem by 1e-08% of 0.0065327338 - largest nonzero change 0 ( 0%) - largest zero change 9.2206422e-06
# 0  Obj -0.051157561 Primal inf 213.49782 (49)
# 21  Obj -0.05505028 Primal inf 1.3849625 (7)
# Primal infeasible - objective value -0.05505028
# PrimalInfeasible objective -0.0550502797 - 426 iterations time 0.022, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3ef72e8cdb1a422ea837544355448317-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/3ef72e8cdb1a422ea837544355448317-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9863111e-05 ( 38.904592%) - largest zero change 4.081594e-05
# 0  Obj -0 Primal inf 0.69518184 (2)
# 36  Obj -0.0002745141 Primal inf 131.91211 (237)
# 87  Obj -0.00086662922 Primal inf 82.151908 (207)
# 136  Obj -0.001867643 Primal inf 4586.7021 (255)
# 190  Obj -0.0042228288 Primal inf 932.59748 (205)
# 237  Obj -0.0063366375 Primal inf 767.52813 (191)
# 269  Obj -0.0090094027 Primal inf 213.73184 (147)
# 321  Obj -0.012265237 Primal inf 57.848302 (68)
# 405  Obj -0.074659601 Primal inf 481.03758 (62)
# Primal infeasible - objective value -0.074659601
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.072013239, infeasibilities - dual 0.042259042 (221), primal 11.43267 (63)
# Perturbing problem by 1e-08% of 0.0065327338 - largest nonzero change 0 ( 0%) - largest zero change 9.2206422e-06
# 0  Obj -0.072013239 Primal inf 485.74626 (63)
# 27  Obj -0.083619829 Primal inf 3.8806035 (9)
# Primal infeasible - objective value -0.083619829
# PrimalInfeasible objective -0.08361982874 - 432 iterations time 0.022, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b1e957ee9c0842f5a0ec1dd5d07b684e-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b1e957ee9c0842f5a0ec1dd5d07b684e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9863111e-05 ( 38.904592%) - largest zero change 4.081594e-05
# 0  Obj -0 Primal inf 0.78061202 (2)
# 32  Obj -0.00035619721 Primal inf 152.11269 (234)
# 83  Obj -0.0015897478 Primal inf 630.09823 (231)
# 136  Obj -0.003316019 Primal inf 1528.4427 (244)
# 190  Obj -0.0053805782 Primal inf 1753.2933 (224)
# 235  Obj -0.0078235704 Primal inf 421.90412 (170)
# 272  Obj -0.010858265 Primal inf 743.96527 (183)
# 317  Obj -0.015602011 Primal inf 27.761296 (50)
# 369  Obj -0.054276229 Primal inf 2405.9749 (124)
# 393  Obj -0.096002737 Primal inf 839.04731 (76)
# Primal infeasible - objective value -0.096002737
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.092530271, infeasibilities - dual 0.040937554 (214), primal 17.391404 (77)
# Perturbing problem by 1e-08% of 0.0065327338 - largest nonzero change 0 ( 0%) - largest zero change 9.2206422e-06
# 0  Obj -0.092530271 Primal inf 847.33972 (77)
# 37  Obj -0.11255628 Primal inf 2.4505741 (3)
# Primal infeasible - objective value -0.11255628
# PrimalInfeasible objective -0.1125562825 - 430 iterations time 0.022, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/14796d3a02304be2af802f3a5402e481-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/14796d3a02304be2af802f3a5402e481-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9863111e-05 ( 38.904592%) - largest zero change 4.081594e-05
# 0  Obj -0 Primal inf 0.8660422 (2)
# 36  Obj -0.00077102027 Primal inf 701.87682 (233)
# 95  Obj -0.0038387135 Primal inf 632.83112 (215)
# 138  Obj -0.0056726041 Primal inf 708.85921 (197)
# 195  Obj -0.0098035956 Primal inf 727.54323 (185)
# 251  Obj -0.014597288 Primal inf 459.73377 (154)
# 294  Obj -0.018263415 Primal inf 120.22074 (84)
# 340  Obj -0.02333868 Primal inf 132.28544 (68)
# 368  Obj -0.10818049 Primal inf 1750.0125 (92)
# Primal infeasible - objective value -0.10818049
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.10446446, infeasibilities - dual 0.039664502 (206), primal 26.605198 (93)
# Perturbing problem by 1e-08% of 0.0065327338 - largest nonzero change 0 ( 0%) - largest zero change 9.2206422e-06
# 0  Obj -0.10446446 Primal inf 1761.8886 (93)
# 44  Obj -0.14132064 Primal inf 3.8204685 (5)
# Primal infeasible - objective value -0.14132064
# PrimalInfeasible objective -0.1413206389 - 412 iterations time 0.012, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/db22ef36976f41509fd67fb787e5c8d8-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/db22ef36976f41509fd67fb787e5c8d8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9863111e-05 ( 38.904592%) - largest zero change 4.081594e-05
# 0  Obj -0 Primal inf 0.95147238 (2)
# 31  Obj -0.00045453687 Primal inf 521.9039 (234)
# 72  Obj -0.0012048676 Primal inf 316.87716 (222)
# 115  Obj -0.0032149235 Primal inf 1671.3402 (223)
# 166  Obj -0.0055360165 Primal inf 1864.806 (212)
# 215  Obj -0.00869087 Primal inf 2039.4397 (210)
# 272  Obj -0.015881613 Primal inf 974.65093 (170)
# 315  Obj -0.021447953 Primal inf 986.46636 (150)
# 374  Obj -0.11371265 Primal inf 2658.0647 (102)
# Primal infeasible - objective value -0.11371265
# Presolved problem not optimal, resolve after postsolve
# After Postsolve, objective -0.10984693, infeasibilities - dual 0.038859154 (201), primal 38.289384 (103)
# Perturbing problem by 1e-08% of 0.0065327338 - largest nonzero change 0 ( 0%) - largest zero change 9.2206422e-06
# 0  Obj -0.10984693 Primal inf 2673.5245 (103)
# 49  Obj -0.17012951 Primal inf 5.2370201 (5)
# Primal infeasible - objective value -0.17012951
# PrimalInfeasible objective -0.170129513 - 423 iterations time 0.022, Presolve 0.00
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9a607c1bb41043d58118e97839f04e3b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/9a607c1bb41043d58118e97839f04e3b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 11 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 1.0369044 (2)
# 38  Obj -0.0002773878 Primal inf 234.53753 (244)
# 83  Obj -0.0011927163 Primal inf 2048.427 (238)
# 128  Obj -0.0034052023 Primal inf 1396.7202 (232)
# 172  Obj -0.0059377439 Primal inf 346.9445 (167)
# 217  Obj -0.010951446 Primal inf 465.47346 (161)
# 271  Obj -0.018314063 Primal inf 427.44152 (137)
# 311  Obj -0.022108061 Primal inf 192.99495 (93)
# 403  Obj -0.18046337 Primal inf 993.39075 (63)
# Primal infeasible - objective value -0.18046337
# PrimalInfeasible objective -0.1804633723 - 403 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1745135c6d05435f87a4d44cf6f0102b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/1745135c6d05435f87a4d44cf6f0102b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 1.1223345 (2)
# 38  Obj -0.00030260487 Primal inf 255.86796 (244)
# 89  Obj -0.0017522698 Primal inf 1716.8129 (250)
# 134  Obj -0.0036087825 Primal inf 1000.5394 (214)
# 182  Obj -0.0064496443 Primal inf 6771.9151 (238)
# 230  Obj -0.011873116 Primal inf 718.91411 (182)
# 288  Obj -0.020753873 Primal inf 203.76099 (102)
# 336  Obj -0.025194988 Primal inf 180.50168 (90)
# 422  Obj -0.20618769 Primal inf 1157.6818 (63)
# Primal infeasible - objective value -0.20618769
# PrimalInfeasible objective -0.2061876901 - 422 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ea5279a99c784d9482f1ac19afd2d361-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/ea5279a99c784d9482f1ac19afd2d361-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 1.2077647 (2)
# 38  Obj -0.00032782195 Primal inf 277.19838 (244)
# 85  Obj -0.0019866228 Primal inf 1475.9862 (243)
# 134  Obj -0.0046278417 Primal inf 602.11918 (207)
# 169  Obj -0.0068583973 Primal inf 3020.6763 (251)
# 214  Obj -0.011184146 Primal inf 1122.3524 (197)
# 273  Obj -0.021576392 Primal inf 635.61248 (146)
# 312  Obj -0.02561543 Primal inf 299.20834 (107)
# 411  Obj -0.23191557 Primal inf 1321.9729 (63)
# Primal infeasible - objective value -0.23191557
# PrimalInfeasible objective -0.2319155728 - 411 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/2da15516da1b4fcc865839a468453094-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/2da15516da1b4fcc865839a468453094-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 1.2931949 (2)
# 38  Obj -0.00035303902 Primal inf 298.52881 (244)
# 88  Obj -0.0023192435 Primal inf 2107.3179 (237)
# 139  Obj -0.0046556837 Primal inf 777.56493 (212)
# 195  Obj -0.0084866687 Primal inf 4604.0818 (215)
# 228  Obj -0.013058287 Primal inf 2281.0933 (215)
# 281  Obj -0.022753662 Primal inf 720.00467 (156)
# 330  Obj -0.028934029 Primal inf 260.31849 (95)
# 422  Obj -0.25762531 Primal inf 1486.264 (63)
# Primal infeasible - objective value -0.25762531
# PrimalInfeasible objective -0.2576253114 - 422 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0e2ba83380b547d8af700c46a986cead-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/0e2ba83380b547d8af700c46a986cead-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 12 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 1.3786251 (2)
# 38  Obj -0.00037825609 Primal inf 319.85924 (244)
# 88  Obj -0.0024934769 Primal inf 2267.2504 (237)
# 133  Obj -0.0055751125 Primal inf 1420.3157 (217)
# 184  Obj -0.0096529741 Primal inf 1367.1261 (209)
# 221  Obj -0.015628216 Primal inf 18829.134 (246)
# 272  Obj -0.026001524 Primal inf 191.27423 (96)
# 315  Obj -0.031818263 Primal inf 236.67713 (90)
# 404  Obj -0.28337134 Primal inf 1650.6322 (65)
# Primal infeasible - objective value -0.28337134
# PrimalInfeasible objective -0.2833713382 - 404 iterations time 0.022
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6327b28f8f0546c19ba9386607d3e436-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6327b28f8f0546c19ba9386607d3e436-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 1.4640553 (2)
# 38  Obj -0.00040347316 Primal inf 341.18967 (244)
# 87  Obj -0.0023476227 Primal inf 2126.9448 (235)
# 138  Obj -0.0045775872 Primal inf 20023.623 (253)
# 190  Obj -0.010014454 Primal inf 16742.967 (249)
# 233  Obj -0.01555495 Primal inf 10762.627 (232)
# 276  Obj -0.024656236 Primal inf 2478.4146 (199)
# 330  Obj -0.031549096 Primal inf 406.13477 (112)
# 393  Obj -0.10367115 Primal inf 9355.4987 (145)
# 433  Obj -0.30909922 Primal inf 1815.0723 (65)
# Primal infeasible - objective value -0.30909922
# PrimalInfeasible objective -0.3090992209 - 433 iterations time 0.022
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/de053f7dfefa47248b2128bdcfb344e4-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/de053f7dfefa47248b2128bdcfb344e4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 1.5494854 (2)
# 38  Obj -0.00046946717 Primal inf 1320.5004 (248)
# 87  Obj -0.0029432128 Primal inf 1278.7258 (239)
# 137  Obj -0.0069209352 Primal inf 1071.3831 (219)
# 190  Obj -0.015967965 Primal inf 740.69449 (163)
# 257  Obj -0.028910291 Primal inf 153.53505 (82)
# 297  Obj -0.034372658 Primal inf 381.52844 (105)
# 396  Obj -0.3348271 Primal inf 1979.5124 (65)
# Primal infeasible - objective value -0.3348271
# PrimalInfeasible objective -0.3348271036 - 396 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b83a6eafc58740daa271977d95350720-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b83a6eafc58740daa271977d95350720-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 1.6349156 (2)
# 38  Obj -0.00049731961 Primal inf 1402.7667 (247)
# 87  Obj -0.0031238771 Primal inf 1359.5248 (239)
# 137  Obj -0.0073492336 Primal inf 1138.5894 (219)
# 190  Obj -0.016963798 Primal inf 787.73854 (163)
# 253  Obj -0.030060588 Primal inf 196.67201 (88)
# 300  Obj -0.037221529 Primal inf 499.30634 (115)
# 397  Obj -0.36055499 Primal inf 2143.9525 (65)
# Primal infeasible - objective value -0.36055499
# PrimalInfeasible objective -0.3605549863 - 397 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c76492b62b154c1ba4a1909ec3fd561b-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c76492b62b154c1ba4a1909ec3fd561b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 1.7203458 (2)
# 38  Obj -0.00052517206 Primal inf 1485.0332 (247)
# 87  Obj -0.0033045415 Primal inf 1440.3237 (239)
# 141  Obj -0.0085195793 Primal inf 28954.392 (250)
# 191  Obj -0.015190026 Primal inf 2540.9252 (218)
# 254  Obj -0.030188224 Primal inf 5101.4357 (203)
# 307  Obj -0.038988629 Primal inf 445.34458 (105)
# 404  Obj -0.38628287 Primal inf 2308.3926 (65)
# Primal infeasible - objective value -0.38628287
# PrimalInfeasible objective -0.386282869 - 404 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f21e0b0068d04400a4610fd286ab867c-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/f21e0b0068d04400a4610fd286ab867c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 1.805776 (2)
# 38  Obj -0.0005530245 Primal inf 1567.2998 (247)
# 84  Obj -0.0031118561 Primal inf 2863.8286 (237)
# 136  Obj -0.0083442417 Primal inf 932.598 (213)
# 184  Obj -0.014742027 Primal inf 1267.4351 (203)
# 234  Obj -0.028709144 Primal inf 838.43456 (147)
# 290  Obj -0.040305988 Primal inf 493.16429 (111)
# 394  Obj -0.41201232 Primal inf 2472.8327 (65)
# Primal infeasible - objective value -0.41201232
# PrimalInfeasible objective -0.4120123218 - 394 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b529619e8e344c808e7e5a8edc05ff22-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b529619e8e344c808e7e5a8edc05ff22-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 1.8912062 (2)
# 38  Obj -0.00058087695 Primal inf 1649.5664 (247)
# 84  Obj -0.003273007 Primal inf 3014.7336 (237)
# 136  Obj -0.0087797768 Primal inf 982.01663 (213)
# 184  Obj -0.015514608 Primal inf 1334.8147 (203)
# 234  Obj -0.030222322 Primal inf 883.13471 (147)
# 290  Obj -0.04243837 Primal inf 521.08547 (111)
# 394  Obj -0.4377403 Primal inf 2637.2727 (65)
# Primal infeasible - objective value -0.4377403
# PrimalInfeasible objective -0.4377402993 - 394 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/73766dfa0ab84f5e9481898a3d6b3648-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/73766dfa0ab84f5e9481898a3d6b3648-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 1.9766363 (2)
# 38  Obj -0.0006087294 Primal inf 1731.8329 (247)
# 84  Obj -0.0034341579 Primal inf 3165.6387 (237)
# 136  Obj -0.0092153119 Primal inf 1031.4353 (213)
# 184  Obj -0.01628719 Primal inf 1402.1943 (203)
# 234  Obj -0.0317355 Primal inf 927.83981 (149)
# 290  Obj -0.044570752 Primal inf 549.00664 (111)
# 394  Obj -0.46346828 Primal inf 2801.7128 (65)
# Primal infeasible - objective value -0.46346828
# PrimalInfeasible objective -0.4634682769 - 394 iterations time 0.022
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/2193210b3f49495093e759c145a05626-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/2193210b3f49495093e759c145a05626-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 2.0620665 (2)
# 38  Obj -0.00063658184 Primal inf 1814.0995 (247)
# 84  Obj -0.0035953088 Primal inf 3316.5437 (237)
# 136  Obj -0.0096508471 Primal inf 1080.8539 (213)
# 184  Obj -0.017059771 Primal inf 1469.5739 (203)
# 234  Obj -0.033250105 Primal inf 972.55887 (149)
# 290  Obj -0.046702873 Primal inf 576.92782 (111)
# 394  Obj -0.48919625 Primal inf 2966.1529 (65)
# Primal infeasible - objective value -0.48919625
# PrimalInfeasible objective -0.4891962545 - 394 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/998eba16644544de8a5b005a113b904f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/998eba16644544de8a5b005a113b904f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 2.1474967 (2)
# 38  Obj -0.00066443429 Primal inf 1896.366 (247)
# 84  Obj -0.0037564598 Primal inf 3467.4488 (237)
# 136  Obj -0.010086382 Primal inf 1130.2725 (213)
# 184  Obj -0.017832352 Primal inf 1536.9536 (203)
# 234  Obj -0.034763347 Primal inf 1017.2779 (149)
# 290  Obj -0.048835242 Primal inf 604.849 (111)
# 394  Obj -0.51492423 Primal inf 3130.593 (65)
# Primal infeasible - objective value -0.51492423
# PrimalInfeasible objective -0.5149242321 - 394 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/dc34aee8c33a41b2b795fc7edea41159-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/dc34aee8c33a41b2b795fc7edea41159-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 2.2329269 (2)
# 38  Obj -0.00069228673 Primal inf 1978.6326 (247)
# 88  Obj -0.0042253779 Primal inf 5285.6594 (234)
# 143  Obj -0.010257125 Primal inf 3302.1238 (225)
# 190  Obj -0.01619761 Primal inf 3350.5137 (225)
# 230  Obj -0.026583744 Primal inf 3944.0202 (212)
# 282  Obj -0.045169733 Primal inf 303.02148 (84)
# 326  Obj -0.053942845 Primal inf 702.31308 (96)
# 417  Obj -0.54065017 Primal inf 3295.0331 (65)
# Primal infeasible - objective value -0.54065017
# PrimalInfeasible objective -0.5406501653 - 417 iterations time 0.022
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ff681d579cd8457292235289412d3b41-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/ff681d579cd8457292235289412d3b41-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 2.3183571 (2)
# 38  Obj -0.00072013918 Primal inf 2060.8991 (247)
# 81  Obj -0.0038374304 Primal inf 2206.9918 (238)
# 131  Obj -0.0096431724 Primal inf 2306.4231 (208)
# 183  Obj -0.018191303 Primal inf 5625.1838 (236)
# 248  Obj -0.042115176 Primal inf 2114.6538 (176)
# 300  Obj -0.054346286 Primal inf 1123.3509 (115)
# 370  Obj -0.32134125 Primal inf 13418.099 (123)
# 399  Obj -0.56636848 Primal inf 3459.4732 (65)
# Primal infeasible - objective value -0.56636848
# PrimalInfeasible objective -0.5663684785 - 399 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/880e90c2e76e4f849e2c2f31e48dfb1a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/880e90c2e76e4f849e2c2f31e48dfb1a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 2.4037872 (2)
# 38  Obj -0.00074799162 Primal inf 2143.1657 (247)
# 81  Obj -0.0041479947 Primal inf 11059.584 (249)
# 133  Obj -0.010319808 Primal inf 1519.1655 (210)
# 177  Obj -0.016147044 Primal inf 4931.6234 (224)
# 223  Obj -0.027215999 Primal inf 4348.6477 (214)
# ...
# 326  Obj -0.089553485 Primal inf 699.43588 (89)
# 414  Obj -0.92656841 Primal inf 5761.6345 (65)
# Primal infeasible - objective value -0.92656841
# PrimalInfeasible objective -0.9265684059 - 414 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0211fc6ae72a412f935f9ac5c14d4ed9-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/0211fc6ae72a412f935f9ac5c14d4ed9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 3.5998098 (2)
# 38  Obj -0.0011469785 Primal inf 4311.9362 (252)
# 90  Obj -0.0066880437 Primal inf 9300.7835 (243)
# 143  Obj -0.015976157 Primal inf 6837.3117 (237)
# 191  Obj -0.025930146 Primal inf 10488.585 (233)
# 231  Obj -0.044818168 Primal inf 13596.567 (222)
# 286  Obj -0.078547894 Primal inf 992.99196 (117)
# 326  Obj -0.091858125 Primal inf 718.17019 (89)
# 414  Obj -0.95229629 Primal inf 5926.0745 (65)
# Primal infeasible - objective value -0.95229629
# PrimalInfeasible objective -0.9522962886 - 414 iterations time 0.022
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/a704884c63944a2dab839a29279c13f0-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/a704884c63944a2dab839a29279c13f0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 3.68524 (2)
# 38  Obj -0.0011750541 Primal inf 4419.3281 (252)
# 90  Obj -0.0068538951 Primal inf 9533.131 (243)
# 143  Obj -0.016373692 Primal inf 7008.1321 (237)
# 191  Obj -0.026576474 Primal inf 10750.552 (233)
# 230  Obj -0.043525465 Primal inf 54823.582 (250)
# 285  Obj -0.077968834 Primal inf 8134.9512 (197)
# 325  Obj -0.092967336 Primal inf 751.07288 (92)
# 414  Obj -0.97802417 Primal inf 6090.5146 (65)
# Primal infeasible - objective value -0.97802417
# PrimalInfeasible objective -0.9780241713 - 414 iterations time 0.022
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/31e887a7d5d443cca7dafbeb0c532c91-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/31e887a7d5d443cca7dafbeb0c532c91-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 3.7706701 (2)
# 38  Obj -0.0012031296 Primal inf 4526.731 (254)
# 90  Obj -0.0070197464 Primal inf 9765.4785 (243)
# 143  Obj -0.016771228 Primal inf 7178.9526 (237)
# 191  Obj -0.027222801 Primal inf 11012.519 (233)
# 230  Obj -0.044586269 Primal inf 56166.298 (250)
# 285  Obj -0.079873405 Primal inf 8335.2237 (197)
# 325  Obj -0.095242276 Primal inf 770.15914 (92)
# 414  Obj -1.0037521 Primal inf 6254.9547 (65)
# Primal infeasible - objective value -1.0037521
# PrimalInfeasible objective -1.003752054 - 414 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/525a713f2f9a4e1ca941500b6f369cc0-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/525a713f2f9a4e1ca941500b6f369cc0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 3.8561003 (2)
# 38  Obj -0.0012312052 Primal inf 4634.1392 (254)
# 90  Obj -0.0071855977 Primal inf 9997.826 (243)
# 143  Obj -0.017168763 Primal inf 7349.7731 (237)
# 191  Obj -0.027869128 Primal inf 11274.486 (233)
# 230  Obj -0.045647073 Primal inf 57509.015 (250)
# 285  Obj -0.081777976 Primal inf 8535.4962 (197)
# 325  Obj -0.097517216 Primal inf 789.24541 (92)
# 414  Obj -1.0294799 Primal inf 6419.3948 (65)
# Primal infeasible - objective value -1.0294799
# PrimalInfeasible objective -1.029479937 - 414 iterations time 0.022
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7c2c8613df8d4cd4a36d9d3945735c3f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/7c2c8613df8d4cd4a36d9d3945735c3f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 3.9415305 (2)
# 38  Obj -0.0012592808 Primal inf 4741.5474 (254)
# 90  Obj -0.0073514491 Primal inf 10230.174 (243)
# 143  Obj -0.017566298 Primal inf 7520.5936 (237)
# 191  Obj -0.028515455 Primal inf 11536.454 (233)
# 230  Obj -0.046707877 Primal inf 58851.731 (250)
# 285  Obj -0.083682547 Primal inf 8735.7687 (197)
# 325  Obj -0.099792156 Primal inf 808.33168 (92)
# 414  Obj -1.0552078 Primal inf 6583.8349 (65)
# Primal infeasible - objective value -1.0552078
# PrimalInfeasible objective -1.055207819 - 414 iterations time 0.022
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/98ab14d704ef49358bfb1bb7beb89adb-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/98ab14d704ef49358bfb1bb7beb89adb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 4.0269607 (2)
# 38  Obj -0.0012873563 Primal inf 4848.9556 (254)
# 90  Obj -0.0075173004 Primal inf 10462.521 (243)
# 143  Obj -0.017963834 Primal inf 7691.414 (237)
# 191  Obj -0.029161782 Primal inf 11798.421 (233)
# 230  Obj -0.047768681 Primal inf 60194.447 (250)
# 285  Obj -0.085587118 Primal inf 8936.0413 (197)
# 325  Obj -0.1020671 Primal inf 827.41794 (92)
# 414  Obj -1.0809357 Primal inf 6748.275 (65)
# Primal infeasible - objective value -1.0809357
# PrimalInfeasible objective -1.080935702 - 414 iterations time 0.022
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4338221d30bb4de3a87f35fe1289636c-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4338221d30bb4de3a87f35fe1289636c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 4.1123909 (2)
# 38  Obj -0.0013154319 Primal inf 4956.3638 (254)
# 90  Obj -0.0076831517 Primal inf 10694.869 (243)
# 143  Obj -0.018361369 Primal inf 7862.2345 (237)
# 191  Obj -0.02980811 Primal inf 12060.388 (233)
# 230  Obj -0.048829485 Primal inf 61537.164 (250)
# 285  Obj -0.087491689 Primal inf 9136.3138 (197)
# 325  Obj -0.10434204 Primal inf 846.50421 (92)
# 414  Obj -1.1066636 Primal inf 6912.7151 (65)
# Primal infeasible - objective value -1.1066636
# PrimalInfeasible objective -1.106663585 - 414 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0a2cd80c14ed41dd8420313fcde8ee8f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/0a2cd80c14ed41dd8420313fcde8ee8f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 4.197821 (2)
# 38  Obj -0.0013435074 Primal inf 5063.772 (254)
# 90  Obj -0.0078490031 Primal inf 10927.216 (243)
# 143  Obj -0.018758904 Primal inf 8033.055 (237)
# 191  Obj -0.030454437 Primal inf 12322.355 (233)
# 230  Obj -0.049890288 Primal inf 62879.88 (250)
# 285  Obj -0.08939626 Primal inf 9336.5863 (197)
# 325  Obj -0.10661698 Primal inf 865.59047 (92)
# 414  Obj -1.1323915 Primal inf 7077.1552 (65)
# Primal infeasible - objective value -1.1323915
# PrimalInfeasible objective -1.132391468 - 414 iterations time 0.022
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.02
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/df883f5893304a8faaab2cfe78575c4a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/df883f5893304a8faaab2cfe78575c4a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 509 COLUMNS
# At line 5799 RHS
# At line 6304 BOUNDS
# At line 6305 ENDATA
# Problem MODEL has 504 rows, 260 columns and 5038 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 495 (-9) rows, 260 (0) columns and 4948 (-90) elements
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001% of 0.0065327338 - largest nonzero change 4.9934539e-06 ( 3.8931538%) - largest zero change 4.6133329e-06
# 0  Obj -0 Primal inf 4.2832512 (2)
# 38  Obj -0.001371583 Primal inf 5171.1802 (254)
# 90  Obj -0.0080148544 Primal inf 11159.564 (243)
# 143  Obj -0.01915644 Primal inf 8203.8755 (237)
# 191  Obj -0.031100764 Primal inf 12584.322 (233)
# 230  Obj -0.050951092 Primal inf 64222.596 (250)
# 285  Obj -0.091300831 Primal inf 9536.8588 (197)
# 325  Obj -0.10889192 Primal inf 884.67674 (92)
# 414  Obj -1.1581194 Primal inf 7241.5953 (65)
# Primal infeasible - objective value -1.1581194
# PrimalInfeasible objective -1.15811935 - 414 iterations time 0.012
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.01
# Time (Wallclock Seconds):   0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Status: Infeasible
# Optimal Portfolio Weights:
# x0: 0.0
# x1: 0.0
# x2: 0.0
# x3: 0.0
# x4: 0.0
# x5: 0.0
# x6: 127.39685
# x7: -126.39685
# x8: 0.0
# expected return (MAD): 0.009999999686803221
# Mean Absolute Deviation (MAD): 1.1538555437270919

# %%
print(T)
# Out:
# 251

# %%
plt.figure()
plt.plot(m0_array, risk_array)

# %% [markdown]
# # Now we consider risk as total variance of the portfolio, all these models are model 2x

# %% [markdown]
# # model 2A
# when we minimize variance under a specified expected return $r_0$
# $$
# \begin{gathered}
# \operatorname{maximize} -\frac{1}{T} \sum_{t=1}^T\left(\sum_j x_j\left(R_j(t)-r_j\right)\right)^2 \\
# \text { subject to } \sum_j x_j=1 \\
#   \sum_j x_j r_j = r_0 \\
# x_j \geq 0 \quad j=1,2, \ldots, n, \\
# r_j=\frac{1}{T} \sum_{t=1}^T R_j(t)
# \end{gathered}
# $$

# %%
# centered return
T = 251
R_c = 0. * R
for j in range(len(R[0,:])):
  R_c[:,j] = R[:,j] - r[j]

#print(np.outer(R_c[0,:],R_c[0,:]))
R_c.T @ R_c

# compute the convariance matrix manually
sig = 0. * S
for i in range(len(R[:,0])):
  sig = sig + np.outer(R_c[i,:],R_c[i,:])
sig = sig / T


r0 = 0.0005
n = len(R[0,:])
e = np.ones((n,1))
rq = r.reshape(n,1)

X = cp.Variable((n,1))
Objective = cp.Minimize(cp.quad_form(X,sig))
constraints = [e.T@X == 1, X >= 0, rq.T@X >= r0]
problem = cp.Problem(Objective,constraints)

result = problem.solve()

print(X)
# Out:
# var295

# %%
print("expected portfolio", X.value.T)
print("expected return :", (rq.T @ X.value)[0] )
print("Mean variance:", (X.value.T @ sig @ X.value)[0] )
# Out:
# expected portfolio [[ 1.00765992e-01  1.27556295e-01  1.02968173e-01  3.95945155e-02
#    9.01088657e-02  5.13512347e-02  1.11269797e-02  4.76531512e-01
#   -3.48048956e-06]]
# expected return : [0.00050012]
# Mean variance: [1.82294098e-05]

# %% [markdown]
# ## Optimization Problem
#
# Choose a risk tolerance $q > 0$:
#
# \begin{align*}
# \text{minimize:} \ \ & \mathbf{x}^T \Sigma \mathbf{x} - q \mathbf{r}^T \mathbf{x} \\
# \text{subject to:} \ \ & \mathbf{e}^T \mathbf{x} = 1 \\
# & \mathbf{x} \geq 0 \\
# \end{align*}

# %%
n = len(assets)
q = 0.1
e = np.ones(n)
X = cp.Variable(n)

obj = cp.Minimize(cp.quad_form(X,S) - q*r@X)
constraints = [e@X == 1, X >= 0]
problem = cp.Problem(obj,constraints)

result = problem.solve()
X.value
# Out:
# array([0.10704058, 0.12416004, 0.10859637, 0.07326517, 0.09991066,
#        0.0944193 , 0.01374105, 0.35285437, 0.02601249])

# %% [markdown]
# ## Optimization Problem
#
# \begin{align*}
# \text{minimize:} \ \ & \mathbf{x}^T \Sigma \mathbf{x} \\
# \text{subject to:} \ \ & \mathbf{e}^T \mathbf{x} = 1 \\
# & \mathbf{r}^T \mathbf{x} = \mu \\
# & \mathbf{x} \geq 0 \\
# \end{align*}

# %% [markdown]
# case mu = 0.01,   minimize risk sigma = 0.001
#
# case mu = 0.02,  minimize risk sigma = 0.003
#
# case mu = 0.05,  minimize risk  sigma = 0.010

# %%
n = len(assets)
e = np.ones((n,1))
r = r.reshape(n,1)
mu = 0.001

M = np.block([[2*S,-r,-e],[r.T,0,0],[e.T,0,0]])
b = np.block([[np.zeros((n,1))],[mu],[1]])

x = la.solve(M,b)
print(x)
# Out:
# [[ 1.47216069e-01]
#  [ 7.69726751e+00]
#  [-3.95682836e-01]
#  [-5.87429844e+00]
#  [-1.23037896e+00]
#  [ 1.41669335e+01]
#  [-1.60295891e-02]
#  [ 8.96652511e-01]
#  [-1.43916798e+01]
#  [ 8.42633049e-02]
#  [-1.74570989e-05]]
